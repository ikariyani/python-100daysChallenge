# %% [markdown]
# ![Python_logo_and_wordmark.svg.png](attachment:Python_logo_and_wordmark.svg.png)
# # Introduction to Data Analytics with Python and SQL

# %% [markdown]
# Hai, nama saya Ika Riyani. Saya sedang belajar Python dan SQL untuk Data Analisis dan memulai dengan mengikuti tantangan #100daysofcode. Saya akan update progres belajar saya setiap hari melalui sosial media saya di [Twitter](https://twitter.com/ikariyani_B4/status/1575849127782801408) dan di <a href='https://www.linkedin.com/in/ikariyanip/'>LinkedIn</a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('Hai, nama saya Ika Riyani. Saya sedang belajar Python dan SQL ')
# Out:
# Hai, nama saya Ika Riyani. Saya sedang belajar Python dan SQL

# %%
print('Saya akan update progres belajar saya setiap hari melalui sosial media saya melalui Twitter dan LinkedIn')
# Out:
# Saya akan update progres belajar saya setiap hari melalui sosial media saya melalui Twitter dan LinkedIn
