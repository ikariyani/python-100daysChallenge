# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://upload.wikimedia.org/wikipedia/fr/3/37/Logo_Matplotlib.svg" style="height:80px"> |
# | --- | --- |
#
#
#
# # MATPLOTLIB - Introduction to Matplotlib

# %% [markdown]
# Setelah selesai mempelajari basic Python, library NumPy dan Pandas, maka pada progres belajar selanjutnya adalah mempelajari library lain pada Python yaitu Matplotlib. Matplotlib adalah library Python yang fokus pada visualisasi data seperti membuat plot grafik.Visualisasi dari matplotlib adalah sebuah gambar grafik yang terdapat satu sumbu atau lebih. Setiap sumbu memiliki sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna dan glyphs seperti marker (contohnya bentuk lingkaran) atau lines (garis) atau poligon. Hal yang penting dalam visualisasi data adalah penentuan warna, tekstur, dan style yang menarik untuk dilihat dan representatif terhadap data.

# %%
# Untuk memulai menggunakan matplotlib, lakukan install terlebih dahulu library matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (3.6.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (4.37.3)
# Requirement already satisfied: numpy>=1.19 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (1.23.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in d:\belajar\github\python-100dayschallenge\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Setelah terinstal, maka package atau library Matplotlib dapat dilakukan import untuk memanggil seluruh fungsi yang ada pada Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([0, 20])
y = np.array([0, 5])

plt.plot(x , y)
plt.show()

# %%
x = np.array([0, 20])
y = np.array([0, 5])

plt.plot(x , y , 'o')
plt.show()

# %%
A = np.array([0, 5, 10, 15, 20, 25, 30])
B = np.array([10, 8, 5, 12, 8, 9, 3])

plt.plot(A, B)
plt.show()
