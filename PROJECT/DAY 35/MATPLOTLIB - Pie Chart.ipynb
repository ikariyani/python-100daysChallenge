# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://upload.wikimedia.org/wikipedia/fr/3/37/Logo_Matplotlib.svg" style="height:80px"> |
# | --- | --- |
#
#
# # MATPLOTLIB - Pie Chart

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "gdp.csv"


df = pd.read_csv(file)


df
# Out:
#     code  rank                    country        gdp
# 0    USA   1.0              United States  19485394.0
# 1    CHN   2.0                      China  12237700.0
# 2    JPN   3.0                      Japan   4872415.0
# 3    DEU   4.0                    Germany   3693204.0
# 4    IND   5.0                      India   2650725.0
# ..   ...   ...                        ...         ...
# 212  SXM   NaN  Sint Maarten (Dutch part)         NaN
# 213  MAF   NaN   St. Martin (French part)         NaN
# 214  SYR   NaN       Syrian Arab Republic         NaN
# 215  TCA   NaN   Turks and Caicos Islands         NaN
# 216  VEN   NaN              Venezuela, RB         NaN
#
# [217 rows x 4 columns]

# %%
file2 = "country_region.csv"

df2 = pd.read_csv(file2)

df2
# Out:
#                country                 region
# 0       American Samoa  EAST ASIA AND PACIFIC
# 1            Australia  EAST ASIA AND PACIFIC
# 2    Brunei Darussalam  EAST ASIA AND PACIFIC
# 3             Cambodia  EAST ASIA AND PACIFIC
# 4                China  EAST ASIA AND PACIFIC
# ..                 ...                    ...
# 213           Tanzania     SUB-SAHARAN AFRICA
# 214               Togo     SUB-SAHARAN AFRICA
# 215             Uganda     SUB-SAHARAN AFRICA
# 216             Zambia     SUB-SAHARAN AFRICA
# 217           Zimbabwe     SUB-SAHARAN AFRICA
#
# [218 rows x 2 columns]

# %%
tabel1 = df.set_index('country')

tabel1
# Out:
#                           code  rank        gdp
# country
# United States              USA   1.0  19485394.0
# China                      CHN   2.0  12237700.0
# Japan                      JPN   3.0   4872415.0
# Germany                    DEU   4.0   3693204.0
# India                      IND   5.0   2650725.0
# ...                        ...   ...         ...
# Sint Maarten (Dutch part)  SXM   NaN         NaN
# St. Martin (French part)   MAF   NaN         NaN
# Syrian Arab Republic       SYR   NaN         NaN
# Turks and Caicos Islands   TCA   NaN         NaN
# Venezuela, RB              VEN   NaN         NaN
#
# [217 rows x 3 columns]

# %%
tabel2 = df2.set_index('country')

tabel2
# Out:
#                                   region
# country
# American Samoa     EAST ASIA AND PACIFIC
# Australia          EAST ASIA AND PACIFIC
# Brunei Darussalam  EAST ASIA AND PACIFIC
# Cambodia           EAST ASIA AND PACIFIC
# China              EAST ASIA AND PACIFIC
# ...                                  ...
# Tanzania              SUB-SAHARAN AFRICA
# Togo                  SUB-SAHARAN AFRICA
# Uganda                SUB-SAHARAN AFRICA
# Zambia                SUB-SAHARAN AFRICA
# Zimbabwe              SUB-SAHARAN AFRICA
#
# [218 rows x 1 columns]

# %%
join = tabel1.join(tabel2)

join
# Out:
#                           code  rank        gdp   \
# country
# United States              USA   1.0  19485394.0
# China                      CHN   2.0  12237700.0
# Japan                      JPN   3.0   4872415.0
# Germany                    DEU   4.0   3693204.0
# India                      IND   5.0   2650725.0
# ...                        ...   ...         ...
# Sint Maarten (Dutch part)  SXM   NaN         NaN
# St. Martin (French part)   MAF   NaN         NaN
# Syrian Arab Republic       SYR   NaN         NaN
# Turks and Caicos Islands   TCA   NaN         NaN
# Venezuela, RB              VEN   NaN         NaN
#
#                                                     region
# country
# United States                                NORTH AMERICA
# China                                EAST ASIA AND PACIFIC
# Japan                                EAST ASIA AND PACIFIC
# Germany                            EUROPE AND CENTRAL ASIA
# India                                          SOUTH ASIA
# ...                                                    ...
# Sint Maarten (Dutch part)  LATIN AMERICA AND THE CARIBBEAN
# St. Martin (French part)   LATIN AMERICA AND THE CARIBBEAN
# Syrian Arab Republic          MIDDLE EAST AND NORTH AFRICA
# Turks and Caicos Islands   LATIN AMERICA AND THE CARIBBEAN
# Venezuela, RB              LATIN AMERICA AND THE CARIBBEAN
#
# [217 rows x 4 columns]

# %%
total_dunia = join[' gdp '].sum()

total_dunia
# Out:
# 79725204.0

# %%
join['region'].unique()
# Out:
# array(['NORTH AMERICA', 'EAST ASIA AND PACIFIC',
#        'EUROPE AND CENTRAL ASIA', 'SOUTH ASIA\xa0',
#        'LATIN AMERICA AND THE CARIBBEAN', nan,
#        'MIDDLE EAST AND NORTH AFRICA', 'SUB-SAHARAN AFRICA'], dtype=object)

# %%
NA = join.loc[join['region'] == 'NORTH AMERICA'][' gdp '].sum()

NA
# Out:
# 21132514.0

# %%
EAP = join.loc[join['region'] == 'EAST ASIA AND PACIFIC'][' gdp '].sum()

EAP
# Out:
# 23377837.0

# %%
EACA = join.loc[join['region'] == 'EUROPE AND CENTRAL ASIA'][' gdp '].sum()

EACA
# Out:
# 20639993.0

# %%
SA = join.loc[join['region'] == 'SOUTH ASIA\xa0'][' gdp '].sum()

SA
# Out:
# 3344576.0

# %%
LATC = join.loc[join['region'] == 'LATIN AMERICA AND THE CARIBBEAN'][' gdp '].sum()

LATC
# Out:
# 5499690.0

# %%
MENA = join.loc[join['region'] == 'MIDDLE EAST AND NORTH AFRICA'][' gdp '].sum()

MENA
# Out:
# 3206394.0

# %%
SSA = join.loc[join['region'] == 'SUB-SAHARAN AFRICA'][' gdp '].sum()

SSA
# Out:
# 1663950.0

# %%
gdp_regional = np.array([NA, EAP, EACA, SA, LATC, MENA, SSA])

gdp_regional
# Out:
# array([21132514., 23377837.,  3344576.,  3344576.,  5499690.,  3206394.,
#         1663950.])

# %%
region = np.delete(join['region'].unique(), 5)

region
# Out:
# array(['NORTH AMERICA', 'EAST ASIA AND PACIFIC',
#        'EUROPE AND CENTRAL ASIA', 'SOUTH ASIA\xa0',
#        'LATIN AMERICA AND THE CARIBBEAN', 'MIDDLE EAST AND NORTH AFRICA',
#        'SUB-SAHARAN AFRICA'], dtype=object)

# %%
region[3] = 'SOUTH ASIA'

region
# Out:
# array(['NORTH AMERICA', 'EAST ASIA AND PACIFIC',
#        'EUROPE AND CENTRAL ASIA', 'SOUTH ASIA',
#        'LATIN AMERICA AND THE CARIBBEAN', 'MIDDLE EAST AND NORTH AFRICA',
#        'SUB-SAHARAN AFRICA'], dtype=object)

# %%
plt.pie(gdp_regional, labels = region, autopct='%1.1f%%')


plt.title("GDP Negara Berdasarkan Region Menurut World Bank")



plt.show()

# %%
NA = join.loc[join['region'] == 'NORTH AMERICA'][' gdp ']

NA = NA.to_numpy()

NA = np.delete(NA, 2)

NA
# Out:
# array([19485394.,  1647120.])

# %%
NA_negara = join.loc[join['region'] == 'NORTH AMERICA'].reset_index()

NA_negara = NA_negara['country'].to_numpy()

NA_negara = np.delete(NA_negara, 2)

NA_negara
# Out:
# array(['United States', 'Canada'], dtype=object)

# %%
plt.pie(NA, labels = NA_negara, autopct='%1.1f%%')

plt.show()

# %%
EAP = join.loc[join['region'] == 'EAST ASIA AND PACIFIC'][' gdp ']

EAP = EAP.to_numpy()

EAP = np.delete(EAP, [34, 35, 36])

EAP
# Out:
# array([1.223770e+07, 4.872415e+06, 1.530751e+06, 1.323421e+06,
#        1.015421e+06, 4.553030e+05, 3.414490e+05, 3.239070e+05,
#        3.147100e+05, 3.135950e+05, 2.237800e+05, 2.041390e+05,
#        6.706900e+04, 5.036100e+04, 2.215800e+04, 2.053600e+04,
#        1.685300e+04, 1.212800e+04, 1.143400e+04, 5.859000e+03,
#        5.061000e+03, 2.955000e+03, 1.593000e+03, 1.303000e+03,
#        8.630000e+02, 8.410000e+02, 6.340000e+02, 4.280000e+02,
#        3.360000e+02, 2.900000e+02, 2.040000e+02, 1.860000e+02,
#        1.140000e+02, 4.000000e+01])

# %%
EAP_negara = join.loc[join['region'] == 'EAST ASIA AND PACIFIC'][' gdp '].reset_index()

EAP_negara = EAP_negara['country'].to_numpy()

EAP_negara = np.delete(EAP_negara, [34, 35, 36])

EAP_negara
# Out:
# array(['China', 'Japan', 'Korea, Rep.', 'Australia', 'Indonesia',
#        'Thailand', 'Hong Kong SAR, China', 'Singapore', 'Malaysia',
#        'Philippines', 'Vietnam', 'New Zealand', 'Myanmar',
#        'Macao SAR, China', 'Cambodia', 'Papua New Guinea', 'Lao PDR',
#        'Brunei Darussalam', 'Mongolia', 'Guam', 'Fiji', 'Timor-Leste',
#        'Northern Mariana Islands', 'Solomon Islands', 'Vanuatu', 'Samoa',
#        'American Samoa', 'Tonga', 'Micronesia, Fed. Sts.', 'Palau',
#        'Marshall Islands', 'Kiribati', 'Nauru', 'Tuvalu'], dtype=object)

# %%
plt.pie(EAP, labels = EAP_negara, autopct='%1.1f%%')

plt.show()

# %%
EACA_negara = join.loc[join['region'] == 'EUROPE AND CENTRAL ASIA'][' gdp ']

EACA_negara
# Out:
# country
# Germany                   3693204.0
# United Kingdom            2637866.0
# France                    2582501.0
# Italy                     1943835.0
# Russian Federation        1578417.0
# Spain                     1314314.0
# Netherlands                830573.0
# Switzerland                678965.0
# Sweden                     535607.0
# Poland                     526466.0
# Belgium                    494764.0
# Austria                    416836.0
# Norway                     399489.0
# Ireland                    331430.0
# Denmark                    329866.0
# Finland                    252302.0
# Portugal                   219308.0
# Czech Republic             215914.0
# Romania                    211884.0
# Greece                     203086.0
# Kazakhstan                 162887.0
# Hungary                    139761.0
# Ukraine                    112154.0
# Slovak Republic             95618.0
# Luxembourg                  62316.0
# Bulgaria                    58221.0
# Croatia                     55213.0
# Belarus                     54456.0
# Uzbekistan                  49677.0
# Slovenia                    48770.0
# Lithuania                   47544.0
# Serbia                      41432.0
# Azerbaijan                  40748.0
# Turkmenistan                37926.0
# Latvia                      30463.0
# Estonia                     26612.0
# Iceland                     24488.0
# Cyprus                      22054.0
# Bosnia and Herzegovina      18055.0
# Georgia                     15081.0
# Albania                     13039.0
# Armenia                     11537.0
# North Macedonia             11280.0
# Moldova                      8128.0
# Kyrgyz Republic              7565.0
# Kosovo                       7245.0
# Tajikistan                   7146.0
# Isle of Man                  6593.0
# Monaco                       6468.0
# Liechtenstein                6215.0
# Montenegro                   4845.0
# Andorra                      3013.0
# Greenland                    2706.0
# Faroe Islands                2477.0
# San Marino                   1633.0
# Channel Islands                 NaN
# Gibraltar                       NaN
# Name:  gdp , dtype: float64

# %%
EACA = join.loc[join['region'] == 'EUROPE AND CENTRAL ASIA'][' gdp ']

EACA = EACA.to_numpy()

EACA = np.delete(EACA, [55, 56])

EACA
# Out:
# array([3.693204e+06, 2.637866e+06, 2.582501e+06, 1.943835e+06,
#        1.578417e+06, 1.314314e+06, 8.305730e+05, 6.789650e+05,
#        5.356070e+05, 5.264660e+05, 4.947640e+05, 4.168360e+05,
#        3.994890e+05, 3.314300e+05, 3.298660e+05, 2.523020e+05,
#        2.193080e+05, 2.159140e+05, 2.118840e+05, 2.030860e+05,
#        1.628870e+05, 1.397610e+05, 1.121540e+05, 9.561800e+04,
#        6.231600e+04, 5.822100e+04, 5.521300e+04, 5.445600e+04,
#        4.967700e+04, 4.877000e+04, 4.754400e+04, 4.143200e+04,
#        4.074800e+04, 3.792600e+04, 3.046300e+04, 2.661200e+04,
#        2.448800e+04, 2.205400e+04, 1.805500e+04, 1.508100e+04,
#        1.303900e+04, 1.153700e+04, 1.128000e+04, 8.128000e+03,
#        7.565000e+03, 7.245000e+03, 7.146000e+03, 6.593000e+03,
#        6.468000e+03, 6.215000e+03, 4.845000e+03, 3.013000e+03,
#        2.706000e+03, 2.477000e+03, 1.633000e+03])

# %%
EACA_negara = join.loc[join['region'] == 'EUROPE AND CENTRAL ASIA'][' gdp '].reset_index()

EACA_negara = EACA_negara['country'].to_numpy()

EACA_negara = np.delete(EACA_negara, [55,56])

EACA_negara
# Out:
# array(['Germany', 'United Kingdom', 'France', 'Italy',
#        'Russian Federation', 'Spain', 'Netherlands', 'Switzerland',
#        'Sweden', 'Poland', 'Belgium', 'Austria', 'Norway', 'Ireland',
#        'Denmark', 'Finland', 'Portugal', 'Czech Republic', 'Romania',
#        'Greece', 'Kazakhstan', 'Hungary', 'Ukraine', 'Slovak Republic',
#        'Luxembourg', 'Bulgaria', 'Croatia', 'Belarus', 'Uzbekistan',
#        'Slovenia', 'Lithuania', 'Serbia', 'Azerbaijan', 'Turkmenistan',
#        'Latvia', 'Estonia', 'Iceland', 'Cyprus', 'Bosnia and Herzegovina',
#        'Georgia', 'Albania', 'Armenia', 'North Macedonia', 'Moldova',
#        'Kyrgyz Republic', 'Kosovo', 'Tajikistan', 'Isle of Man', 'Monaco',
#        'Liechtenstein', 'Montenegro', 'Andorra', 'Greenland',
#        'Faroe Islands', 'San Marino'], dtype=object)

# %%
plt.pie(EACA, labels = EACA_negara, autopct='%1.1f%%')

plt.show()

# %%
SA = join.loc[join['region'] == 'SOUTH ASIA\xa0'][' gdp ']

SA
# Out:
# country
# India          2650725.0
# Pakistan        304952.0
# Bangladesh      249724.0
# Sri Lanka        87357.0
# Nepal            24880.0
# Afghanistan      19544.0
# Maldives          4866.0
# Bhutan            2528.0
# Name:  gdp , dtype: float64

# %%
SA = join.loc[join['region'] == 'SOUTH ASIA\xa0'][' gdp ']

SA = SA.to_numpy()

SA
# Out:
# array([2.650725e+06, 3.049520e+05, 2.497240e+05, 8.735700e+04,
#        2.488000e+04, 1.954400e+04, 4.866000e+03, 2.528000e+03])

# %%
SA_negara = join.loc[join['region'] == 'SOUTH ASIA\xa0'][' gdp '].reset_index()

SA_negara = SA_negara['country'].to_numpy()

SA_negara
# Out:
# array(['India', 'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal',
#        'Afghanistan', 'Maldives', 'Bhutan'], dtype=object)

# %%
plt.pie(SA, labels = SA_negara, autopct='%1.1f%%')


plt.show()

# %%
LATC = join.loc[join['region'] == 'LATIN AMERICA AND THE CARIBBEAN'][' gdp ']

LATC
# Out:
# country
# Brazil                            2053595.0
# Mexico                            1150888.0
# Argentina                          637430.0
# Colombia                           314458.0
# Chile                              277076.0
# Peru                               211389.0
# Ecuador                            104296.0
# Puerto Rico                        103961.0
# Cuba                                96851.0
# Dominican Republic                  75932.0
# Guatemala                           75620.0
# Panama                              62284.0
# Costa Rica                          57286.0
# Uruguay                             56157.0
# Paraguay                            39667.0
# Bolivia                             37509.0
# El Salvador                         24805.0
# Honduras                            22979.0
# Trinidad and Tobago                 22079.0
# Jamaica                             14781.0
# Nicaragua                           13814.0
# Bahamas, The                        12162.0
# Haiti                                8408.0
# Barbados                             4674.0
# Virgin Islands (U.S.)                3759.0
# Guyana                               3621.0
# Suriname                             2996.0
# Aruba                                2701.0
# Belize                               1863.0
# St. Lucia                            1738.0
# Antigua and Barbuda                  1510.0
# Grenada                              1127.0
# St. Kitts and Nevis                   992.0
# St. Vincent and the Grenadines        785.0
# Dominica                              497.0
# British Virgin Islands                  NaN
# Cayman Islands                          NaN
# Sint Maarten (Dutch part)               NaN
# St. Martin (French part)                NaN
# Turks and Caicos Islands                NaN
# Venezuela, RB                           NaN
# Name:  gdp , dtype: float64

# %%
LATC = join.loc[join['region'] == 'LATIN AMERICA AND THE CARIBBEAN'][' gdp '].to_numpy()

LATC = np.delete(LATC, [35, 36, 37, 38, 39, 40])

LATC
# Out:
# array([2.053595e+06, 1.150888e+06, 6.374300e+05, 3.144580e+05,
#        2.770760e+05, 2.113890e+05, 1.042960e+05, 1.039610e+05,
#        9.685100e+04, 7.593200e+04, 7.562000e+04, 6.228400e+04,
#        5.728600e+04, 5.615700e+04, 3.966700e+04, 3.750900e+04,
#        2.480500e+04, 2.297900e+04, 2.207900e+04, 1.478100e+04,
#        1.381400e+04, 1.216200e+04, 8.408000e+03, 4.674000e+03,
#        3.759000e+03, 3.621000e+03, 2.996000e+03, 2.701000e+03,
#        1.863000e+03, 1.738000e+03, 1.510000e+03, 1.127000e+03,
#        9.920000e+02, 7.850000e+02, 4.970000e+02])

# %%
LATC_negara = join.loc[join['region'] == 'LATIN AMERICA AND THE CARIBBEAN'][' gdp '].reset_index()

LATC_negara = LATC_negara['country'].to_numpy()

LATC_negara = np.delete(LATC_negara, [35, 36, 37, 38, 39, 40])
LATC_negara
# Out:
# array(['Brazil', 'Mexico', 'Argentina', 'Colombia', 'Chile', 'Peru',
#        'Ecuador', 'Puerto Rico', 'Cuba', 'Dominican Republic',
#        'Guatemala', 'Panama', 'Costa Rica', 'Uruguay', 'Paraguay',
#        'Bolivia', 'El Salvador', 'Honduras', 'Trinidad and Tobago',
#        'Jamaica', 'Nicaragua', 'Bahamas, The', 'Haiti', 'Barbados',
#        'Virgin Islands (U.S.)', 'Guyana', 'Suriname', 'Aruba', 'Belize',
#        'St. Lucia', 'Antigua and Barbuda', 'Grenada',
#        'St. Kitts and Nevis', 'St. Vincent and the Grenadines',
#        'Dominica'], dtype=object)

# %%
plt.pie(LATC, labels = LATC_negara, autopct='%1.1f%%')


plt.show()

# %%
MENA = join.loc[join['region'] == 'MIDDLE EAST AND NORTH AFRICA'][' gdp ']

MENA
# Out:
# country
# Saudi Arabia            686738.0
# Iran, Islamic Rep.      454013.0
# United Arab Emirates    382575.0
# Israel                  353268.0
# Egypt, Arab Rep.        235369.0
# Iraq                    192061.0
# Algeria                 167555.0
# Qatar                   166929.0
# Kuwait                  120126.0
# Morocco                 109709.0
# Oman                     70784.0
# Lebanon                  53577.0
# Jordan                   40068.0
# Tunisia                  39952.0
# Libya                    38108.0
# Bahrain                  35433.0
# Yemen, Rep.              31268.0
# West Bank and Gaza       14498.0
# Malta                    12518.0
# Djibouti                  1845.0
# Syrian Arab Republic         NaN
# Name:  gdp , dtype: float64

# %%
MENA = join.loc[join['region'] == 'MIDDLE EAST AND NORTH AFRICA'][' gdp '].to_numpy()

MENA = np.delete(MENA, 20)

MENA
# Out:
# array([686738., 454013., 382575., 353268., 235369., 192061., 167555.,
#        166929., 120126., 109709.,  70784.,  53577.,  40068.,  39952.,
#         38108.,  35433.,  31268.,  14498.,  12518.,   1845.])

# %%
MENA_negara = join.loc[join['region'] == 'MIDDLE EAST AND NORTH AFRICA'][' gdp '].reset_index()

MENA_negara = MENA_negara['country'].to_numpy()

MENA_negara = np.delete(MENA_negara, 20)

MENA_negara
# Out:
# array(['Saudi Arabia', 'Iran, Islamic Rep.', 'United Arab Emirates',
#        'Israel', 'Egypt, Arab Rep.', 'Iraq', 'Algeria', 'Qatar', 'Kuwait',
#        'Morocco', 'Oman', 'Lebanon', 'Jordan', 'Tunisia', 'Libya',
#        'Bahrain', 'Yemen, Rep.', 'West Bank and Gaza', 'Malta',
#        'Djibouti'], dtype=object)

# %%
plt.pie(MENA, labels = MENA_negara, autopct='%1.1f%%')


plt.show()

# %%
SSA = join.loc[join['region'] == 'SUB-SAHARAN AFRICA'][' gdp ']

SSA
# Out:
# country
# Nigeria                     375745.0
# South Africa                348872.0
# Angola                      122124.0
# Sudan                       117488.0
# Ethiopia                     80561.0
# Kenya                        79263.0
# Ghana                        58997.0
# Tanzania                     53321.0
# Congo, Dem. Rep.             37642.0
# Côte d'Ivoire                37353.0
# Cameroon                     34923.0
# Uganda                       25995.0
# Zambia                       25868.0
# Zimbabwe                     22041.0
# Senegal                      21070.0
# Botswana                     17407.0
# Mali                         15334.0
# Gabon                        15014.0
# Mauritius                    13266.0
# Namibia                      13254.0
# Mozambique                   12646.0
# Burkina Faso                 12323.0
# Equatorial Guinea            12294.0
# Madagascar                   11500.0
# Guinea                       10473.0
# Chad                          9871.0
# Benin                         9247.0
# Rwanda                        9135.0
# Niger                         8120.0
# Somalia                       7052.0
# Malawi                        6303.0
# Mauritania                    5025.0
# Togo                          4758.0
# Eswatini                      4434.0
# Sierra Leone                  3775.0
# Liberia                       3285.0
# Burundi                       3172.0
# South Sudan                   2904.0
# Lesotho                       2578.0
# Central African Republic      1949.0
# Cabo Verde                    1773.0
# Seychelles                    1498.0
# Gambia, The                   1489.0
# Guinea-Bissau                 1347.0
# Comoros                       1068.0
# São Tomé and Principe          393.0
# Eritrea                          NaN
# Name:  gdp , dtype: float64

# %%
SSA = join.loc[join['region'] == 'SUB-SAHARAN AFRICA'][' gdp '].to_numpy()

SSA = np.delete(SSA, 46)

SSA
# Out:
# array([375745., 348872., 122124., 117488.,  80561.,  79263.,  58997.,
#         53321.,  37642.,  37353.,  34923.,  25995.,  25868.,  22041.,
#         21070.,  17407.,  15334.,  15014.,  13266.,  13254.,  12646.,
#         12323.,  12294.,  11500.,  10473.,   9871.,   9247.,   9135.,
#          8120.,   7052.,   6303.,   5025.,   4758.,   4434.,   3775.,
#          3285.,   3172.,   2904.,   2578.,   1949.,   1773.,   1498.,
#          1489.,   1347.,   1068.,    393.])

# %%
SSA_negara = join.loc[join['region'] == 'SUB-SAHARAN AFRICA'][' gdp '].reset_index()

SSA_negara = SSA_negara['country'].to_numpy()

SSA_negara = np.delete(SSA_negara, 46)
SSA_negara
# Out:
# array(['Nigeria', 'South Africa', 'Angola', 'Sudan', 'Ethiopia', 'Kenya',
#        'Ghana', 'Tanzania', 'Congo, Dem. Rep.', "Côte d'Ivoire",
#        'Cameroon', 'Uganda', 'Zambia', 'Zimbabwe', 'Senegal', 'Botswana',
#        'Mali', 'Gabon', 'Mauritius', 'Namibia', 'Mozambique',
#        'Burkina Faso', 'Equatorial Guinea', 'Madagascar', 'Guinea',
#        'Chad', 'Benin', 'Rwanda', 'Niger', 'Somalia', 'Malawi',
#        'Mauritania', 'Togo', 'Eswatini', 'Sierra Leone', 'Liberia',
#        'Burundi', 'South Sudan', 'Lesotho', 'Central African Republic',
#        'Cabo Verde', 'Seychelles', 'Gambia, The', 'Guinea-Bissau',
#        'Comoros', 'São Tomé and Principe'], dtype=object)

# %%
plt.pie(SSA, labels = SSA_negara, autopct='%1.1f%%')

plt.show()
