# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://upload.wikimedia.org/wikipedia/fr/3/37/Logo_Matplotlib.svg" style="height:80px"> |
# | --- | --- |
#
#
#
# # MATPLOTLIB - Stem Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "oil_consumption.csv"

df = pd.read_csv(file)

df
# Out:
#     year           gdp  oil_energy_use
# 0   1960  3.010000e+11          250.00
# 1   1961  3.010000e+11          252.57
# 2   1962  3.010000e+11          259.76
# 3   1963  3.010000e+11          265.47
# 4   1964  3.010000e+11          267.09
# ..   ...           ...             ...
# 56  2016  9.320000e+11          903.97
# 57  2017  1.020000e+12          917.69
# 58  2018  1.040000e+12          936.89
# 59  2019  1.120000e+12          940.04
# 60  2020  1.060000e+12          967.33
#
# [61 rows x 3 columns]

# %%
X = df['year']

X
# Out:
# 0     1960
# 1     1961
# 2     1962
# 3     1963
# 4     1964
#       ...
# 56    2016
# 57    2017
# 58    2018
# 59    2019
# 60    2020
# Name: year, Length: 61, dtype: int64

# %%
Y = df['oil_energy_use']

Y
# Out:
# 0     250.00
# 1     252.57
# 2     259.76
# 3     265.47
# 4     267.09
#        ...
# 56    903.97
# 57    917.69
# 58    936.89
# 59    940.04
# 60    967.33
# Name: oil_energy_use, Length: 61, dtype: float64

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 23)
font2 = fm.FontProperties(fname = path2, size = 15)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 10)

# %%
plt.figure(figsize = (10, 5))

plt.stem(X, Y, label = 'Oil Consumption', linefmt = '#668b69', markerfmt = '#2d3c1f', basefmt = '#206261')


plt.xticks(np.arange(1960, 2025, 5), fontproperties = font4)
plt.yticks(np.arange(0, 1000, 100), fontproperties = font4)

plt.title("Oil Consumption in Indonesia", fontproperties = font1)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel ('Oil Energy Use', fontproperties = font2)

plt.grid(linestyle = 'dashed')

plt.legend(prop = font2)

plt.show()
