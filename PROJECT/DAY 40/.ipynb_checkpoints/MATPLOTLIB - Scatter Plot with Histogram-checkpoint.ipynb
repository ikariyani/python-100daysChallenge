# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://upload.wikimedia.org/wikipedia/fr/3/37/Logo_Matplotlib.svg" style="height:80px"> |
# | --- | --- |

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import numpy as np

# %%
file = "energy.csv"

df = pd.read_csv(file)

df
# Out:
#        Unnamed: 0   Country                Energy_type  Year  \
# 0               0     World           all_energy_types  1980
# 1               1     World                       coal  1980
# 2               2     World                natural_gas  1980
# 3               3     World  petroleum_n_other_liquids  1980
# 4               4     World                    nuclear  1980
# ...           ...       ...                        ...   ...
# 55435       55435  Zimbabwe                       coal  2019
# 55436       55436  Zimbabwe                natural_gas  2019
# 55437       55437  Zimbabwe  petroleum_n_other_liquids  2019
# 55438       55438  Zimbabwe                    nuclear  2019
# 55439       55439  Zimbabwe         renewables_n_other  2019
#
#        Energy_consumption  Energy_production           GDP    Population  \
# 0              292.899790         296.337228  27770.910281  4.298127e+06
# 1               78.656134          80.114194  27770.910281  4.298127e+06
# ...

# %%
world = df.loc[df['Country'] == 'World']

world
# Out:
#        Unnamed: 0 Country                Energy_type  Year  \
# 0               0   World           all_energy_types  1980
# 1               1   World                       coal  1980
# 2               2   World                natural_gas  1980
# 3               3   World  petroleum_n_other_liquids  1980
# 4               4   World                    nuclear  1980
# ...           ...     ...                        ...   ...
# 54055       54055   World                       coal  2019
# 54056       54056   World                natural_gas  2019
# 54057       54057   World  petroleum_n_other_liquids  2019
# 54058       54058   World                    nuclear  2019
# 54059       54059   World         renewables_n_other  2019
#
#        Energy_consumption  Energy_production            GDP    Population  \
# 0              292.899790         296.337228   27770.910281  4.298127e+06
# 1               78.656134          80.114194   27770.910281  4.298127e+06
# ...

# %%
country = df.set_index('Country')

country
# Out:
#           Unnamed: 0                Energy_type  Year  Energy_consumption  \
# Country
# World              0           all_energy_types  1980          292.899790
# World              1                       coal  1980           78.656134
# World              2                natural_gas  1980           53.865223
# World              3  petroleum_n_other_liquids  1980          132.064019
# World              4                    nuclear  1980            7.575700
# ...              ...                        ...   ...                 ...
# Zimbabwe       55435                       coal  2019            0.045064
# Zimbabwe       55436                natural_gas  2019            0.000000
# Zimbabwe       55437  petroleum_n_other_liquids  2019            0.055498
# Zimbabwe       55438                    nuclear  2019                 NaN
# Zimbabwe       55439         renewables_n_other  2019            0.068089
#
#           Energy_production           GDP    Population  \
# Country
# ...

# %%
world = country.drop('World')

world
# Out:
#              Unnamed: 0                Energy_type  Year  Energy_consumption  \
# Country
# Afghanistan           6           all_energy_types  1980            0.026583
# Afghanistan           7                       coal  1980            0.002479
# Afghanistan           8                natural_gas  1980            0.002094
# Afghanistan           9  petroleum_n_other_liquids  1980            0.014624
# Afghanistan          10                    nuclear  1980                 NaN
# ...                 ...                        ...   ...                 ...
# Zimbabwe          55435                       coal  2019            0.045064
# Zimbabwe          55436                natural_gas  2019            0.000000
# Zimbabwe          55437  petroleum_n_other_liquids  2019            0.055498
# Zimbabwe          55438                    nuclear  2019                 NaN
# Zimbabwe          55439         renewables_n_other  2019            0.068089
#
# ...

# %%
cons = world['CO2_emission']

cons
# Out:
# Country
# Afghanistan         NaN
# Afghanistan         NaN
# Afghanistan         NaN
# Afghanistan         NaN
# Afghanistan    0.000000
#                  ...
# Zimbabwe       4.586869
# Zimbabwe       0.000000
# Zimbabwe       4.377890
# Zimbabwe       0.000000
# Zimbabwe       0.000000
# Name: CO2_emission, Length: 55200, dtype: float64

# %%
gdp = world['GDP']

gdp
# Out:
# Country
# Afghanistan        NaN
# Afghanistan        NaN
# Afghanistan        NaN
# Afghanistan        NaN
# Afghanistan        NaN
#                 ...
# Zimbabwe       37.6204
# Zimbabwe       37.6204
# Zimbabwe       37.6204
# Zimbabwe       37.6204
# Zimbabwe       37.6204
# Name: GDP, Length: 55200, dtype: float64

# %%
plt.scatter(cons, gdp)


plt.show()

# %%
fig = plt.figure()
gs = GridSpec(4, 4)

plt_scatter = fig.add_subplot(gs[1:4, 0:3])
plt_hist_y = fig.add_subplot(gs[0,0:3])
plt_hist_x = fig.add_subplot(gs[1:4, 3])

plt_scatter.scatter(cons, gdp)

plt_hist_x.hist(cons)
plt_hist_y.hist(gdp, orientation = 'horizontal')


plt.show()

# %%
def scatter_hist(cons, gdp, plt, plt_histx, plt_histy):
    
    plt_histx.tick_params(axis="x", labelbottom=False)
    plt_histy.tick_params(axis="y", labelleft=False)

    plt.scatter(cons, gdp)

   
    plt_histx.hist(cons)
    plt_histy.hist(gdp, orientation='horizontal')


ax = fig.add_subplot(gs[1, 0])
ax_histx = fig.add_subplot(gs[0, 0], sharex=ax)
ax_histy = fig.add_subplot(gs[1, 1], sharey=ax)    

scatter_hist(cons, gdp, plt, ax_histx, ax_histy)

# %%
file = "gapminder_data_graphs.csv"

df = pd.read_csv(file)

df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
year_2018 = df.loc[df['year'] == 2018]

year_2018
# Out:
#           country      continent  year  life_exp  hdi_index  co2_consump  \
# 20    Afghanistan           Asia  2018      62.7      0.509        0.254
# 41        Albania         Europe  2018      78.4      0.792        1.590
# 62        Algeria         Africa  2018      76.0      0.746        3.690
# 83         Angola         Africa  2018      64.6      0.582        1.120
# 104     Argentina  South America  2018      76.5      0.842        4.410
# ...           ...            ...   ...       ...        ...          ...
# 3590      Vanuatu        Oceania  2018      65.3      0.603        0.529
# 3611      Vietnam           Asia  2018      74.3      0.700        2.160
# 3632        Yemen           Asia  2018      66.1      0.468        0.356
# 3653       Zambia         Africa  2018      62.5      0.582        0.302
# 3674     Zimbabwe         Africa  2018      60.6      0.569        0.850
#
#           gdp  services
# 20      569.0      38.4
# 41     4430.0      43.0
# ...

# %%
life = year_2018['life_exp']

life
# Out:
# 20      62.7
# 41      78.4
# 62      76.0
# 83      64.6
# 104     76.5
#         ...
# 3590    65.3
# 3611    74.3
# 3632    66.1
# 3653    62.5
# 3674    60.6
# Name: life_exp, Length: 175, dtype: float64

# %%
hdi = year_2018['hdi_index']

hdi
# Out:
# 20      0.509
# 41      0.792
# 62      0.746
# 83      0.582
# 104     0.842
#         ...
# 3590    0.603
# 3611    0.700
# 3632    0.468
# 3653    0.582
# 3674    0.569
# Name: hdi_index, Length: 175, dtype: float64

# %%
fig = plt.figure()
gs = GridSpec(4, 4)

plt_scatter = fig.add_subplot(gs[1:4, 0:3])
plt_bar_y = fig.add_subplot(gs[0,0:3])
plt_bar_x = fig.add_subplot(gs[1:4, 3])

plt_scatter.scatter(life, hdi)

plt_bar_x.hist(life, orientation = 'horizontal')
plt_bar_y.hist(hdi, orientation = 'vertical')


plt.show()
