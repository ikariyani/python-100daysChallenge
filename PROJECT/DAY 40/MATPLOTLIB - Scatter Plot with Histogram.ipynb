# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://upload.wikimedia.org/wikipedia/fr/3/37/Logo_Matplotlib.svg" style="height:80px"> |
# | --- | --- |
#
# # MATPLOTLIB - Scatter Plot with Histogram

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import pandas as pd
import numpy as np

# %%
file = "gapminder_data_graphs.csv"

df = pd.read_csv(file)

df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# 3         24.7
# 4         25.6
# ...        ...
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2
#
# [3675 rows x 8 columns]

# %%
year_2018 = df.loc[df['year'] == 2018]

year_2018
# Out:
#           country      continent  year  life_exp  hdi_index  co2_consump  \
# 20    Afghanistan           Asia  2018      62.7      0.509        0.254
# 41        Albania         Europe  2018      78.4      0.792        1.590
# 62        Algeria         Africa  2018      76.0      0.746        3.690
# 83         Angola         Africa  2018      64.6      0.582        1.120
# 104     Argentina  South America  2018      76.5      0.842        4.410
# ...           ...            ...   ...       ...        ...          ...
# 3590      Vanuatu        Oceania  2018      65.3      0.603        0.529
# 3611      Vietnam           Asia  2018      74.3      0.700        2.160
# 3632        Yemen           Asia  2018      66.1      0.468        0.356
# 3653       Zambia         Africa  2018      62.5      0.582        0.302
# 3674     Zimbabwe         Africa  2018      60.6      0.569        0.850
#
#           gdp  services
# 20      569.0      38.4
# 41     4430.0      43.0
# 62     4160.0      59.6
# 83     3600.0      42.1
# 104   13100.0      78.0
# ...       ...       ...
# 3590   2860.0      29.0
# 3611   2460.0      34.7
# 3632   1290.0      61.5
# 3653   1370.0      39.3
# 3674   1510.0      27.2
#
# [175 rows x 8 columns]

# %%
life18 = year_2018['life_exp']

life18 = life18.to_numpy()

life18
# Out:
# array([62.7, 78.4, 76. , 64.6, 76.5, 75.6, 82.9, 82.1, 70.8, 73.8, 77. ,
#        74.2, 76.5, 74. , 81.4, 74.4, 64. , 73. , 71.8, 76.9, 61.8, 75.7,
#        74.2, 73.3, 61.3, 63.4, 69.7, 62.6, 82.2, 73.5, 51.5, 59.9, 80.1,
#        77.4, 80.1, 68.5, 64.7, 65. , 80. , 63.6, 78.6, 78.3, 80.8, 79.3,
#        81.1, 66.7, 72.9, 76.2, 70.7, 75.6, 65.8, 77.9, 57.8, 68.4, 68.3,
#        81.8, 82.9, 67.5, 66.4, 73.3, 81.2, 65.8, 81. , 72.4, 60.6, 60.3,
#        67.1, 63.5, 71.9, 84.3, 76.3, 84. , 70.5, 71.1, 77.6, 73.3, 82. ,
#        83. , 83.1, 76.3, 84.8, 77.9, 71.7, 66.1, 81.6, 73.3, 68.6, 75.8,
#        76.2, 51.4, 65.7, 75.7, 76.1, 82.9, 65.1, 64.1, 75.2, 79. , 61.2,
#        82.5, 70.5, 75.3, 75.5, 74. , 68. , 75.6, 73.1, 57.9, 69.1, 64.7,
#        70.8, 81.7, 81.8, 75.2, 62. , 63.8, 74.3, 82.8, 73.6, 65.5, 74.7,
#        79.9, 64.4, 76.5, 80. , 71.6, 78. , 81.7, 76.1, 75.5, 73. , 68.3,
#        70.4, 70.7, 74.3, 68. , 75.6, 61.2, 84.7, 77.5, 81.4, 59. , 64.4,
#        82.9, 63. , 83.1, 77.2, 75.1, 72.8, 70.1, 72.6, 82.7, 83.9, 69.2,
#        66.7, 78.3, 70.5, 64.5, 72.9, 74.8, 77.5, 78.1, 70.6, 65.7, 73.9,
#        73.7, 81. , 79. , 77.5, 68.1, 65.3, 74.3, 66.1, 62.5, 60.6])

# %%
year_2017 = df.loc[df['year'] == 2017]

year_2017
# Out:
#           country      continent  year  life_exp  hdi_index  co2_consump  \
# 19    Afghanistan           Asia  2017      62.9      0.506        0.247
# 40        Albania         Europe  2017      78.3      0.790        1.610
# 61        Algeria         Africa  2017      75.9      0.745        3.560
# 82         Angola         Africa  2017      64.2      0.582        1.140
# 103     Argentina  South America  2017      76.3      0.843        4.550
# ...           ...            ...   ...       ...        ...          ...
# 3589      Vanuatu        Oceania  2017      65.3      0.601        0.527
# 3610      Vietnam           Asia  2017      74.2      0.696        1.950
# 3631        Yemen           Asia  2017      67.3      0.467        0.363
# 3652       Zambia         Africa  2017      61.9      0.578        0.304
# 3673     Zimbabwe         Africa  2017      59.9      0.563        0.845
#
#           gdp  services
# 19      576.0      38.0
# 40     4250.0      42.5
# 61     4190.0      59.2
# 82     3790.0      41.8
# 103   13600.0      77.5
# ...       ...       ...
# 3589   2850.0      28.8
# 3610   2320.0      34.1
# 3631   1310.0      60.6
# 3652   1350.0      38.6
# 3673   1480.0      26.6
#
# [175 rows x 8 columns]

# %%
life17 = year_2017['life_exp']

life17 = life17.to_numpy()

life17
# Out:
# array([62.9, 78.3, 75.9, 64.2, 76.3, 75.5, 83. , 82. , 70.4, 73.8, 76.8,
#        73.9, 76.5, 73.8, 81.4, 74.5, 63.4, 72.7, 71.7, 76.8, 61.5, 75.4,
#        74.1, 73.3, 60.8, 63. , 69.4, 61.9, 82.4, 74.8, 50.4, 59.5, 80. ,
#        77.2, 80. , 68.2, 63.9, 64.7, 79.8, 62.8, 78.5, 78.3, 80.8, 79.3,
#        81.1, 66.2, 72.5, 76. , 70.5, 75.4, 65.6, 77.8, 57. , 67.9, 68.2,
#        81.8, 82.9, 67. , 66. , 73.2, 81.1, 65.1, 81.1, 72.3, 59.9, 59.8,
#        66.9, 63.1, 71.7, 84.1, 76.3, 83.9, 70.3, 70.9, 77.3, 71.5, 81.9,
#        83. , 83.1, 76.3, 84.7, 78.2, 71.5, 65.7, 81.6, 73. , 68.4, 75.8,
#        76.2, 50.8, 65.1, 75.6, 76. , 82.8, 64.8, 63.4, 75.1, 78.9, 60.8,
#        82.4, 70.2, 75.3, 75.5, 73.7, 67.9, 75.5, 72.9, 57.3, 68.3, 64.1,
#        70.6, 81.7, 82. , 75. , 61.5, 63.3, 74.1, 82.8, 72.9, 64.9, 74.7,
#        79.6, 64.3, 76.3, 79.8, 71.2, 78. , 81.6, 75.9, 75.4, 72.9, 68. ,
#        70.3, 70.4, 74. , 67.5, 75.6, 60.2, 84.7, 77.4, 81.3, 58.8, 63.2,
#        82.9, 62.3, 83. , 76.8, 75.1, 72.7, 69.8, 72.5, 82.7, 83.9, 68.8,
#        66. , 78.2, 70.5, 63.8, 72.8, 74.8, 77.3, 77.8, 70.5, 65. , 73.8,
#        73.5, 81.2, 79. , 77.3, 67.8, 65.3, 74.2, 67.3, 61.9, 59.9])

# %%
year_2016 = df.loc[df['year'] == 2016]

year_2016
# Out:
#           country      continent  year  life_exp  hdi_index  co2_consump  \
# 18    Afghanistan           Asia  2016      62.0      0.502        0.245
# 39        Albania         Europe  2016      78.2      0.788        1.570
# 60        Algeria         Africa  2016      75.7      0.743        3.640
# 81         Angola         Africa  2016      63.9      0.578        1.180
# 102     Argentina  South America  2016      76.2      0.839        4.600
# ...           ...            ...   ...       ...        ...          ...
# 3588      Vanuatu        Oceania  2016      65.1      0.598        0.527
# 3609      Vietnam           Asia  2016      74.0      0.693        1.960
# 3630        Yemen           Asia  2016      67.5      0.474        0.377
# 3651       Zambia         Africa  2016      61.4      0.571        0.296
# 3672     Zimbabwe         Africa  2016      59.2      0.558        0.771
#
#           gdp  services
# 18      575.0      36.9
# 39     4090.0      40.6
# 60     4220.0      59.0
# 81     3920.0      41.5
# 102   13400.0      77.0
# ...       ...       ...
# 3588   2750.0      28.7
# 3609   2190.0      33.4
# 3630   1420.0      59.5
# 3651   1350.0      38.0
# 3672   1430.0      26.1
#
# [175 rows x 8 columns]

# %%
life16 = year_2016['life_exp']

life16 = life16.to_numpy()

life16
# Out:
# array([62. , 78.2, 75.7, 63.9, 76.2, 75.3, 83. , 81.8, 70.3, 73.7, 76.8,
#        73.9, 76.5, 73.8, 81.3, 74.4, 63. , 72.5, 71.5, 76.7, 61.2, 75. ,
#        74.1, 73.3, 60.3, 62.4, 69.2, 60.9, 82.3, 74.8, 50.3, 59.3, 80. ,
#        77. , 79.8, 67.9, 63.3, 64.2, 79.8, 62. , 78.4, 78.5, 80.7, 79.2,
#        81. , 65.8, 72.1, 75.9, 70.2, 75.2, 64.9, 77.7, 56.1, 67.4, 68. ,
#        81.8, 82.8, 66.6, 65.7, 73.1, 81. , 64.7, 81. , 72. , 59.3, 59.3,
#        66.7, 62.4, 71.5, 83.9, 76.3, 83.8, 70. , 70.7, 77.1, 70.9, 81.9,
#        83. , 83. , 76.2, 84.5, 78.1, 71.1, 65.1, 81.6, 72.7, 68. , 75.7,
#        76.1, 49.6, 64.5, 74.3, 74.9, 82.7, 64.5, 62.6, 75. , 78.9, 60.4,
#        82.3, 69.9, 75.2, 75.5, 72.6, 67.8, 75.4, 72.8, 56.6, 68.2, 63.7,
#        70.4, 81.7, 81.9, 74.8, 61.1, 62.7, 73.8, 82.5, 72.6, 64.7, 74.5,
#        79.5, 64.1, 76.1, 79.6, 71. , 77.9, 81.6, 75.7, 75.3, 72. , 67.6,
#        70.2, 70.2, 73.7, 67.3, 75.5, 60. , 84.4, 77.3, 81.3, 58.6, 62.7,
#        82.8, 62. , 83. , 76.6, 75.1, 72.6, 69.4, 72.4, 82.6, 83.8, 68.6,
#        65.5, 78. , 70.4, 63. , 72.7, 74.8, 77.2, 77.5, 70.3, 64. , 72.9,
#        73.4, 81.1, 78.9, 77.3, 67.6, 65.1, 74. , 67.5, 61.4, 59.2])

# %%
hdi18 = year_2018['hdi_index']

hdi18
# Out:
# 20      0.509
# 41      0.792
# 62      0.746
# 83      0.582
# 104     0.842
#         ...
# 3590    0.603
# 3611    0.700
# 3632    0.468
# 3653    0.582
# 3674    0.569
# Name: hdi_index, Length: 175, dtype: float64

# %%
gdp18 = year_2018['gdp']

gdp18
# Out:
# 20        569.0
# 41       4430.0
# 62       4160.0
# 83       3600.0
# 104     13100.0
#          ...
# 3590     2860.0
# 3611     2460.0
# 3632     1290.0
# 3653     1370.0
# 3674     1510.0
# Name: gdp, Length: 175, dtype: float64

# %%
hdi17 = year_2017['hdi_index']

hdi17
# Out:
# 19      0.506
# 40      0.790
# 61      0.745
# 82      0.582
# 103     0.843
#         ...
# 3589    0.601
# 3610    0.696
# 3631    0.467
# 3652    0.578
# 3673    0.563
# Name: hdi_index, Length: 175, dtype: float64

# %%
gdp17 = year_2017['gdp']

gdp17
# Out:
# 19        576.0
# 40       4250.0
# 61       4190.0
# 82       3790.0
# 103     13600.0
#          ...
# 3589     2850.0
# 3610     2320.0
# 3631     1310.0
# 3652     1350.0
# 3673     1480.0
# Name: gdp, Length: 175, dtype: float64

# %%
hdi16 = year_2016['hdi_index']

hdi16
# Out:
# 18      0.502
# 39      0.788
# 60      0.743
# 81      0.578
# 102     0.839
#         ...
# 3588    0.598
# 3609    0.693
# 3630    0.474
# 3651    0.571
# 3672    0.558
# Name: hdi_index, Length: 175, dtype: float64

# %%
gdp16 = year_2016['gdp']

gdp16
# Out:
# 18        575.0
# 39       4090.0
# 60       4220.0
# 81       3920.0
# 102     13400.0
#          ...
# 3588     2750.0
# 3609     2190.0
# 3630     1420.0
# 3651     1350.0
# 3672     1430.0
# Name: gdp, Length: 175, dtype: float64

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 23)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 10)

# %%
fig = plt.figure(figsize = (8,6))
gs = GridSpec(4, 4)

ax1 = fig.add_subplot(gs[1:4, 0:3], facecolor = '#f7f9f2')
ax2 = fig.add_subplot(gs[0,0:3], facecolor = '#f7f9f2')
ax3 = fig.add_subplot(gs[1:4, 3], facecolor = '#f7f9f2')



ax1.scatter(life16, hdi16, color = '#941d26', label = 2016, s = 20)
ax1.scatter(life17, hdi17, color = '#406c35', label = 2017, s = 20)
ax1.scatter(life18, hdi18, color = '#dab678', label = 2018, s = 20)
ax1.legend(prop = font2)


ax1.grid(linestyle = 'dashed')
ax1.set_xlabel('Life Expectancy', fontproperties = font2)
ax1.set_ylabel('Human Development Index', fontproperties = font2)


fig.tight_layout(pad=1)

ax2.hist([life16, life17, life18], orientation = 'vertical', bins = 40, histtype = 'bar', color = ['#941d26','#406c35','#dab678'])
ax2.set_ylabel('Count', fontproperties = font2)
ax2.grid(linestyle = 'dashed', axis = 'y')

ax3.hist(hdi16, orientation = 'horizontal', bins = 40, stacked = True, histtype = 'bar', color = '#941d26', alpha = 0.5, edgecolor = 'black')
ax3.hist(hdi17, orientation = 'horizontal', bins = 40, stacked = True, histtype = 'bar', color = '#406c35', alpha = 0.5, edgecolor = 'black')
ax3.hist(hdi18, orientation = 'horizontal', bins = 40, stacked = True, histtype = 'bar', color = '#dab678', alpha = 0.5, edgecolor = 'black')
ax3.set_xlabel('Count', fontproperties = font2)
ax3.grid(linestyle = 'dashed', axis = 'x')

plt.show()
