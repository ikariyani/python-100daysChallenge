# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
intro = 1
sql = 3
python = 8
numpy = 9
pandas = 8
matplotlib = 13

# %%
belajar = np.array([1,3,8,9,8,13])

belajar
# Out:
# array([ 1,  3,  8,  9,  8, 13])

# %%
materi = np.array(['Intro', 'SQL', 'Python', 'NumPy', 'Pandas', 'Matplotlib'])

materi
# Out:
# array(['Intro', 'SQL', 'Python', 'NumPy', 'Pandas', 'Matplotlib'],
#       dtype='<U10')

# %%
plt.barh(materi[0], belajar[0])
plt.barh(materi[1], belajar[1], left = belajar[0])
plt.barh(materi[2], belajar[2], left = belajar[0] + belajar[1])
plt.barh(materi[3], belajar[3], left = belajar[0] + belajar[1] + belajar [2])
plt.barh(materi[4], belajar[4], left = belajar[0] + belajar[1] + belajar [2] + belajar[3])
plt.barh(materi[5], belajar[5], left = belajar[0] + belajar[1] + belajar [2] + belajar[3] + belajar [4])


plt.show()

# %%
kiri = []

for idx, data in enumerate (materi) :
    if idx == 0 :
        pass
    elif idx != 0 :
        kiri.append(belajar[idx-1])
    plt.barh(materi[idx], belajar[idx], left = np.sum(kiri))
        

plt.show()

# %%
kiri = []

for idx, data in enumerate (materi) :
    plt.barh(materi[idx], belajar[idx], left = np.sum(kiri))
    kiri.append(belajar[idx])
        

plt.show()
