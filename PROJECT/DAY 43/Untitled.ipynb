# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "8 Edible Oils.csv"

df = pd.read_csv(file)

df
# Out:
#         Month Coconut Oil Price Coconut Oil Price Change Olive Oil Price  \
# 0    Aug 1992            494.00                        -        3,490.25
# 1    Sep 1992            501.00                    1.42%        3,342.78
# 2    Oct 1992            493.00                   -1.60%        2,986.24
# 3    Nov 1992            496.00                    0.61%        2,747.90
# 4    Dec 1992            461.00                   -7.06%        2,793.15
# ..        ...               ...                      ...             ...
# 355  Mar 2022          2,230.22                    3.83%        4,398.57
# 356  Apr 2022          2,094.61                   -6.08%        4,284.61
# 357  May 2022          1,813.33                  -13.43%        4,098.48
# 358  Jun 2022          1,700.50                   -6.22%        4,030.65
# 359  Jul 2022          1,540.53                   -9.41%        4,065.02
#
#     Olive Oil Price Change Palm Kernel Oil Price Palm Kernel Oil Price Change  \
# ...

# %%
ok = df[330:359][['Month', 'Coconut Oil Price', 'Olive Oil Price', 'Palm Oil Price', 'Peanut Oil Price']]

ok
# Out:
#         Month Coconut Oil Price Olive Oil Price Palm Oil Price  \
# 330  Feb 2020            844.12        2,737.94         728.81
# 331  Mar 2020            837.72        2,796.26         636.25
# 332  Apr 2020            834.51        2,775.09         608.88
# 333  May 2020            832.33        2,754.38         576.56
# 334  Jun 2020            916.38        2,842.24         656.49
# 335  Jul 2020            888.31        2,868.08         694.16
# 336  Aug 2020            981.30        2,995.76         760.30
# 337  Sep 2020          1,034.18        3,094.02         796.22
# 338  Oct 2020          1,118.36        3,285.64         819.27
# 339  Nov 2020          1,368.95        1,389.97         917.81
# 340  Dec 2020          1,464.96        1,313.41       1,016.37
# 341  Jan 2021          1,463.07        3,468.29         990.27
# 342  Feb 2021          1,444.50        3,898.12       1,019.86
# 343  Mar 2021          1,540.65        3,933.92       1,030.48
# ...

# %%
oil = df[['Coconut Oil Price', 'Olive Oil Price', 'Palm Oil Price', 'Peanut Oil Price']]

oil
# Out:
#     Coconut Oil Price Olive Oil Price Palm Oil Price Peanut Oil Price
# 0              494.00        3,490.25         382.00           600.00
# 1              501.00        3,342.78         391.00           562.00
# 2              493.00        2,986.24         396.00           565.00
# 3              496.00        2,747.90         413.00           575.00
# 4              461.00        2,793.15         401.00           622.00
# ..                ...             ...            ...              ...
# 355          2,230.22        4,398.57       1,776.96         2,153.15
# 356          2,094.61        4,284.61       1,682.74         2,145.25
# 357          1,813.33        4,098.48       1,716.92         2,146.29
# 358          1,700.50        4,030.65       1,501.10         2,146.19
# 359          1,540.53        4,065.02       1,056.64         2,146.19
#
# [360 rows x 4 columns]

# %%
sawit = ok['Palm Oil Price']

sawit = sawit.to_numpy()

sawit
# Out:
# array(['728.81', '636.25', '608.88', '576.56', '656.49', '694.16',
#        '760.30', '796.22', '819.27', '917.81', '1,016.37', '990.27',
#        '1,019.86', '1,030.48', '1,078.05', '1,136.46', '1,004.42',
#        '1,062.99', '1,141.82', '1,181.38', '1,310.25', '1,340.65',
#        '1,270.29', '1,344.79', '1,522.36', '1,776.96', '1,682.74',
#        '1,716.92', '1,501.10'], dtype=object)

# %%
kelapa = ok['Coconut Oil Price']

kelapa = kelapa.to_numpy()

kelapa
# Out:
# array(['844.12', '837.72', '834.51', '832.33', '916.38', '888.31',
#        '981.30', '1,034.18', '1,118.36', '1,368.95', '1,464.96',
#        '1,463.07', '1,444.50', '1,540.65', '1,659.64', '1,715.24',
#        '1,670.68', '1,584.09', '1,493.64', '1,485.00', '1,922.86',
#        '1,960.68', '1,695.71', '2,016.14', '2,147.89', '2,230.22',
#        '2,094.61', '1,813.33', '1,700.50'], dtype=object)

# %%
date = ok['Month']

date = date.to_numpy()

date
# Out:
# array(['Feb 2020', 'Mar 2020', 'Apr 2020', 'May 2020', 'Jun 2020',
#        'Jul 2020', 'Aug 2020', 'Sep 2020', 'Oct 2020', 'Nov 2020',
#        'Dec 2020', 'Jan 2021', 'Feb 2021', 'Mar 2021', 'Apr 2021',
#        'May 2021', 'Jun 2021', 'Jul 2021', 'Aug 2021', 'Sep 2021',
#        'Oct 2021', 'Nov 2021', 'Dec 2021', 'Jan 2022', 'Feb 2022',
#        'Mar 2022', 'Apr 2022', 'May 2022', 'Jun 2022'], dtype=object)

# %%
end = cases['Total Cases']

end
# Out:
# 2              2
# 5              2
# 9              2
# 13             2
# 18             4
#           ...
# 31690    6394340
# 31725    6397236
# 31760    6400035
# 31794    6402686
# 31821    6405044
# Name: Total Cases, Length: 929, dtype: int64

# %%
plt.figure(figsize = (10, 10))

plt.plot(date, kelapa, color = 'red', alpha = 0.5)
plt.plot(date,sawit, color = 'blue', alpha = 0.5)


plt.show()

# %%
file = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 43\Indonesia_Inflation.csv"

df = pd.read_csv(file)

df
# Out:
#              Month Inflation
# 0           Apr-20     2.67%
# 1       Maret 2020     2.96%
# 2    Februari 2020     2.98%
# 3     Januari 2020     2.68%
# 4    Desember 2019     2.72%
# ..             ...       ...
# 204         Apr-03     7.62%
# 205     Maret 2003     7.17%
# 206  Februari 2003     7.60%
# 207   Januari 2003     8.68%
# 208  Desember 2002        0%
#
# [209 rows x 2 columns]

# %%
coba = df[0:25]

coba
# Out:
#             Month Inflation
# 0          Apr-20     2.67%
# 1      Maret 2020     2.96%
# 2   Februari 2020     2.98%
# 3    Januari 2020     2.68%
# 4   Desember 2019     2.72%
# 5          Nov-19        3%
# 6    Oktober 2019     3.13%
# 7          Sep-19     3.39%
# 8    Agustus 2019     3.49%
# 9       Juli 2019     3.32%
# 10      Juni 2019     3.28%
# 11       Mei 2019     3.32%
# 12         Apr-19     2.83%
# 13     Maret 2019     2.48%
# 14  Februari 2019     2.57%
# 15   Januari 2019     2.82%
# 16  Desember 2018     3.13%
# 17         Nov-18     3.23%
# 18   Oktober 2018     3.16%
# 19         Sep-18     2.88%
# 20   Agustus 2018     3.20%
# 21      Juli 2018     3.18%
# 22      Juni 2018     3.12%
# 23       Mei 2018     3.23%
# 24         Apr-18     3.41%

# %%
date = coba['Month']

date
# Out:
# 0            Apr-20
# 1        Maret 2020
# 2     Februari 2020
# 3      Januari 2020
# 4     Desember 2019
# 5            Nov-19
# 6      Oktober 2019
# 7            Sep-19
# 8      Agustus 2019
# 9         Juli 2019
# 10        Juni 2019
# 11         Mei 2019
# 12           Apr-19
# 13       Maret 2019
# 14    Februari 2019
# 15     Januari 2019
# 16    Desember 2018
# 17           Nov-18
# 18     Oktober 2018
# 19           Sep-18
# 20     Agustus 2018
# 21        Juli 2018
# 22        Juni 2018
# 23         Mei 2018
# 24           Apr-18
# Name: Month, dtype: object

# %%
inflasi = coba['Inflation']

inflasi
# Out:
# 0     2.67%
# 1     2.96%
# 2     2.98%
# 3     2.68%
# 4     2.72%
# 5        3%
# 6     3.13%
# 7     3.39%
# 8     3.49%
# 9     3.32%
# 10    3.28%
# 11    3.32%
# 12    2.83%
# 13    2.48%
# 14    2.57%
# 15    2.82%
# 16    3.13%
# 17    3.23%
# 18    3.16%
# 19    2.88%
# 20    3.20%
# 21    3.18%
# 22    3.12%
# 23    3.23%
# 24    3.41%
# Name: Inflation, dtype: object

# %%
plt.vlines(date, inflasi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 plt.vlines(date, inflasi)
#
# TypeError: vlines() missing 1 required positional argument: 'ymax'
