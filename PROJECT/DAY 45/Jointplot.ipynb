# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('death-rates-from-air-pollution.csv')

df
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df_negara = df.loc[(df['Entity'] == 'Indonesia') |
                   (df['Entity'] == 'Malaysia') |
                   (df['Entity'] == 'Thailand') |
                   (df['Entity'] == 'Philippines') |
                    (df['Entity'] == 'Philippines')]

df_negara
# Out:
#          Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 2688  Indonesia  IDN  1990                                  108.258041
# 2689  Indonesia  IDN  1991                                  105.068758
# 2690  Indonesia  IDN  1992                                  101.865004
# 2691  Indonesia  IDN  1993                                   99.076420
# 2692  Indonesia  IDN  1994                                   96.168075
# ...         ...  ...   ...                                         ...
# 5735   Thailand  THA  2013                                   35.909944
# 5736   Thailand  THA  2014                                   34.651111
# 5737   Thailand  THA  2015                                   33.328411
# 5738   Thailand  THA  2016                                   33.060406
# 5739   Thailand  THA  2017                                   32.813423
#
#       Indoor air pollution (deaths per 100,000)  \
# 2688                                  88.257244
# ...

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)")

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", hue='Entity')

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", hue='Entity', kind='kde')

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", kind='reg')

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", kind='hist')

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", kind='hex')

plt.show()

# %%
sns.jointplot(data=df_negara, x="Outdoor particulate matter (deaths per 100,000)", 
              y="Indoor air pollution (deaths per 100,000)", kind='hist')

plt.show()
