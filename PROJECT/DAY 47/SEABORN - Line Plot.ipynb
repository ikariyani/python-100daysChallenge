# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://user-images.githubusercontent.com/315810/92255284-156f1180-eea0-11ea-9d2d-be8262670e8c.png" style="height:100px"> |
# | --- | --- |
#
#
#
# # SEABORN - Line Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file = "keparahan.csv"

df = pd.read_csv(file, sep=';')

df
# Out:
#                                        ﻿nama_variabel nama_variabel_turunan  \
# 0   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 1   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 2   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 3   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 4   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 5   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 6   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 7   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 8   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 9   Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# 10  Indeks Keparahan Kemiskinan (P2) Menurut Kabup...             Tidak Ada
# ...

# %%
file2 = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 46\kedalaman kemiskinan.csv"

df2 = pd.read_csv(file2, sep=';')

df2
# Out:
#                                        ﻿nama_variabel nama_variabel_turunan  \
# 0   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 1   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 2   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 3   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 4   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 5   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 6   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 7   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 8   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 9   Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# 10  Indeks Kedalaman Kemiskinan (P1) Menurut Kabup...             Tidak Ada
# ...

# %%
df = df[['nama_tahun', 'data_content', 'nama_item_vertical_variabel']]

df
# Out:
#     nama_tahun  data_content nama_item_vertical_variabel
# 0         2021      0.380000                  JAWA BARAT
# 1         2021      0.450000                 JAWA TENGAH
# 2         2021      0.430000                  JAWA TIMUR
# 3         2020      0.230000                  JAWA BARAT
# 4         2020      0.340000                 JAWA TENGAH
# 5         2020      0.430000                  JAWA TIMUR
# 6         2019      0.240743                  JAWA BARAT
# 7         2019      0.299092                 JAWA TENGAH
# 8         2019      0.451807                  JAWA TIMUR
# 9         2018      0.330000                  JAWA BARAT
# 10        2018      0.450000                 JAWA TENGAH
# 11        2018      0.500000                  JAWA TIMUR
# 12        2017      0.370000                  JAWA BARAT
# 13        2017      0.570000                 JAWA TENGAH
# 14        2017      0.450000                  JAWA TIMUR
# ...

# %%
df2 = df2[['nama_tahun', 'data_content', 'nama_item_vertical_variabel']]

df2
# Out:
#     nama_tahun  data_content nama_item_vertical_variabel
# 0         2021      1.470000                  JAWA BARAT
# 1         2021      1.910000                 JAWA TENGAH
# 2         2021      1.840000                  JAWA TIMUR
# 3         2020      1.130000                  JAWA BARAT
# 4         2020      1.720000                 JAWA TENGAH
# 5         2020      1.820000                  JAWA TIMUR
# 6         2019      1.094820                  JAWA BARAT
# 7         2019      1.527226                 JAWA TENGAH
# 8         2019      1.799355                  JAWA TIMUR
# 9         2018      1.320000                  JAWA BARAT
# 10        2018      1.850000                 JAWA TENGAH
# 11        2018      1.940000                  JAWA TIMUR
# 12        2017      1.450000                  JAWA BARAT
# 13        2017      2.210000                 JAWA TENGAH
# 14        2017      1.870000                  JAWA TIMUR
# ...

# %%
# tabel1 = df.set_index('nama_item_vertical_variabel')

# tabel1

# %%
tabel1 = df.rename(columns={'nama_tahun' : 'tahun1', 'data_content' : 'keparahan', 'nama_item_vertical_variabel' : 'provinsi1'})

tabel1
# Out:
#     tahun1  keparahan    provinsi1
# 0     2021   0.380000   JAWA BARAT
# 1     2021   0.450000  JAWA TENGAH
# 2     2021   0.430000   JAWA TIMUR
# 3     2020   0.230000   JAWA BARAT
# 4     2020   0.340000  JAWA TENGAH
# 5     2020   0.430000   JAWA TIMUR
# 6     2019   0.240743   JAWA BARAT
# 7     2019   0.299092  JAWA TENGAH
# 8     2019   0.451807   JAWA TIMUR
# 9     2018   0.330000   JAWA BARAT
# 10    2018   0.450000  JAWA TENGAH
# 11    2018   0.500000   JAWA TIMUR
# 12    2017   0.370000   JAWA BARAT
# 13    2017   0.570000  JAWA TENGAH
# 14    2017   0.450000   JAWA TIMUR
# 15    2016   0.370000   JAWA BARAT
# 16    2016   0.630000  JAWA TENGAH
# 17    2016   0.470000   JAWA TIMUR
# 18    2015   0.430000   JAWA BARAT
# 19    2015   0.650000  JAWA TENGAH
# 20    2015   0.520000   JAWA TIMUR
# 21    2014   0.330000   JAWA BARAT
# 22    2014   0.510000  JAWA TENGAH
# 23    2014   0.450000   JAWA TIMUR
# 24    2013   0.440000   JAWA BARAT
# 25    2013   0.590000  JAWA TENGAH
# ...

# %%
# tabel2 = df2.set_index('nama_item_vertical_variabel')

# tabel2

# %%
tabel2 = df2.rename(columns={'nama_tahun' : 'tahun2', 'data_content' : 'kedalaman', 'nama_item_vertical_variabel' : 'provinsi2'})

tabel2
# Out:
#     tahun2  kedalaman    provinsi2
# 0     2021   1.470000   JAWA BARAT
# 1     2021   1.910000  JAWA TENGAH
# 2     2021   1.840000   JAWA TIMUR
# 3     2020   1.130000   JAWA BARAT
# 4     2020   1.720000  JAWA TENGAH
# 5     2020   1.820000   JAWA TIMUR
# 6     2019   1.094820   JAWA BARAT
# 7     2019   1.527226  JAWA TENGAH
# 8     2019   1.799355   JAWA TIMUR
# 9     2018   1.320000   JAWA BARAT
# 10    2018   1.850000  JAWA TENGAH
# 11    2018   1.940000   JAWA TIMUR
# 12    2017   1.450000   JAWA BARAT
# 13    2017   2.210000  JAWA TENGAH
# 14    2017   1.870000   JAWA TIMUR
# 15    2016   1.490000   JAWA BARAT
# 16    2016   2.370000  JAWA TENGAH
# 17    2016   1.980000   JAWA TIMUR
# 18    2015   1.630000   JAWA BARAT
# 19    2015   2.440000  JAWA TENGAH
# 20    2015   2.060000   JAWA TIMUR
# 21    2014   1.390000   JAWA BARAT
# 22    2014   2.090000  JAWA TENGAH
# 23    2014   1.860000   JAWA TIMUR
# 24    2013   1.650000   JAWA BARAT
# 25    2013   2.370000  JAWA TENGAH
# ...

# %%
join = tabel1.join(tabel2)

join
# Out:
#     tahun1  keparahan    provinsi1  tahun2  kedalaman    provinsi2
# 0     2021   0.380000   JAWA BARAT    2021   1.470000   JAWA BARAT
# 1     2021   0.450000  JAWA TENGAH    2021   1.910000  JAWA TENGAH
# 2     2021   0.430000   JAWA TIMUR    2021   1.840000   JAWA TIMUR
# 3     2020   0.230000   JAWA BARAT    2020   1.130000   JAWA BARAT
# 4     2020   0.340000  JAWA TENGAH    2020   1.720000  JAWA TENGAH
# 5     2020   0.430000   JAWA TIMUR    2020   1.820000   JAWA TIMUR
# 6     2019   0.240743   JAWA BARAT    2019   1.094820   JAWA BARAT
# 7     2019   0.299092  JAWA TENGAH    2019   1.527226  JAWA TENGAH
# 8     2019   0.451807   JAWA TIMUR    2019   1.799355   JAWA TIMUR
# 9     2018   0.330000   JAWA BARAT    2018   1.320000   JAWA BARAT
# 10    2018   0.450000  JAWA TENGAH    2018   1.850000  JAWA TENGAH
# 11    2018   0.500000   JAWA TIMUR    2018   1.940000   JAWA TIMUR
# 12    2017   0.370000   JAWA BARAT    2017   1.450000   JAWA BARAT
# ...

# %%
tahun = np.arange(2004, 2022, 1)

tahun
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
join.loc[join['provinsi1'] == 'JAWA BARAT']
# Out:
#     tahun1  keparahan   provinsi1  tahun2  kedalaman   provinsi2
# 0     2021   0.380000  JAWA BARAT    2021    1.47000  JAWA BARAT
# 3     2020   0.230000  JAWA BARAT    2020    1.13000  JAWA BARAT
# 6     2019   0.240743  JAWA BARAT    2019    1.09482  JAWA BARAT
# 9     2018   0.330000  JAWA BARAT    2018    1.32000  JAWA BARAT
# 12    2017   0.370000  JAWA BARAT    2017    1.45000  JAWA BARAT
# 15    2016   0.370000  JAWA BARAT    2016    1.49000  JAWA BARAT
# 18    2015   0.430000  JAWA BARAT    2015    1.63000  JAWA BARAT
# 21    2014   0.330000  JAWA BARAT    2014    1.39000  JAWA BARAT
# 24    2013   0.440000  JAWA BARAT    2013    1.65000  JAWA BARAT
# 27    2012   0.420000  JAWA BARAT    2012    1.62000  JAWA BARAT
# 30    2011   0.430000  JAWA BARAT    2011    1.72000  JAWA BARAT
# 33    2010   0.420000  JAWA BARAT    2010    1.68000  JAWA BARAT
# 36    2009   0.700000  JAWA BARAT    2009    2.09000  JAWA BARAT
# ...

# %%
fig, ax = plt.subplots(figsize = (10, 6))


sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA BARAT'], x = join['tahun1'], y = join['kedalaman'], palette = 'red', alpha = 0.8)
sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA TENGAH'], x = join['tahun1'], y = join['kedalaman'], palette = 'green', alpha = 0.5)
sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA TIMUR'], x = join['tahun1'], y = join['kedalaman'], palette = 'blue', alpha = 0.2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8768\3641409745.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA BARAT'], x = join['tahun1'], y = join['kedalaman'], palette = 'red', alpha = 0.8)
# C:\Users\HP\AppData\Local\Temp\ipykernel_8768\3641409745.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA TENGAH'], x = join['tahun1'], y = join['kedalaman'], palette = 'green', alpha = 0.5)
# C:\Users\HP\AppData\Local\Temp\ipykernel_8768\3641409745.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(ax = ax, data = join.loc[join['provinsi1'] == 'JAWA TIMUR'], x = join['tahun1'], y = join['kedalaman'], palette = 'blue', alpha = 0.2)
# <AxesSubplot: xlabel='tahun1', ylabel='kedalaman'>

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 20)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 10)

# %%
fig, ax = plt.subplots(figsize = (10, 6))

x = join['tahun1']
y = join['kedalaman']

sns.lineplot(ax = ax, data = join, x = x, y = y, color = '#235347', zorder = 3)
ax.plot(x.loc[join['provinsi1'] == 'JAWA BARAT'], y.loc[join['provinsi1'] == 'JAWA BARAT'], label = 'JAWA BARAT', color = '#1c4f6b',linestyle = 'dashed', marker = 'o', zorder = 3)
ax.plot(x.loc[join['provinsi1'] == 'JAWA TENGAH'], y.loc[join['provinsi1'] == 'JAWA TENGAH'], label = 'JAWA TENGAH', color = '#4f0205',linestyle = 'dashed', marker = 'o', zorder = 3)
ax.plot(x.loc[join['provinsi1'] == 'JAWA TIMUR'], y.loc[join['provinsi1'] == 'JAWA TIMUR'], label = 'JAWA TIMUR', color = '#ffbe00',linestyle = 'dashed', marker = 'o', zorder = 3)

plt.title('Persebaran Indeks Kedalaman Kemiskinan\ndan Indeks Keparahan Kemiskinan', pad = 20, fontproperties = font1)
plt.xlabel('Indeks Keparahan Kemiskinan', fontproperties = font2)
plt.ylabel('Indeks Kedalaman Kemiskinan', fontproperties = font2)

plt.xticks(np.arange(2004, 2021, 2),fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend()
plt.grid(axis = 'y', linestyle = 'dashed', zorder = 0)

plt.show()
