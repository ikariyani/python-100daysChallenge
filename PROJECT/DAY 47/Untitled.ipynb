# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file = "IDI.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#                                        ﻿nama_variabel nama_variabel_turunan  \
# 0   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 1   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 2   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 3   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 4   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 5   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 6   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 7   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 8   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 9   Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# 10  Indeks Demokrasi Indonesia (IDI) Menurut Provinsi             Tidak Ada
# ...

# %%
idi = df[['nama_tahun', 'data_content', 'nama_item_vertical_variabel']]

idi
# Out:
#     nama_tahun  data_content nama_item_vertical_variabel
# 0         2020     81.090000            KALIMANTAN BARAT
# 1         2020     74.910000           KALIMANTAN TENGAH
# 2         2020     74.050000          KALIMANTAN SELATAN
# 3         2020     81.990000            KALIMANTAN TIMUR
# 4         2020     78.240000            KALIMANTAN UTARA
# 5         2019     77.660000            KALIMANTAN BARAT
# 6         2019     81.160000           KALIMANTAN TENGAH
# 7         2019     79.470000          KALIMANTAN SELATAN
# 8         2019     77.670000            KALIMANTAN TIMUR
# 9         2019     83.450000            KALIMANTAN UTARA
# 10        2018     76.135989            KALIMANTAN BARAT
# 11        2018     71.265328           KALIMANTAN TENGAH
# 12        2018     79.916239          KALIMANTAN SELATAN
# 13        2018     73.881940            KALIMANTAN TIMUR
# 14        2018     81.070830            KALIMANTAN UTARA
# ...

# %%
sns.set_theme(style="whitegrid")

sns.lineplot(data = idi, x= 'nama_tahun', y = 'data_content', hue = 'nama_item_vertical_variabel', kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [54], line 3
#       1 sns.set_theme(style="whitegrid")
# ----> 3 sns.lineplot(data = idi, x= 'nama_tahun', y = 'data_content', hue = 'nama_item_vertical_variabel', kind = 'scatter')
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# ...

# %%
file2 = "kejahatan.csv"

df2 = pd.read_csv(file2,sep = ';')

df2
# Out:
#                                     ﻿nama_variabel nama_variabel_turunan  \
# 0   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 1   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 2   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 3   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 4   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 5   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 6   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 7   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 8   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 9   Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 10  Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# 11  Jumlah Tindak Pidana Menurut Kepolisian Daerah             Tidak Ada
# ...

# %%
kejahatan = df2[['nama_tahun', 'data_content', 'nama_item_vertical_variabel']]

kejahatan
# Out:
#     nama_tahun  data_content nama_item_vertical_variabel
# 0         2020          5350                      MALUKU
# 1         2020           850                MALUKU UTARA
# 2         2020          3162                 PAPUA BARAT
# 3         2020          6962                       PAPUA
# 4         2019          3495                      MALUKU
# 5         2019           718                MALUKU UTARA
# 6         2019          2972                 PAPUA BARAT
# 7         2019          6994                       PAPUA
# 8         2018          2751                      MALUKU
# 9         2018           722                MALUKU UTARA
# 10        2018          3475                 PAPUA BARAT
# 11        2018          7311                       PAPUA
# 12        2017          3086                      MALUKU
# 13        2017           789                MALUKU UTARA
# 14        2017          2284                 PAPUA BARAT
# ...

# %%
sns.lineplot(data = kejahatan, x= 'nama_tahun', y = 'data_content', hue = 'nama_item_vertical_variabel', style = 'nama_item_vertical_variabel')

plt.show()

# %%
sns.relplot(data = kejahatan, x= 'nama_tahun', y = 'data_content',  hue = 'nama_item_vertical_variabel', kind = 'line', style = 'nama_item_vertical_variabel')

plt.show()

# %%
file4 = "wisata.csv"

df4 = pd.read_csv(file4, sep = ';')

df4
# Out:
#                                        ﻿nama_variabel nama_variabel_turunan  \
# 0   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 1   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 2   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 3   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 4   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 5   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 6   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 7   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 8   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 9   Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# 10  Tingkat Penghunian Kamar pada Hotel Bintang Me...             Tidak Ada
# ...

# %%
jateng = df4[['nama_tahun', 'data_content', 'nama_item_vertical_variabel']]

jateng
# Out:
#     nama_tahun  data_content nama_item_vertical_variabel
# 0         2021         31.98                 JAWA TENGAH
# 1         2020         29.31                 JAWA TENGAH
# 2         2019         47.46                 JAWA TENGAH
# 3         2018         45.49                 JAWA TENGAH
# 4         2017         49.17                 JAWA TENGAH
# 5         2016         46.76                 JAWA TENGAH
# 6         2015         46.13                 JAWA TENGAH
# 7         2014         46.89                 JAWA TENGAH
# 8         2013         49.92                 JAWA TENGAH
# 9         2012         48.58                 JAWA TENGAH
# 10        2011         44.22                 JAWA TENGAH
# 11        2010         41.01                 JAWA TENGAH
# 12        2009         38.12                 JAWA TENGAH
# 13        2008         37.79                 JAWA TENGAH
# 14        2007         37.60                 JAWA TENGAH
# ...

# %%
sns.lineplot(data = jateng, x = 'nama_tahun', y = 'data_content')

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))

sns.set_theme(style="darkgrid")

sns.lineplot(ax = ax, data = jateng, x = jateng['nama_tahun'], y = jateng['data_content'], palette = 'red', alpha = 0.8, errorbar = 'sd')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2696\2259940102.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(ax = ax, data = jateng, x = jateng['nama_tahun'], y = jateng['data_content'], palette = 'red', alpha = 0.8, errorbar = 'sd')
# <AxesSubplot: xlabel='nama_tahun', ylabel='data_content'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
file5 = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 47\demokrasi.csv"

df5 = pd.read_csv(file5, sep = ';')

df5
# Out:
#                                        ﻿nama_variabel  \
# 0   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 1   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 2   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 3   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 4   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 5   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 6   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 7   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 8   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 9   Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 10  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 11  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 12  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 13  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 14  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# 15  Indeks Demokrasi Indonesia (IDI) Menurut Aspek...
# ...

# %%
sns.lineplot(x="nama_tahun", y="data_content", data=df5)
plt.scatter(df5.loc['nama_tahun'], df5.loc[df5['data_content'] == , s = 10)



plt.show()
