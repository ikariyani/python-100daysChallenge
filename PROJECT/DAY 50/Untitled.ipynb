# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 50\WorldHappiness_Corruption_2015_2020.csv"

df = pd.read_csv(file)

df
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %%
data = df.loc[(df['Year'] == 2020) |
              (df['Year'] == 2019) |
              (df['Year'] == 2018) |
              (df['Year'] == 2017) |
              (df['Year'] == 2016) |
              (df['Year'] == 2015)]

data
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# ...

# %%
sns.jointplot(data = data, y = data['gdp_per_capita'], x = data['happiness_score'], kind = 'hex')

# %%
plt.violinplot([penghasilan['income'], penghasilan['pengeluaran'],penghasilan['pengeluaran_makan']], showmedians = True)

# plt.legend(['A', 'B', 'C'])

label = ['Penghasilan', 'Pengeluaran', 'Pengeluaran Makan']

plt.xticks([1,2,3], labels = label)

plt.show()

# %%
df.loc[df['(B3) GENDER'] == 'Female', 'gender'] = 1
df.loc[df['(B3) GENDER'] == 'Male', 'gender'] = 0
