# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://user-images.githubusercontent.com/315810/92255284-156f1180-eea0-11ea-9d2d-be8262670e8c.png" style="height:100px"> |
# | --- | --- |
#
#
#
# # SEABORN - Violin Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 51\WorldHappiness_Corruption_2015_2020.csv"

df = pd.read_csv(file)

df
# Out:
#          Country  happiness_score  gdp_per_capita    family    health  \
# 0         Norway           7.5370        1.616463  1.533524  0.796667
# 1        Denmark           7.5220        1.482383  1.551122  0.792566
# 2        Iceland           7.5040        1.480633  1.610574  0.833552
# 3    Switzerland           7.4940        1.564980  1.516912  0.858131
# 4        Finland           7.4690        1.443572  1.540247  0.809158
# ..           ...              ...             ...       ...       ...
# 787     Botswana           3.4789        0.997549  0.000000  0.494102
# 788     Tanzania           3.4762        0.457163  0.000000  0.442678
# 789       Rwanda           3.3123        0.343243  0.000000  0.572383
# 790     Zimbabwe           3.2992        0.425564  0.000000  0.375038
# 791  Afghanistan           2.5669        0.300706  0.000000  0.266052
#
#       freedom  generosity  government_trust  dystopia_residual continent  \
# 0    0.635423    0.362012          0.315964           2.277027    Europe
# 1    0.626007    0.355280          0.400770           2.313707    Europe
# 2    0.627163    0.475540          0.153527           2.322715    Europe
# 3    0.620071    0.290549          0.367007           2.276716    Europe
# 4    0.617951    0.245483          0.382612           2.430182    Europe
# ..        ...         ...               ...                ...       ...
# 787  0.509089    0.033407          0.101786           0.257241    Africa
# 788  0.509343    0.271541          0.203881           0.718963    Africa
# 789  0.604088    0.235705          0.485542           0.548445    Africa
# 790  0.377405    0.151349          0.080929           0.841031    Africa
# 791  0.000000    0.135235          0.001226           1.507236      Asia
#
#      Year  social_support  cpi_score
# 0    2015        0.000000         88
# 1    2015        0.000000         91
# 2    2015        0.000000         79
# 3    2015        0.000000         86
# 4    2015        0.000000         90
# ..    ...             ...        ...
# 787  2020        1.085695         60
# 788  2020        0.872675         38
# 789  2020        0.522876         54
# 790  2020        1.047835         24
# 791  2020        0.356434         19
#
# [792 rows x 13 columns]

# %%
data = df['gdp_per_capita'], df['family'], df['health'], df['freedom'], df['generosity'], df['government_trust'], df['dystopia_residual'], df['social_support']

data
# Out:
# (0      1.616463
#  1      1.482383
#  2      1.480633
#  3      1.564980
#  4      1.443572
#           ...
#  787    0.997549
#  788    0.457163
#  789    0.343243
#  790    0.425564
#  791    0.300706
#  Name: gdp_per_capita, Length: 792, dtype: float64,
#  0      1.533524
#  1      1.551122
#  2      1.610574
#  3      1.516912
#  4      1.540247
#           ...
#  787    0.000000
#  788    0.000000
#  789    0.000000
#  790    0.000000
#  791    0.000000
#  Name: family, Length: 792, dtype: float64,
#  0      0.796667
#  1      0.792566
#  2      0.833552
#  3      0.858131
#  4      0.809158
#           ...
#  787    0.494102
#  788    0.442678
#  789    0.572383
#  790    0.375038
#  791    0.266052
#  Name: health, Length: 792, dtype: float64,
#  0      0.635423
#  1      0.626007
#  2      0.627163
#  3      0.620071
#  4      0.617951
#           ...
#  787    0.509089
#  788    0.509343
#  789    0.604088
#  790    0.377405
#  791    0.000000
#  Name: freedom, Length: 792, dtype: float64,
#  0      0.362012
#  1      0.355280
#  2      0.475540
#  3      0.290549
#  4      0.245483
#           ...
#  787    0.033407
#  788    0.271541
#  789    0.235705
#  790    0.151349
#  791    0.135235
#  Name: generosity, Length: 792, dtype: float64,
#  0      0.315964
#  1      0.400770
#  2      0.153527
#  3      0.367007
#  4      0.382612
#           ...
#  787    0.101786
#  788    0.203881
#  789    0.485542
#  790    0.080929
#  791    0.001226
#  Name: government_trust, Length: 792, dtype: float64,
#  0      2.277027
#  1      2.313707
#  2      2.322715
#  3      2.276716
#  4      2.430182
#           ...
#  787    0.257241
#  788    0.718963
#  789    0.548445
#  790    0.841031
#  791    1.507236
#  Name: dystopia_residual, Length: 792, dtype: float64,
#  0      0.000000
#  1      0.000000
#  2      0.000000
#  3      0.000000
#  4      0.000000
#           ...
#  787    1.085695
#  788    0.872675
#  789    0.522876
#  790    1.047835
#  791    0.356434
#  Name: social_support, Length: 792, dtype: float64)

# %%
import matplotlib.font_manager as fm

# %%
path = "Amelaryas.otf"
path2 = "AUBREY1__.TTF"
path3 = "Caver Pitalsal.otf"
path4 = "Galgony.ttf"


font1 = fm.FontProperties(fname = path, size = 10)
font2 = fm.FontProperties(fname = path4, size = 13)
font3 = fm.FontProperties(fname = path3, size = 30)
font4 = fm.FontProperties(fname = path4, size = 25)
font5 = fm.FontProperties(fname = path4, size = 13)
font6 = fm.FontProperties(fname = path2, size = 10)

# %%
fig, ax = plt.subplots(figsize = (15, 6))
label = ['GDP per Capita', 'Family', 'Health', 'Freedom', 'Generosity', 'Government Trust', 'Dystopia Residual', 'Social Support']

sns.violinplot(ax = ax, data = data, palette = 'crest')

plt.title('Kontribusi Indikator Penentu Indeks Kebahagiaan', fontproperties = font4)
plt.xticks([0,1,2,3,4,5,6,7], labels = label, fontproperties = font2)
plt.yticks(fontproperties = font2)

plt.grid(axis = 'y', zorder = 0, linestyle = 'dashed', alpha = 0.4)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\figure.py:3069, in Figure.draw(self, renderer)
#    3066         # ValueError can occur when resizing a window.
#    3068 self.patch.draw(renderer)
# -> 3069 mimage._draw_list_compositing_images(
#    3070     renderer, self, artists, self.suppressComposite)
#    3072 for sfig in self.subfigs:
#    3073     sfig.draw(renderer)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067     for spine in self.spines.values():
#    3068         artists.remove(spine)
# -> 3070 self._update_title_position(renderer)
#    3072 if not self.axison:
#    3073     for _axis in self._axis_map.values():
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axes\_base.py:3014, in _AxesBase._update_title_position(self, renderer)
#    3012 top = max(top, bb.ymax)
#    3013 if title.get_text():
# -> 3014     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3015     if ax.yaxis.offsetText.get_text():
#    3016         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axis.py:1253, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1250     renderer = self.figure._get_renderer()
#    1251 ticks_to_draw = self._update_ticks()
# -> 1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#    1256 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axis.py:2506, in YAxis._update_label_position(self, renderer)
#    2502     return
#    2504 # get bounding boxes for this axis and any siblings
#    2505 # that have been set by `fig.align_ylabels()`
# -> 2506 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2507 x, y = self.label.get_position()
#    2508 if self.label_position == 'left':
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axis.py:2056, in Axis._get_tick_boxes_siblings(self, renderer)
#    2054 axis = getattr(ax, f"{axis_name}axis")
#    2055 ticks_to_draw = axis._update_ticks()
# -> 2056 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2057 bboxes.extend(tlb)
#    2058 bboxes2.extend(tlb2)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axis.py:1232, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\axis.py:1232, in <listcomp>(.0)
#    1230 if renderer is None:
#    1231     renderer = self.figure._get_renderer()
# -> 1232 return ([tick.label1.get_window_extent(renderer)
#    1233          for tick in ticks if tick.label1.get_visible()],
#    1234         [tick.label2.get_window_extent(renderer)
#    1235          for tick in ticks if tick.label2.get_visible()])
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\text.py:916, in Text.get_window_extent(self, renderer, dpi)
#     911     raise RuntimeError(
#     912         "Cannot get window extent of text w/o renderer. You likely "
#     913         "want to call 'figure.draw_without_rendering()' first.")
#     915 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 916     bbox, info, descent = self._get_layout(self._renderer)
#     917     x, y = self.get_unitless_position()
#     918     x, y = self.get_transform().transform((x, y))
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\text.py:314, in Text._get_layout(self, renderer)
#     311 ys = []
#     313 # Full vertical extent of font, including ascenders and descenders:
# --> 314 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     315     renderer, "lp", self._fontproperties,
#     316     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     317 min_dy = (lp_h - lp_d) * self._linespacing
#     319 for i, line in enumerate(lines):
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\text.py:97, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      94 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      95 # Cached based on a copy of fontprop so that later in-place mutations of
#      96 # the passed-in argument do not mess up the cache.
# ---> 97 return _get_text_metrics_with_cache_impl(
#      98     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\text.py:105, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#     101 @functools.lru_cache(4096)
#     102 def _get_text_metrics_with_cache_impl(
#     103         renderer_ref, text, fontprop, ismath, dpi):
#     104     # dpi is unused, but participates in cache invalidation (via the renderer).
# --> 105     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\backends\backend_agg.py:241, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     237     ox, oy, width, height, descent, font_image = \
#     238         self.mathtext_parser.parse(s, self.dpi, prop)
#     239     return width, height, descent
# --> 241 font = self._prepare_font(prop)
#     242 font.set_text(s, 0.0, flags=get_hinting_flag())
#     243 w, h = font.get_width_height()  # width and height of unrotated string
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\backends\backend_agg.py:275, in RendererAgg._prepare_font(self, font_prop)
#     271 def _prepare_font(self, font_prop):
#     272     """
#     273     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     274     """
# --> 275     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     276     font.clear()
#     277     size = font_prop.get_size_in_points()
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\font_manager.py:1600, in get_font(font_filepaths, hinting_factor)
#    1597 if hinting_factor is None:
#    1598     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1600 return _get_font(
#    1601     # must be a tuple to be cached
#    1602     paths,
#    1603     hinting_factor,
#    1604     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1605     # also key on the thread ID to prevent segfaults with multi-threading
#    1606     thread_id=threading.get_ident()
#    1607 )
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\matplotlib\font_manager.py:1541, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1538 @lru_cache(64)
#    1539 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1540     first_fontpath, *rest = font_filepaths
# -> 1541     return ft2font.FT2Font(
#    1542         first_fontpath, hinting_factor,
#    1543         _fallback_list=[
#    1544             ft2font.FT2Font(
#    1545                 fpath, hinting_factor,
#    1546                 _kerning_factor=_kerning_factor
#    1547             )
#    1548             for fpath in rest
#    1549         ],
#    1550         _kerning_factor=_kerning_factor
#    1551     )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\BELAJAR\\GITHUB\\python-100daysChallenge\\PROJECT\\DAY 52\\Galgony.ttf'
