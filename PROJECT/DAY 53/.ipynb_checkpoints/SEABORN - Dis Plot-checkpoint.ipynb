# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 53\per-capita-energy-use.csv"

df = pd.read_csv(file)

df
# Out:
#            Entity Code  Year  Energy consumption per capita (kWh)
# 0     Afghanistan  AFG  1980                           581.932201
# 1     Afghanistan  AFG  1981                           662.912777
# 2     Afghanistan  AFG  1982                           709.075252
# 3     Afghanistan  AFG  1983                           877.845852
# 4     Afghanistan  AFG  1984                           905.948350
# ...           ...  ...   ...                                  ...
# 8956     Zimbabwe  ZWE  2012                          4251.321680
# 8957     Zimbabwe  ZWE  2013                          4200.828880
# 8958     Zimbabwe  ZWE  2014                          4127.800993
# 8959     Zimbabwe  ZWE  2015                          4027.628101
# 8960     Zimbabwe  ZWE  2016                          3385.574447
#
# [8961 rows x 4 columns]

# %%
data1 = df.loc[df['Year'] == 2016], df.loc[df['Year'] == 2015], df.loc[df['Year'] == 2014]

data1
# Out:
# (              Entity      Code  Year  Energy consumption per capita (kWh)
#  36       Afghanistan       AFG  2016                          1010.013581
#  88            Africa       NaN  2016                          4208.473928
#  128          Albania       ALB  2016                         13668.121006
#  180          Algeria       DZA  2016                         15210.944342
#  220   American Samoa       ASM  2016                         26149.812016
#  ...              ...       ...   ...                                  ...
#  8794  Western Sahara       ESH  2016                          1982.333996
#  8846           World  OWID_WRL  2016                         20490.954821
#  8886           Yemen       YEM  2016                          2525.175596
#  8923          Zambia       ZMB  2016                          2832.410826
#  8960        Zimbabwe       ZWE  2016                          3385.574447
#
#  [215 rows x 4 columns],
# ...

# %%
sns.lineplot(data = data1, x = 2016, y = data1['Energy consumption per capita (kWh)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 sns.lineplot(data = data1, x = 2016, y = data1['Energy consumption per capita (kWh)'])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
A = df.loc[df['Year'] == 2016]

A
# Out:
#               Entity      Code  Year  Energy consumption per capita (kWh)
# 36       Afghanistan       AFG  2016                          1010.013581
# 88            Africa       NaN  2016                          4208.473928
# 128          Albania       ALB  2016                         13668.121006
# 180          Algeria       DZA  2016                         15210.944342
# 220   American Samoa       ASM  2016                         26149.812016
# ...              ...       ...   ...                                  ...
# 8794  Western Sahara       ESH  2016                          1982.333996
# 8846           World  OWID_WRL  2016                         20490.954821
# 8886           Yemen       YEM  2016                          2525.175596
# 8923          Zambia       ZMB  2016                          2832.410826
# 8960        Zimbabwe       ZWE  2016                          3385.574447
#
# [215 rows x 4 columns]

# %%
data = A['Energy consumption per capita (kWh)']

data
# Out:
# 36       1010.013581
# 88       4208.473928
# 128     13668.121006
# 180     15210.944342
# 220     26149.812016
#             ...
# 8794     1982.333996
# 8846    20490.954821
# 8886     2525.175596
# 8923     2832.410826
# 8960     3385.574447
# Name: Energy consumption per capita (kWh), Length: 215, dtype: float64

# %%
sns.catplot(data)

# %%
df.loc[df['Entity'] == 'Indonesia']
# Out:
#          Entity Code  Year  Energy consumption per capita (kWh)
# 3741  Indonesia  IDN  1965                           839.648074
# 3742  Indonesia  IDN  1966                           810.199888
# 3743  Indonesia  IDN  1967                           778.528893
# 3744  Indonesia  IDN  1968                           807.458341
# 3745  Indonesia  IDN  1969                           887.348681
# 3746  Indonesia  IDN  1970                           925.194819
# 3747  Indonesia  IDN  1971                           862.360057
# 3748  Indonesia  IDN  1972                           891.165375
# 3749  Indonesia  IDN  1973                           979.026206
# 3750  Indonesia  IDN  1974                          1022.551614
# 3751  Indonesia  IDN  1975                          1221.298522
# 3752  Indonesia  IDN  1976                          1252.376550
# 3753  Indonesia  IDN  1977                          1615.475142
# 3754  Indonesia  IDN  1978                          1747.710242
# ...

# %%
file2 = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 45\death-rates-from-air-pollution.csv"

df2 = pd.read_csv(file2)

df2
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df2_negara = df2.loc[(df2['Entity'] == 'Indonesia') |
                   (df2['Entity'] == 'Mexico') |
                   (df2['Entity'] == 'Netherlands') |
                   (df2['Entity'] == 'Spain') |
                    (df2['Entity'] == 'Turkey')]

df2_negara
# Out:
#          Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 2688  Indonesia  IDN  1990                                  108.258041
# 2689  Indonesia  IDN  1991                                  105.068758
# 2690  Indonesia  IDN  1992                                  101.865004
# 2691  Indonesia  IDN  1993                                   99.076420
# 2692  Indonesia  IDN  1994                                   96.168075
# ...         ...  ...   ...                                         ...
# 5931     Turkey  TUR  2013                                   50.000179
# 5932     Turkey  TUR  2014                                   50.091587
# 5933     Turkey  TUR  2015                                   49.713325
# 5934     Turkey  TUR  2016                                   47.881273
# 5935     Turkey  TUR  2017                                   46.775579
#
#       Indoor air pollution (deaths per 100,000)  \
# 2688                                  88.257244
# ...

# %%
df2_negara['Entity'].unique()
# Out:
# array(['Indonesia', 'Mexico', 'Netherlands', 'Spain', 'Turkey'],
#       dtype=object)

# %%
sns.displot(data = df2_negara, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)")

# %%
coba = df2.loc[(df2['Year'] == 2017) |
               (df2['Year'] == 2016) |
               (df2['Year'] == 2015) |
               (df2['Year'] == 2014)]

# %%
sns.displot(data = coba, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", 
            palette = 'YlOrBr', hue = coba['Year'])

# %%
sns.relplot(data = data)

# %%
sns.catplot(data = indo, y = indo['happiness_score'], x = indo['Year'])

# %%
data1 = df2.loc[df2['Year'] == 2020]

data1
# Out:
#          Country  happiness_score  gdp_per_capita  family    health   freedom  \
# 660      Finland           7.8087        1.285190     0.0  0.961271  0.662317
# 661      Denmark           7.6456        1.326949     0.0  0.979333  0.665040
# 662  Switzerland           7.5599        1.390774     0.0  1.040533  0.628954
# 663      Iceland           7.5045        1.326502     0.0  1.000843  0.661981
# 664       Norway           7.4880        1.424207     0.0  1.008072  0.670201
# ..           ...              ...             ...     ...       ...       ...
# 787     Botswana           3.4789        0.997549     0.0  0.494102  0.509089
# 788     Tanzania           3.4762        0.457163     0.0  0.442678  0.509343
# 789       Rwanda           3.3123        0.343243     0.0  0.572383  0.604088
# 790     Zimbabwe           3.2992        0.425564     0.0  0.375038  0.377405
# 791  Afghanistan           2.5669        0.300706     0.0  0.266052  0.000000
#
# ...

# %%
happy = data1['happiness_score']

happy
# Out:
# 660    7.8087
# 661    7.6456
# 662    7.5599
# 663    7.5045
# 664    7.4880
#         ...
# 787    3.4789
# 788    3.4762
# 789    3.3123
# 790    3.2992
# 791    2.5669
# Name: happiness_score, Length: 132, dtype: float64

# %%
sns.boxplot(data = happy)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# ...
