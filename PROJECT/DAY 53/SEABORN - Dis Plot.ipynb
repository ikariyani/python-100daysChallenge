# %% [markdown]
# | <img src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg" style="height:100px"> | <img src="https://user-images.githubusercontent.com/315810/92255284-156f1180-eea0-11ea-9d2d-be8262670e8c.png" style="height:100px"> |
# | --- | --- |
#
#
#
# # SEABORN - Dis Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file2 = "D:\BELAJAR\GITHUB\python-100daysChallenge\PROJECT\DAY 53\death-rates-from-air-pollution.csv"

df2 = pd.read_csv(file2)

df2
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df2_negara = df2.loc[(df2['Entity'] == 'Indonesia') |
                   (df2['Entity'] == 'Mexico') |
                   (df2['Entity'] == 'Netherlands') |
                   (df2['Entity'] == 'Spain') |
                    (df2['Entity'] == 'Turkey')]

df2_negara
# Out:
#          Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 2688  Indonesia  IDN  1990                                  108.258041
# 2689  Indonesia  IDN  1991                                  105.068758
# 2690  Indonesia  IDN  1992                                  101.865004
# 2691  Indonesia  IDN  1993                                   99.076420
# 2692  Indonesia  IDN  1994                                   96.168075
# ...         ...  ...   ...                                         ...
# 5931     Turkey  TUR  2013                                   50.000179
# 5932     Turkey  TUR  2014                                   50.091587
# 5933     Turkey  TUR  2015                                   49.713325
# 5934     Turkey  TUR  2016                                   47.881273
# 5935     Turkey  TUR  2017                                   46.775579
#
#       Indoor air pollution (deaths per 100,000)  \
# 2688                                  88.257244
# ...

# %%
df2_negara['Entity'].unique()
# Out:
# array(['Indonesia', 'Mexico', 'Netherlands', 'Spain', 'Turkey'],
#       dtype=object)

# %%
coba = df2.loc[(df2['Year'] == 2017) ]

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 18)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 12)
font5 = fm.FontProperties(fname = path2, size = 16)

# %%
sns.displot(data = coba, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)", 
            palette = 'rocket')

plt.title('Kasus Kematian Akibat Polusi Udara di Beberapa Negara\npada Tahun 2017', fontproperties = font1, pad = 20)
plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.xlabel('Outdoor particulate matter (deaths per 100,000)', fontproperties = font2)
plt.ylabel('Indoor air pollution (deaths per 100,000)', fontproperties = font2)

plt.grid(linestyle = 'dashed')

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4484\2159402512.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data = coba, x="Outdoor particulate matter (deaths per 100,000)", y="Indoor air pollution (deaths per 100,000)",
