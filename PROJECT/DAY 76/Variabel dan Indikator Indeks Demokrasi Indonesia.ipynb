# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
file = "variabel indeks demokrasi.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#                                         ﻿nama_variabel nama_variabel_turunan  \
# 0    Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 1    Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 2    Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 3    Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 4    Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# ..                                                 ...                   ...
# 105  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 106  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 107  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 108  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 109  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
#
# ...

# %%
file2 = "tes.csv"

df2 = pd.read_csv(file2, sep = ';')

df2
# Out:
#                                             indikator   2020   2019   2018  \
# 0   Ancaman/penggunaan kekerasan oleh aparat pemer...  86.76  77.21  82.35
# 1   Ancaman/penggunaan kekerasan oleh masyarakat y...  86.95  83.82  82.35
# 2   Ancaman/penggunaan kekerasan oleh aparat pemer...  58.82  65.69  70.22
# 3   Ancaman/penggunaan kekerasan oleh masyarakat y...  42.28  57.35  45.96
# 4   Aturan tertulis yang membatasi kebebasan menja...  84.02  81.71  80.43
# 5   Tindakan/pernyataan pejabat membatasi kebebasa...  93.38  83.73  84.38
# 6   Ancaman/penggunaan kekerasan dari satu kelompo...  92.35  87.79  91.47
# 7   Aturan tertulis yang diskriminatif dalam hal g...  92.65  92.65  92.16
# 8   Tindakan/pernyataan pejabat yang diskriminatif...  93.84  88.97  91.91
# 9   Ancaman/penggunaan kekerasan oleh masyarakat k...  86.27  94.85  91.18
# 10                 Hak memilih atau dipilih terhambat  94.80  94.80  95.83
# ...

# %% [markdown]
# # Eksplorasi Data

# %%
df['nama_item_vertical_variabel'].unique()
# Out:
# array(['Kebebasan Berkumpul dan Berserikat', 'Kebebasan Berpendapat',
#        'Kebebasan Berkeyakinan', 'Kebebasan dari Diskriminasi',
#        'Hak Memilih dan Dipilih',
#        'Partisipasi Politik dalam Pengambilan Keputusan dan Pengawasan',
#        'Pemilu yang Bebas dan Adil', 'Peran DPRD', 'Peran Partai Politik',
#        'Peran Birokrasi Pemerintah Daerah',
#        'Peran Peradilan yang Independen'], dtype=object)

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berkumpul dan Berserikat'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     83.569294
# std       3.02765      4.190748
# min    2011.00000     78.030000
# 25%    2013.25000     80.680000
# 50%    2015.50000     82.571471
# 75%    2017.75000     86.502500
# max    2020.00000     91.700000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berpendapat'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     65.034838
# std       3.02765      4.413343
# min    2011.00000     56.060000
# 25%    2013.25000     62.730000
# 50%    2015.50000     65.465000
# 75%    2017.75000     67.174596
# max    2020.00000     72.170000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berkeyakinan'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     83.177544
# std       3.02765      1.808433
# min    2011.00000     80.500000
# 25%    2013.25000     81.981359
# 50%    2015.50000     83.080000
# 75%    2017.75000     84.157500
# max    2020.00000     86.570000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan dari Diskriminasi'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     88.788520
# std       3.02765      2.605786
# min    2011.00000     84.700000
# 25%    2013.25000     86.890000
# 50%    2015.50000     88.545000
# 75%    2017.75000     90.845000
# max    2020.00000     92.350000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Hak Memilih dan Dipilih'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     68.695852
# std       3.02765     12.836752
# min    2011.00000     50.110000
# 25%    2013.25000     56.547500
# 50%    2015.50000     75.405000
# 75%    2017.75000     75.766386
# max    2020.00000     79.410000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Partisipasi Politik dalam Pengambilan Keputusan dan Pengawasan'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     52.937013
# std       3.02765      6.103465
# min    2011.00000     44.520000
# 25%    2013.25000     47.047500
# 50%    2015.50000     54.140067
# 75%    2017.75000     56.580000
# max    2020.00000     61.240000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Pemilu yang Bebas dan Adil'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     91.179162
# std       3.02765      4.562851
# min    2011.00000     85.750000
# 25%    2013.25000     87.670000
# 50%    2015.50000     91.515000
# 75%    2017.75000     95.480000
# max    2020.00000     95.481622

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Peran DPRD'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     49.456438
# std       3.02765     11.004519
# min    2011.00000     35.530000
# 25%    2013.25000     40.710000
# 50%    2015.50000     47.075000
# 75%    2017.75000     59.566095
# max    2020.00000     64.940000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Peran Partai Politik'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     65.283303
# std       3.02765     14.106357
# min    2011.00000     35.510000
# 25%    2013.25000     59.745000
# 50%    2015.50000     67.105000
# 75%    2017.75000     74.655000
# max    2020.00000     82.103033

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Peran Birokrasi Pemerintah Daerah'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     70.003949
# std       3.02765     18.981834
# min    2011.00000     47.510000
# 25%    2013.25000     55.869616
# 50%    2015.50000     61.150000
# 75%    2017.75000     88.580000
# max    2020.00000     99.380000

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Peran Peradilan yang Independen'].describe()
# Out:
#        nama_tahun  data_content
# count    10.00000     10.000000
# mean   2015.50000     87.911691
# std       3.02765      4.261158
# min    2011.00000     81.970000
# 25%    2013.25000     84.527500
# 50%    2015.50000     88.240000
# 75%    2017.75000     91.199228
# max    2020.00000     93.660000

# %%
df2 = df2.transpose()

df2
# Out:
# indikator  Ancaman/penggunaan kekerasan oleh aparat pemerintah yang menghambat kebebasan berkumpul dan berserikat  \
# 2020                                                   86.76
# 2019                                                   77.21
# 2018                                                   82.35
# 2017                                                   77.57
# 2016                                                   82.35
# 2015                                                   86.76
# 2014                                                   80.00
# 2013                                                   85.76
# 2012                                                   80.00
# 2011                                                   91.21
#
# indikator  Ancaman/penggunaan kekerasan oleh masyarakat yang menghambat kebebasan berkumpul dan berserikat  \
# 2020                                                   86.95
# 2019                                                   83.82
# ...

# %%
df2.describe()
# Out:
# indikator  Ancaman/penggunaan kekerasan oleh aparat pemerintah yang menghambat kebebasan berkumpul dan berserikat  \
# count                                              10.000000
# mean                                               82.997000
# std                                                 4.535671
# min                                                77.210000
# 25%                                                80.000000
# 50%                                                82.350000
# 75%                                                86.510000
# max                                                91.210000
#
# indikator  Ancaman/penggunaan kekerasan oleh masyarakat yang menghambat kebebasan berkumpul dan berserikat  \
# count                                              10.000000
# mean                                               87.568000
# std                                                 4.666328
# min                                                82.270000
# ...

# %%
df2.isnull()
# Out:
#     indikator   2020   2019   2018   2017   2016   2015   2014   2013   2012  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# 5       False  False  False  False  False  False  False  False  False  False
# 6       False  False  False  False  False  False  False  False  False  False
# 7       False  False  False  False  False  False  False  False  False  False
# 8       False  False  False  False  False  False  False  False  False  False
# 9       False  False  False  False  False  False  False  False  False  False
# 10      False  False  False  False  False  False  False  False  False  False
# ...

# %%
df2 = df2.set_index('indikator')

df2
# Out:
#                                                      2020   2019   2018  \
# indikator
# Ancaman/penggunaan kekerasan oleh aparat pemeri...  86.76  77.21  82.35
# Ancaman/penggunaan kekerasan oleh masyarakat ya...  86.95  83.82  82.35
# Ancaman/penggunaan kekerasan oleh aparat pemeri...  58.82  65.69  70.22
# Ancaman/penggunaan kekerasan oleh masyarakat ya...  42.28  57.35  45.96
# Aturan tertulis yang membatasi kebebasan menjal...  84.02  81.71  80.43
# Tindakan/pernyataan pejabat membatasi kebebasan...  93.38  83.73  84.38
# Ancaman/penggunaan kekerasan dari satu kelompok...  92.35  87.79  91.47
# Aturan tertulis yang diskriminatif dalam hal ge...  92.65  92.65  92.16
# Tindakan/pernyataan pejabat yang diskriminatif ...  93.84  88.97  91.91
# Ancaman/penggunaan kekerasan oleh masyarakat ka...  86.27  94.85  91.18
# Hak memilih atau dipilih terhambat                  94.80  94.80  95.83
# Ketiadaan/kurangnya fasilitas sehingga penyanda...  96.53  96.53  60.00
# ...

# %%
df2.iloc[0]
# Out:
# 2020    86.76
# 2019    77.21
# 2018    82.35
# 2017    77.57
# 2016    82.35
# 2015    86.76
# 2014    80.00
# 2013    85.76
# 2012    80.00
# 2011    91.21
# Name: Ancaman/penggunaan kekerasan oleh aparat pemerintah yang menghambat kebebasan berkumpul dan berserikat, dtype: float64

# %%
tahun = np.arange(2021, 2011, -1)

# %%
df['nama_item_vertical_variabel'].unique()
# Out:
# array(['Kebebasan Berkumpul dan Berserikat', 'Kebebasan Berpendapat',
#        'Kebebasan Berkeyakinan', 'Kebebasan dari Diskriminasi',
#        'Hak Memilih dan Dipilih',
#        'Partisipasi Politik dalam Pengambilan Keputusan dan Pengawasan',
#        'Pemilu yang Bebas dan Adil', 'Peran DPRD', 'Peran Partai Politik',
#        'Peran Birokrasi Pemerintah Daerah',
#        'Peran Peradilan yang Independen'], dtype=object)

# %%
df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berkumpul dan Berserikat']
# Out:
#                                        ﻿nama_variabel nama_variabel_turunan  \
# 0   Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 11  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 22  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 33  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 44  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 55  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 66  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 77  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 88  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
# 99  Indeks Demokrasi Indonesia (IDI) Menurut Variabel             Tidak Ada
#
#     nama_tahun nama_turunan_tahun  data_content  \
# 0         2020              Tahun     86.790000
# ...

# %%
tahun = df['nama_tahun'].unique()

# %% [markdown]
# # Visualisasi Data

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 20)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 10)
font6 = fm.FontProperties(fname = path2, size = 17)

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Variabel - Variabel pada Aspek Kebebasan Sipil\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font1)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, var1, marker = 'o', color = '#3d9191', label = 'Kebebasan Berkumpul dan Berserikat')
plt.plot(tahun, var2, marker = 'o', color = '#aa1803', label = 'Kebebasan Berpendapat')
plt.plot(tahun, var3, marker = 'o', color = '#bcaf4d', label = 'Kebebasan Berkeyakinan')
plt.plot(tahun, var4, marker = 'o', color = '#238a3c', label = 'Kebebasan dari Diskriminasi')

plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
var1 = df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berkumpul dan Berserikat']['data_content']
var2 = df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berpendapat']['data_content']
var3 = df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan Berkeyakinan']['data_content']
var4 = df.loc[df['nama_item_vertical_variabel'] == 'Kebebasan dari Diskriminasi']['data_content']
var5 = df.loc[df['nama_item_vertical_variabel'] == 'Hak Memilih dan Dipilih']['data_content']
var6 = df.loc[df['nama_item_vertical_variabel'] == 'Partisipasi Politik dalam Pengambilan Keputusan dan Pengawasan']['data_content']
var7 = df.loc[df['nama_item_vertical_variabel'] == 'Pemilu yang Bebas dan Adil']['data_content']
var8 = df.loc[df['nama_item_vertical_variabel'] == 'Peran DPRD']['data_content']
var9 = df.loc[df['nama_item_vertical_variabel'] == 'Peran Partai Politik']['data_content']
var10 = df.loc[df['nama_item_vertical_variabel'] == 'Peran Birokrasi Pemerintah Daerah']['data_content']
var11 = df.loc[df['nama_item_vertical_variabel'] == 'Peran Peradilan yang Independen']['data_content']

# %%
df2['indikator'].unique()
# Out:
# array(['Ancaman/penggunaan kekerasan oleh aparat pemerintah yang menghambat kebebasan berkumpul dan berserikat',
#        'Ancaman/penggunaan kekerasan oleh masyarakat yang menghambat kebebasan berkumpul dan berserikat',
#        'Ancaman/penggunaan kekerasan oleh aparat pemerintah yang menghambat kebebasan berpendapat',
#        'Ancaman/penggunaan kekerasan oleh masyarakat yang menghambat kebebasan berpendapat',
#        'Aturan tertulis yang membatasi kebebasan menjalankan ibadah agama',
#        'Tindakan/pernyataan pejabat membatasi kebebasan menjalankan ibadah agama',
#        'Ancaman/penggunaan kekerasan dari satu kelompok terkait ajaran agama',
#        'Aturan tertulis yang diskriminatif dalam hal gender, etnis, kelompok',
#        'Tindakan/pernyataan pejabat yang diskriminatif dalam hal gender, etnis, kelompok',
#        'Ancaman/penggunaan kekerasan oleh masyarakat karena alasan gender, etnis, kelompok',
#        'Hak memilih atau dipilih terhambat',
# ...

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Kebebasan Berkumpul dan Berserikat\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[0], marker = 'o', color = '#254a7f', label = 'Indikator 1')
plt.plot(tahun, df2.iloc[1], marker = 'o', color = '#aa1803', label = 'Indikator 2')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Kebebasan Berpendapat\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[2], marker = 'o', color = '#254a7f', label = 'Indikator 3')
plt.plot(tahun, df2.iloc[3], marker = 'o', color = '#aa1803', label = 'Indikator 4')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2, loc = 'lower left')
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Kebebasan Berkeyakinan\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[4], marker = 'o', color = '#254a7f', label = 'Indikator 5')
plt.plot(tahun, df2.iloc[5], marker = 'o', color = '#aa1803', label = 'Indikator 6')
plt.plot(tahun, df2.iloc[6], marker = 'o', color = '#f3b800', label = 'Indikator 7')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Kebebasan dari Diskriminasi\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[7], marker = 'o', color = '#254a7f', label = 'Indikator 8')
plt.plot(tahun, df2.iloc[8], marker = 'o', color = '#aa1803', label = 'Indikator 9')
plt.plot(tahun, df2.iloc[9], marker = 'o', color = '#f3b800', label = 'Indikator 10')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Variabel - Variabel pada Aspek Hak - Hak Politik\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font1)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, var5, marker = 'o', color = '#3d9191', label = 'Hak Memilih dan Dipilih')
plt.plot(tahun, var6, marker = 'o', color = '#aa1803', label = 'Partisipasi Politik dalam Pengambilan Keputusan\ndan Pengawasan Pemerintahan')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2, loc = 'lower left')
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Hak Memilih dan Dipilih\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[10], marker = 'o', color = '#254a7f', label = 'Indikator 11')
plt.plot(tahun, df2.iloc[11], marker = 'o', color = '#aa1803', label = 'Indikator 12')
plt.plot(tahun, df2.iloc[12], marker = 'o', color = '#f3b800', label = 'Indikator 13')
plt.plot(tahun, df2.iloc[13], marker = 'o', color = '#238a3c', label = 'Indikator 14')
plt.plot(tahun, df2.iloc[14], marker = 'o', color = '#aa6f73', label = 'Indikator 15')



plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Partisipasi Politik\ndalam Pengambilan Keputusan dan Pengawasan Pemerintahan\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[15], marker = 'o', color = '#254a7f', label = 'Indikator 16')
plt.plot(tahun, df2.iloc[16], marker = 'o', color = '#aa1803', label = 'Indikator 17')




plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Variabel - Variabel pada Aspek Lembaga Demokrasi\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font1)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, var7, marker = 'o', color = '#3d9191', label = 'Pemilu yang Bebas dan Adil')
plt.plot(tahun, var8, marker = 'o', color = '#aa1803', label = 'Peran DPRD')
plt.plot(tahun, var9, marker = 'o', color = '#727c57', label = 'Peran Partai Politik')
plt.plot(tahun, var10, marker = 'o', color = '#db8200', label = 'Peran Birokrasi Pemerintah Daerah')
plt.plot(tahun, var11, marker = 'o', color = '#0b132b', label = 'Peran Peradilan yang Independen')


plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Pemilu yang Bebas dan Adil\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[17], marker = 'o', color = '#254a7f', label = 'Indikator 18')
plt.plot(tahun, df2.iloc[18], marker = 'o', color = '#aa1803', label = 'Indikator 19')




plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Peran DPRD\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[19], marker = 'o', color = '#254a7f', label = 'Indikator 20')
plt.plot(tahun, df2.iloc[20], marker = 'o', color = '#aa1803', label = 'Indikator 21')
plt.plot(tahun, df2.iloc[21], marker = 'o', color = '#f3b800', label = 'Indikator 22')




plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Peran Partai Politik\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[22], marker = 'o', color = '#254a7f', label = 'Indikator 23')
plt.plot(tahun, df2.iloc[23], marker = 'o', color = '#aa1803', label = 'Indikator 24')





plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Peran Birokrasi Pemerintah Daerah\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[24], marker = 'o', color = '#254a7f', label = 'Indikator 25')
plt.plot(tahun, df2.iloc[25], marker = 'o', color = '#aa1803', label = 'Indikator 26')





plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2, loc = 'lower left')
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()

# %%
plt.figure(figsize = [8,5])

plt.title('Capaian Indikator pada Variabel Peran Peradilan yang Independen\nIndeks Demokrasi Indonesia Tahun 2011 - 2020', fontproperties = font6)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Nilai', fontproperties = font2)

plt.plot(tahun, df2.iloc[26], marker = 'o', color = '#254a7f', label = 'Indikator 27')
plt.plot(tahun, df2.iloc[27], marker = 'o', color = '#aa1803', label = 'Indikator 28')





plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(prop = font2)
plt.grid(linestyle = 'dashed', axis = 'y')

plt.show()
