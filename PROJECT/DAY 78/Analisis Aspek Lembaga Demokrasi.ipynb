# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "indeks demokrasi.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#      Unnamed: 0              provinsi  year  kebebasan_sipil  hak_politik  \
# 0            32          MALUKU UTARA  2015            73.53        61.00
# 1            12            JAWA BARAT  2016            73.37        72.34
# 2            32           PAPUA BARAT  2011            93.59        43.99
# 3            27     SULAWESI TENGGARA  2013            84.32        28.95
# 4            34                 PAPUA  2015            82.72        41.81
# ..          ...                   ...   ...              ...          ...
# 341           3        SUMATERA BARAT  2017            61.66        61.08
# 342           9  KEP. BANGKA BELITUNG  2020            79.12        66.20
# 343          11           DKI JAKARTA  2014            91.72        73.94
# 344          11           DKI JAKARTA  2011            89.94        58.32
# 345          18   NUSA TENGGARA BARAT  2017            79.40        62.08
#
#      lembaga_demokrasi
# 0                47.25
# 1                49.79
# 2                50.03
# 3                50.32
# 4                50.87
# ..                 ...
# 341              92.72
# 342              92.97
# 343              92.97
# 344              93.50
# 345              93.98
#
# [346 rows x 6 columns]

# %%
df = df.drop(columns = 'Unnamed: 0')

df
# Out:
#                  provinsi  year  kebebasan_sipil  hak_politik  \
# 0            MALUKU UTARA  2015            73.53        61.00
# 1              JAWA BARAT  2016            73.37        72.34
# 2             PAPUA BARAT  2011            93.59        43.99
# 3       SULAWESI TENGGARA  2013            84.32        28.95
# 4                   PAPUA  2015            82.72        41.81
# ..                    ...   ...              ...          ...
# 341        SUMATERA BARAT  2017            61.66        61.08
# 342  KEP. BANGKA BELITUNG  2020            79.12        66.20
# 343           DKI JAKARTA  2014            91.72        73.94
# 344           DKI JAKARTA  2011            89.94        58.32
# 345   NUSA TENGGARA BARAT  2017            79.40        62.08
#
#      lembaga_demokrasi
# 0                47.25
# 1                49.79
# 2                50.03
# 3                50.32
# 4                50.87
# ..                 ...
# 341              92.72
# 342              92.97
# 343              92.97
# 344              93.50
# 345              93.98
#
# [346 rows x 5 columns]

# %%
IDI = df.loc[df['provinsi'] == 'INDONESIA']

IDI
# Out:
#       provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi
# 55   INDONESIA  2016            76.45        70.11              62.05
# 103  INDONESIA  2015            80.30        70.63              66.87
# 136  INDONESIA  2012            77.94        46.33              69.28
# 164  INDONESIA  2013            79.00        46.25              72.24
# 168  INDONESIA  2017            78.75        66.63              72.49
# 191  INDONESIA  2011            80.79        47.54              74.72
# 194  INDONESIA  2018            78.46        65.79              75.25
# 200  INDONESIA  2020            79.40        67.85              75.66
# 201  INDONESIA  2014            82.62        63.72              75.81
# 241  INDONESIA  2019            77.20        70.71              78.73

# %%
IDI = IDI.sort_values(by = ['year'], ascending = True)

IDI
# Out:
#       provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi
# 191  INDONESIA  2011            80.79        47.54              74.72
# 136  INDONESIA  2012            77.94        46.33              69.28
# 164  INDONESIA  2013            79.00        46.25              72.24
# 201  INDONESIA  2014            82.62        63.72              75.81
# 103  INDONESIA  2015            80.30        70.63              66.87
# 55   INDONESIA  2016            76.45        70.11              62.05
# 168  INDONESIA  2017            78.75        66.63              72.49
# 194  INDONESIA  2018            78.46        65.79              75.25
# 241  INDONESIA  2019            77.20        70.71              78.73
# 200  INDONESIA  2020            79.40        67.85              75.66

# %%
IDI['IDI'] = IDI[['kebebasan_sipil', 'hak_politik', 'lembaga_demokrasi']].mean(axis = 1)

IDI
# Out:
#       provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi  \
# 191  INDONESIA  2011            80.79        47.54              74.72
# 136  INDONESIA  2012            77.94        46.33              69.28
# 164  INDONESIA  2013            79.00        46.25              72.24
# 201  INDONESIA  2014            82.62        63.72              75.81
# 103  INDONESIA  2015            80.30        70.63              66.87
# 55   INDONESIA  2016            76.45        70.11              62.05
# 168  INDONESIA  2017            78.75        66.63              72.49
# 194  INDONESIA  2018            78.46        65.79              75.25
# 241  INDONESIA  2019            77.20        70.71              78.73
# 200  INDONESIA  2020            79.40        67.85              75.66
#
#            IDI
# 191  67.683333
# 136  64.516667
# 164  65.830000
# 201  74.050000
# 103  72.600000
# 55   69.536667
# 168  72.623333
# 194  73.166667
# 241  75.546667
# 200  74.303333

# %%
IDI[['kebebasan_sipil', 'hak_politik', 'lembaga_demokrasi']].describe()
# Out:
#        kebebasan_sipil  hak_politik  lembaga_demokrasi
# count        10.000000     10.00000          10.000000
# mean         79.091000     61.55600          72.310000
# std           1.804189     10.48717           4.980183
# min          76.450000     46.25000          62.050000
# 25%          78.070000     51.58500          70.020000
# 50%          78.875000     66.21000          73.605000
# 75%          80.075000     69.54500          75.557500
# max          82.620000     70.71000          78.730000

# %%
IDI['IDI'].describe()
# Out:
# count    10.000000
# mean     70.985667
# std       3.839537
# min      64.516667
# 25%      68.146667
# 50%      72.611667
# 75%      73.829167
# max      75.546667
# Name: IDI, dtype: float64

# %%
buruk_ks = df.loc[df['kebebasan_sipil'] < 60]

buruk_ks
# Out:
#                 provinsi  year  kebebasan_sipil  hak_politik  \
# 34        SUMATERA BARAT  2016            51.01        54.33
# 47   NUSA TENGGARA BARAT  2011            55.45        49.60
# 75                  ACEH  2011            58.65        47.90
# 93   NUSA TENGGARA BARAT  2013            59.68        49.60
# 120  NUSA TENGGARA BARAT  2014            58.73        62.08
# 150  NUSA TENGGARA BARAT  2012            58.31        49.60
# 225       SUMATERA BARAT  2013            54.88        38.97
# 230   KALIMANTAN SELATAN  2014            58.43        76.45
# 268       SUMATERA BARAT  2012            57.10        50.85
# 276       SUMATERA BARAT  2015            52.99        69.77
# 286   KALIMANTAN SELATAN  2013            58.03        56.35
# 288   KALIMANTAN SELATAN  2011            56.33        64.25
# 290   KALIMANTAN SELATAN  2015            54.15        85.77
# 319  NUSA TENGGARA BARAT  2015            51.59        61.11
# 321       SUMATERA BARAT  2018            55.32        62.84
# 322       SUMATERA BARAT  2014            47.21        61.82
# 327   KALIMANTAN SELATAN  2012            49.51        52.59
# 340       SUMATERA BARAT  2019            56.58        61.06
#
#      lembaga_demokrasi
# 34               58.82
# 47               61.06
# 75               63.77
# 93               66.24
# 120              68.38
# 150              70.85
# 225              77.17
# 230              77.53
# 268              81.32
# 276              82.01
# 286              82.54
# 288              82.76
# 290              83.17
# 319              88.36
# 321              88.52
# 322              88.56
# 327              89.33
# 340              92.21

# %%
buruk_ks['provinsi'].unique()
# Out:
# array(['SUMATERA BARAT', 'NUSA TENGGARA BARAT', 'ACEH',
#        'KALIMANTAN SELATAN'], dtype=object)

# %%
buruk_ld = df.loc[df['lembaga_demokrasi'] < 60]

buruk_ld
# Out:
#                provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi
# 0          MALUKU UTARA  2015            73.53        61.00              47.25
# 1            JAWA BARAT  2016            73.37        72.34              49.79
# 2           PAPUA BARAT  2011            93.59        43.99              50.03
# 3     SULAWESI TENGGARA  2013            84.32        28.95              50.32
# 4                 PAPUA  2015            82.72        41.81              50.87
# 5            JAWA BARAT  2015            79.10        81.89              51.37
# 6        SUMATERA UTARA  2018            76.54        62.61              51.69
# 7           PAPUA BARAT  2015            92.33        39.48              51.81
# 8      KALIMANTAN UTARA  2015            98.10        83.65              52.05
# 9            JAWA TIMUR  2012            80.97        36.17              52.22
# 10                PAPUA  2019            93.08        51.16              52.61
# 11       SUMATERA UTARA  2012            73.85        49.82              53.01
# 12          PAPUA BARAT  2020            86.33        47.78              53.09
# 13  NUSA TENGGARA TIMUR  2014            85.92        65.13              53.12
# 14          PAPUA BARAT  2019            70.35        50.31              53.23
# 15                PAPUA  2016            92.15        41.13              53.45
# 16                PAPUA  2020            89.32        51.83              53.54
# 17          PAPUA BARAT  2016            93.67        38.05              53.85
# 18         MALUKU UTARA  2017            90.19        65.84              54.02
# 19                JAMBI  2016            84.39        65.63              54.48
# 20           JAWA BARAT  2018            74.90        64.78              54.80
# 21       SUMATERA UTARA  2013            73.65        49.50              54.90
# 22            GORONTALO  2012            73.25        50.76              55.59
# 23       SUMATERA UTARA  2016            82.71        62.29              56.13
# 24                PAPUA  2017            89.09        42.16              56.91
# 25                PAPUA  2018            84.36        47.90              57.05
# 26          PAPUA BARAT  2018            82.11        40.11              57.21
# 27                 ACEH  2012            60.16        47.16              57.21
# 28               MALUKU  2015            76.04        63.20              57.43
# 29       SUMATERA UTARA  2020            77.33        60.27              57.52
# 30         MALUKU UTARA  2019            85.61        64.86              58.11
# 31     KALIMANTAN TIMUR  2013            92.14        55.36              58.20
# 32    SULAWESI TENGGARA  2012            91.39        29.50              58.44
# 33     KALIMANTAN BARAT  2013            97.54        49.36              58.61
# 34       SUMATERA BARAT  2016            51.01        54.33              58.82
# 35           JAWA BARAT  2017            73.61        71.02              59.16
# 36             BENGKULU  2013            71.57        49.28              59.28
# 37            KEP. RIAU  2016            85.43        71.28              59.48

# %%
buruk_ld['provinsi'].unique()
# Out:
# array(['MALUKU UTARA', 'JAWA BARAT', 'PAPUA BARAT', 'SULAWESI TENGGARA',
#        'PAPUA', 'SUMATERA UTARA', 'KALIMANTAN UTARA', 'JAWA TIMUR',
#        'NUSA TENGGARA TIMUR', 'JAMBI', 'GORONTALO', 'ACEH', 'MALUKU',
#        'KALIMANTAN TIMUR', 'KALIMANTAN BARAT', 'SUMATERA BARAT',
#        'BENGKULU', 'KEP. RIAU'], dtype=object)

# %%
buruk_hp = df.loc[df['hak_politik'] < 60]

buruk_hp
# Out:
#                provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi
# 2           PAPUA BARAT  2011            93.59        43.99              50.03
# 3     SULAWESI TENGGARA  2013            84.32        28.95              50.32
# 4                 PAPUA  2015            82.72        41.81              50.87
# 7           PAPUA BARAT  2015            92.33        39.48              51.81
# 9            JAWA TIMUR  2012            80.97        36.17              52.22
# ..                  ...   ...              ...          ...                ...
# 327  KALIMANTAN SELATAN  2012            49.51        52.59              89.33
# 329               JAMBI  2014            78.23        54.01              89.48
# 331   KALIMANTAN TENGAH  2011            92.56        54.73              90.04
# 338     SULAWESI TENGAH  2019            96.19        53.21              91.68
# 344         DKI JAKARTA  2011            89.94        58.32              93.50
#
# [137 rows x 5 columns]

# %%
buruk_hp['provinsi'].unique()
# Out:
# array(['PAPUA BARAT', 'SULAWESI TENGGARA', 'PAPUA', 'JAWA TIMUR',
#        'SUMATERA UTARA', 'GORONTALO', 'ACEH', 'KALIMANTAN TIMUR',
#        'KALIMANTAN BARAT', 'SUMATERA BARAT', 'BENGKULU', 'JAWA TENGAH',
#        'NUSA TENGGARA BARAT', 'MALUKU', 'JAWA BARAT', 'MALUKU UTARA',
#        'KALIMANTAN TENGAH', 'SUMATERA SELATAN', 'LAMPUNG',
#        'SULAWESI BARAT', 'SULAWESI UTARA', 'SULAWESI TENGAH', 'KEP. RIAU',
#        'SULAWESI SELATAN', 'NUSA TENGGARA TIMUR', 'INDONESIA', 'BANTEN',
#        'KEP. BANGKA BELITUNG', 'JAMBI', 'DKI JAKARTA', 'RIAU', 'BALI',
#        'DI YOGYAKARTA', 'KALIMANTAN SELATAN'], dtype=object)

# %%
sedang = df.loc[(df['hak_politik'] >= 60) & (df['hak_politik'] <= 80)]

sedang
# Out:
#                  provinsi  year  kebebasan_sipil  hak_politik  \
# 0            MALUKU UTARA  2015            73.53        61.00
# 1              JAWA BARAT  2016            73.37        72.34
# 6          SUMATERA UTARA  2018            76.54        62.61
# 13    NUSA TENGGARA TIMUR  2014            85.92        65.13
# 18           MALUKU UTARA  2017            90.19        65.84
# ..                    ...   ...              ...          ...
# 340        SUMATERA BARAT  2019            56.58        61.06
# 341        SUMATERA BARAT  2017            61.66        61.08
# 342  KEP. BANGKA BELITUNG  2020            79.12        66.20
# 343           DKI JAKARTA  2014            91.72        73.94
# 345   NUSA TENGGARA BARAT  2017            79.40        62.08
#
#      lembaga_demokrasi
# 0                47.25
# 1                49.79
# 6                51.69
# 13               53.12
# 18               54.02
# ..                 ...
# 340              92.21
# 341              92.72
# 342              92.97
# 343              92.97
# 345              93.98
#
# [187 rows x 5 columns]

# %%
sedang['provinsi'].unique()
# Out:
# array(['MALUKU UTARA', 'JAWA BARAT', 'SUMATERA UTARA',
#        'NUSA TENGGARA TIMUR', 'JAMBI', 'MALUKU', 'KEP. RIAU', 'ACEH',
#        'KALIMANTAN TIMUR', 'SULAWESI UTARA', 'KALIMANTAN BARAT', 'BANTEN',
#        'SUMATERA SELATAN', 'JAWA TENGAH', 'INDONESIA', 'RIAU',
#        'SULAWESI BARAT', 'LAMPUNG', 'DKI JAKARTA', 'SULAWESI SELATAN',
#        'JAWA TIMUR', 'KEP. BANGKA BELITUNG', 'KALIMANTAN UTARA', 'BALI',
#        'SULAWESI TENGAH', 'KALIMANTAN TENGAH', 'NUSA TENGGARA BARAT',
#        'BENGKULU', 'GORONTALO', 'SULAWESI TENGGARA', 'KALIMANTAN SELATAN',
#        'DI YOGYAKARTA', 'SUMATERA BARAT'], dtype=object)

# %%
buruk = df.loc[df['hak_politik'] > 80]

buruk
# Out:
#                  provinsi  year  kebebasan_sipil  hak_politik  \
# 5              JAWA BARAT  2015            79.10        81.89
# 8        KALIMANTAN UTARA  2015            98.10        83.65
# 77       KALIMANTAN TIMUR  2015            93.07        82.74
# 83     KALIMANTAN SELATAN  2020            69.59        83.53
# 95    NUSA TENGGARA TIMUR  2016            96.25        81.68
# 98       SUMATERA SELATAN  2016            91.17        81.94
# 163      SUMATERA SELATAN  2019            80.54        81.95
# 172  KEP. BANGKA BELITUNG  2017            83.07        82.30
# 173    KALIMANTAN SELATAN  2016            61.04        83.58
# 181         DI YOGYAKARTA  2017            93.25        82.31
# 216        SULAWESI UTARA  2014            93.56        80.89
# 256  KEP. BANGKA BELITUNG  2016            87.65        81.09
# 261            JAWA TIMUR  2019            72.14        80.25
# 287    KALIMANTAN SELATAN  2019            68.01        86.52
# 290    KALIMANTAN SELATAN  2015            54.15        85.77
# 292           DKI JAKARTA  2015            89.64        83.19
# 308         DI YOGYAKARTA  2016            90.00        81.59
# 313           DKI JAKARTA  2017            87.73        80.86
# 320    KALIMANTAN SELATAN  2018            69.26        83.03
# 324    KALIMANTAN SELATAN  2017            60.16        81.09
# 335           DKI JAKARTA  2020            93.27        84.95
# 339           DKI JAKARTA  2019            91.01        83.86
#
#      lembaga_demokrasi
# 5                51.37
# 8                52.05
# 77               63.99
# 83               64.59
# 95               66.46
# 98               66.53
# 163              72.23
# 172              72.89
# 173              72.89
# 181              73.55
# 216              76.68
# 256              80.20
# 261              80.55
# 287              82.67
# 290              83.17
# 292              83.26
# 308              86.37
# 313              87.12
# 320              88.37
# 324              88.79
# 335              90.86
# 339              91.89

# %%
df.sort_values(by = ['provinsi'])
# Out:
#            provinsi  year  kebebasan_sipil  hak_politik  lembaga_demokrasi
# 234            ACEH  2018            96.79        68.09              77.67
# 245            ACEH  2019            93.28        65.22              79.08
# 323            ACEH  2014            69.76        63.94              88.73
# 75             ACEH  2011            58.65        47.90              63.77
# 40             ACEH  2016            92.92        63.94              60.33
# ..              ...   ...              ...          ...                ...
# 23   SUMATERA UTARA  2016            82.71        62.29              56.13
# 63   SUMATERA UTARA  2014            79.86        61.97              62.75
# 70   SUMATERA UTARA  2015            82.02        62.17              63.52
# 29   SUMATERA UTARA  2020            77.33        60.27              57.52
# 154  SUMATERA UTARA  2019            72.54        61.59              71.12
#
# [346 rows x 5 columns]

# %%
buruk['provinsi'].unique()
# Out:
# array(['JAWA BARAT', 'KALIMANTAN UTARA', 'KALIMANTAN TIMUR',
#        'KALIMANTAN SELATAN', 'NUSA TENGGARA TIMUR', 'SUMATERA SELATAN',
#        'KEP. BANGKA BELITUNG', 'DI YOGYAKARTA', 'SULAWESI UTARA',
#        'JAWA TIMUR', 'DKI JAKARTA'], dtype=object)

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 23)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 10)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 9)

# %%
plt.figure(figsize = [9,5])

plt.bar(IDI['year'] , IDI['IDI'], color = '#7bbabb')
plt.plot(IDI['year'], IDI['kebebasan_sipil'], label = 'Kebebasan Sipil', marker = 'o', color = '#aa1803')
plt.plot(IDI['year'], IDI['hak_politik'], label = 'Hak - Hak Politik',  marker = 'o', color = '#344c11')
plt.plot(IDI['year'], IDI['lembaga_demokrasi'], label = 'Lembaga Demokrasi',  marker = 'o', color = '#ffbe00')

plt.title('Indeks Demokrasi Indonesia Tahun 2011 - 2020\ndan Aspek Penyusunnya', fontproperties = font1)

plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Indeks Demokrasi Indonesia', fontproperties = font2)

plt.xticks(np.arange(2011, 2021, 1), fontproperties = font3)
plt.yticks(np.arange(0, 110, 10), fontproperties = font3)

plt.legend(loc = 'upper left', prop = font5)
plt.grid(axis = 'y', linestyle = 'dotted')

plt.show()
