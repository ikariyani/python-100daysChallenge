# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install scipy
# Out:
# ...
#      ---------------------------------------- 40.1/40.1 MB 2.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy import constants

# %%
file = "korelasi.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#    Country/Territory Code  Year  Cardiovascular Diseases  population
# 0          Indonesia  IDN  1990                   278302   181413402
# 1          Indonesia  IDN  1991                   285751   184591903
# 2          Indonesia  IDN  1992                   294517   187739786
# 3          Indonesia  IDN  1993                   303860   190851175
# 4          Indonesia  IDN  1994                   312544   193917462
# 5          Indonesia  IDN  1995                   321557   196934260
# 6          Indonesia  IDN  1996                   331193   199901228
# 7          Indonesia  IDN  1997                   342414   202826446
# 8          Indonesia  IDN  1998                   354220   205724592
# 9          Indonesia  IDN  1999                   366292   208615169
# 10         Indonesia  IDN  2000                   380554   211513823
# 11         Indonesia  IDN  2001                   394941   214427417
# 12         Indonesia  IDN  2002                   410020   217357793
# ...

# %%
x = df['Cardiovascular Diseases']

x
# Out:
# 0     278302
# 1     285751
# 2     294517
# 3     303860
# 4     312544
# 5     321557
# 6     331193
# 7     342414
# 8     354220
# 9     366292
# 10    380554
# 11    394941
# 12    410020
# 13    424879
# 14    440056
# 15    455437
# 16    469704
# 17    484163
# 18    500374
# 19    514806
# 20    527322
# 21    540490
# 22    558106
# 23    573039
# 24    587184
# 25    603096
# 26    614602
# 27    626883
# 28    639224
# 29    651481
# Name: Cardiovascular Diseases, dtype: int64

# %%
y = df['population']

y
# Out:
# 0     181413402
# 1     184591903
# 2     187739786
# 3     190851175
# 4     193917462
# 5     196934260
# 6     199901228
# 7     202826446
# 8     205724592
# 9     208615169
# 10    211513823
# 11    214427417
# 12    217357793
# 13    220309469
# 14    223285676
# 15    226289470
# 16    229318262
# 17    232374245
# 18    235469762
# 19    238620563
# 20    241834215
# 21    245116206
# 22    248452413
# 23    251806402
# 24    255129004
# 25    258383256
# 26    261554226
# 27    264645886
# 28    267670549
# 29    270625567
# Name: population, dtype: int64

# %%
x.corr(y)
# Out:
# 0.9981456849530298

# %%
x.corr(y, method = 'spearman')
# Out:
# 1.0

# %%
x.corr(y, method = 'kendall')
# Out:
# 1.0

# %%
x.corr(y, method = 'pearson')
# Out:
# 0.9981456849530298

# %%
data = df.corr()

data
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23228\3924715615.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = df.corr()
#                              Year  Cardiovascular Diseases  population
# Year                     1.000000                 0.997660    0.999774
# Cardiovascular Diseases  0.997660                 1.000000    0.998146
# population               0.999774                 0.998146    1.000000

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 20)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path, size = 25)

# %%
sns.jointplot(ax = ax, data = df, y = df['Cardiovascular Diseases'], x = df['population'], height = 7, kind = 'reg', color = '#206261')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Populasi di Indonesia\nTahun 1990 - 2019', pad = 90, fontproperties = font1)
plt.xlabel('Population', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23228\1683082624.py:1: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(ax = ax, data = df, y = df['Cardiovascular Diseases'], x = df['population'], height = 7, kind = 'reg', color = '#206261')

# %%
plt.figure(figsize = (14,5))

sns.barplot(data = df, y = df['Cardiovascular Diseases'], x = df['Year'], palette = 'flare')

plt.title('Perkembangan Kematian Akibat Kardiovaskuler di Indonesia Tahun 1990 - 2019', fontproperties = font5)
plt.xlabel('Population', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
plt.figure(figsize = (14,5))

sns.barplot(data = df, y = df['population'], x = df['Year'], palette = 'crest')

plt.title('Perkembangan Populasi di Indonesia Tahun 1990 - 2019', fontproperties = font5)
plt.xlabel('Population', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()
