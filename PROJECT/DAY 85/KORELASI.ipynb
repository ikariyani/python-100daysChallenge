# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "meat.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#        Entity  Year  kardio  Mutton and Goat (kilograms per year)  \
# 0   Indonesia  1990  278302                                  0.51
# 1   Indonesia  1991  285751                                  0.52
# 2   Indonesia  1992  294517                                  0.54
# 3   Indonesia  1993  303860                                  0.59
# 4   Indonesia  1994  312544                                  0.52
# 5   Indonesia  1995  321557                                  0.49
# 6   Indonesia  1996  331193                                  0.50
# 7   Indonesia  1997  342414                                  0.54
# 8   Indonesia  1998  354220                                  0.40
# 9   Indonesia  1999  366292                                  0.38
# 10  Indonesia  2000  380554                                  0.38
# 11  Indonesia  2001  394941                                  0.44
# 12  Indonesia  2002  410020                                  0.59
# ...

# %%
df.describe()
# Out:
#               Year         kardio  Mutton and Goat (kilograms per year)  \
# count    28.000000      28.000000                             28.000000
# mean   2003.500000  439153.785714                              0.496071
# std       8.225975  111570.449979                              0.071406
# min    1990.000000  278302.000000                              0.380000
# 25%    1996.750000  339608.750000                              0.455000
# 50%    2003.500000  432467.500000                              0.495000
# 75%    2010.250000  530614.000000                              0.540000
# max    2017.000000  626883.000000                              0.660000
#
#        Other meats (kilograms per person)  Poultry (kilograms per year)  \
# count                           28.000000                     28.000000
# mean                             0.013571                      5.215000
# std                              0.009114                      1.441569
# ...

# %%
x = df['kardio']

x
# Out:
# 0     278302
# 1     285751
# 2     294517
# 3     303860
# 4     312544
# 5     321557
# 6     331193
# 7     342414
# 8     354220
# 9     366292
# 10    380554
# 11    394941
# 12    410020
# 13    424879
# 14    440056
# 15    455437
# 16    469704
# 17    484163
# 18    500374
# 19    514806
# 20    527322
# 21    540490
# 22    558106
# 23    573039
# 24    587184
# 25    603096
# 26    614602
# 27    626883
# Name: kardio, dtype: int64

# %%
domba = df['Mutton and Goat (kilograms per year)']

domba
# Out:
# 0     0.51
# 1     0.52
# 2     0.54
# 3     0.59
# 4     0.52
# 5     0.49
# 6     0.50
# 7     0.54
# 8     0.40
# 9     0.38
# 10    0.38
# 11    0.44
# 12    0.59
# 13    0.66
# 14    0.56
# 15    0.53
# 16    0.62
# 17    0.52
# 18    0.49
# 19    0.54
# 20    0.48
# 21    0.47
# 22    0.46
# 23    0.46
# 24    0.41
# 25    0.41
# 26    0.42
# 27    0.46
# Name: Mutton and Goat (kilograms per year), dtype: float64

# %%
lainnya = df['Other meats (kilograms per person)']

lainnya
# Out:
# 0     0.01
# 1     0.01
# 2     0.01
# 3     0.01
# 4     0.01
# 5     0.01
# 6     0.01
# 7     0.01
# 8     0.01
# 9     0.01
# 10    0.01
# 11    0.01
# 12    0.01
# 13    0.01
# 14    0.01
# 15    0.03
# 16    0.03
# 17    0.05
# 18    0.02
# 19    0.01
# 20    0.01
# 21    0.02
# 22    0.01
# 23    0.01
# 24    0.01
# 25    0.01
# 26    0.01
# 27    0.01
# Name: Other meats (kilograms per person), dtype: float64

# %%
unggas = df['Poultry (kilograms per year)']

unggas
# Out:
# 0     2.85
# 1     3.21
# 2     3.50
# 3     3.72
# 4     4.31
# 5     4.52
# 6     4.82
# 7     4.50
# 8     3.05
# 9     3.04
# 10    3.98
# 11    4.36
# 12    5.13
# 13    5.21
# 14    5.49
# 15    5.13
# 16    5.66
# 17    5.83
# 18    5.92
# 19    6.04
# 20    6.51
# 21    6.95
# 22    7.16
# 23    7.50
# 24    6.40
# 25    6.62
# 26    7.42
# 27    7.19
# Name: Poultry (kilograms per year), dtype: float64

# %%
babi = df['Pigmeat (kilograms per year)']

babi
# Out:
# 0     3.06
# 1     3.17
# 2     3.17
# 3     3.31
# 4     3.46
# 5     2.95
# 6     3.04
# 7     3.17
# 8     3.06
# 9     2.67
# 10    1.98
# 11    1.97
# 12    2.16
# 13    2.23
# 14    2.19
# 15    2.46
# 16    2.60
# 17    2.59
# 18    2.73
# 19    2.73
# 20    2.89
# 21    2.96
# 22    2.96
# 23    2.98
# 24    1.14
# 25    1.25
# 26    1.27
# 27    1.24
# Name: Pigmeat (kilograms per year), dtype: float64

# %%
sapi = df['Beef and bufallo (kilograms per year)']

sapi
# Out:
# 0     1.72
# 1     1.73
# 2     1.88
# 3     2.14
# 4     2.05
# 5     1.90
# 6     2.10
# 7     2.16
# 8     1.97
# 9     1.86
# 10    2.02
# 11    1.91
# 12    1.81
# 13    1.95
# 14    2.28
# 15    1.89
# 16    2.08
# 17    1.88
# 18    2.09
# 19    2.23
# 20    2.43
# 21    2.46
# 22    2.38
# 23    2.59
# 24    2.39
# 25    2.27
# 26    2.61
# 27    2.79
# Name: Beef and bufallo (kilograms per year), dtype: float64

# %%
x.corr(domba)
# Out:
# -0.2922572759836146

# %%
x.corr(lainnya)
# Out:
# 0.15889625602393112

# %%
x.corr(unggas)
# Out:
# 0.9298344865737715

# %%
x.corr(babi)
# Out:
# -0.6447661072029567

# %%
x.corr(sapi)
# Out:
# 0.7925283430951106

# %%
y = df['total consumption']

y.astype('int64')
# Out:
# 0      8
# 1      8
# 2      9
# 3      9
# 4     10
# 5      9
# 6     10
# 7     10
# 8      8
# 9      7
# 10     8
# 11     8
# 12     9
# 13    10
# 14    10
# 15    10
# 16    10
# 17    10
# 18    11
# 19    11
# 20    12
# 21    12
# 22    12
# 23    13
# 24    10
# 25    10
# 26    11
# 27    11
# Name: total consumption, dtype: int64

# %%
x.corr(y)
# Out:
# 0.7423528083172781

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 25)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 15.98)

# %%
sns.jointplot(data = df, y = df['kardio'], x = df['total consumption'], height = 7, kind = 'reg', color = '#7f4042')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Total Konsumsi Daging di Indonesia\nTahun 1990 - 2017', pad = 90, fontproperties = font1)
plt.xlabel('Per Capita Meat Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.set({'figure.figsize':(16,5)})
sns.set_theme(style='white')

sns.barplot(data = df, x = df['Year'], y = df['total consumption'], palette = 'YlOrBr')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler dengan Total Konsumsi Daging di Indonesia\nTahun 1990 - 2017', pad = 20, fontproperties = font1)
plt.xlabel('Per Capita Meat Consumption (kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted', axis = 'y')

plt.show()

# %%
plt.figure(figsize = (14,6))

keterangan = ['Domba', 'Unggas', 'Babi', 'Sapi', 'Lainnya']

plt.barh(df['Year'], b, label = 'Daging Domba', color = '#238a3c')
plt.barh(df['Year'], c, left = b, label = 'Daging Unggas', color = '#92bd54')
plt.barh(df['Year'], d, left = b + c, label = 'Daging Babi', color = '#dadb9d')
plt.barh(df['Year'], e, left = b + c + d, label = 'Daging Sapi', color = '#c23119')
plt.barh(df['Year'], f, left = b + c + d + e, label = 'Lainnya', color = '#d99a4e')

plt.title('Tingkat Konsumsi Beberapa Jenis Daging di Indonesia Tahun 1990 - 2017', pad = 50, fontproperties = font1)
plt.xlabel('Per Capita Meat Consumption (%)', fontproperties = font2)
plt.ylabel('Tahun', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(np.arange(1990, 2018,2), fontproperties = font3)

plt.legend(bbox_to_anchor=(-0.011,0.99),  loc='lower left', ncols = len(keterangan), prop = font5)
plt.grid(linestyle = 'dotted', axis = 'y')

plt.show()

# %%
b = df['Mutton and Goat (kilograms per year)'] / df['total consumption'] * 100

b
# Out:
# 0     6.257669
# 1     6.018519
# 2     5.934066
# 3     6.038895
# 4     5.024155
# 5     4.964539
# 6     4.775549
# 7     5.202312
# 8     4.711425
# 9     4.773869
# 10    4.540024
# 11    5.063291
# 12    6.082474
# 13    6.560636
# 14    5.318139
# 15    5.278884
# 16    5.641492
# 17    4.783809
# 18    4.355556
# 19    4.675325
# 20    3.896104
# 21    3.654743
# 22    3.546646
# 23    3.397341
# 24    3.961353
# 25    3.882576
# 26    3.580563
# 27    3.934987
# dtype: float64

# %%
f = df['Other meats (kilograms per person)'] / df['total consumption'] * 100

f
# Out:
# 0     0.122699
# 1     0.115741
# 2     0.109890
# 3     0.102354
# 4     0.096618
# 5     0.101317
# 6     0.095511
# 7     0.096339
# 8     0.117786
# 9     0.125628
# 10    0.119474
# 11    0.115075
# 12    0.103093
# 13    0.099404
# 14    0.094967
# 15    0.298805
# 16    0.272975
# 17    0.459982
# 18    0.177778
# 19    0.086580
# 20    0.081169
# 21    0.155521
# 22    0.077101
# 23    0.073855
# 24    0.096618
# 25    0.094697
# 26    0.085251
# 27    0.085543
# dtype: float64

# %%
c = df['Poultry (kilograms per year)'] / df['total consumption'] * 100

c
# Out:
# 0     34.969325
# 1     37.152778
# 2     38.461538
# 3     38.075742
# 4     41.642512
# 5     45.795339
# 6     46.036294
# 7     43.352601
# 8     35.924617
# 9     38.190955
# 10    47.550777
# 11    50.172612
# 12    52.886598
# 13    51.789264
# 14    52.136752
# 15    51.095618
# 16    51.501365
# 17    53.633855
# 18    52.622222
# 19    52.294372
# 20    52.840909
# 21    54.043546
# 22    55.204318
# 23    55.391433
# 24    61.835749
# 25    62.689394
# 26    63.256607
# 27    61.505560
# dtype: float64

# %%
d = df['Pigmeat (kilograms per year)'] / df['total consumption'] * 100

d
# Out:
# 0     37.546012
# 1     36.689815
# 2     34.835165
# 3     33.879222
# 4     33.429952
# 5     29.888551
# 6     29.035339
# 7     30.539499
# 8     36.042403
# 9     33.542714
# 10    23.655914
# 11    22.669735
# 12    22.268041
# 13    22.166998
# 14    20.797721
# 15    24.501992
# 16    23.657871
# 17    23.827047
# 18    24.266667
# 19    23.636364
# 20    23.457792
# 21    23.017107
# 22    22.821897
# 23    22.008863
# 24    11.014493
# 25    11.837121
# 26    10.826939
# 27    10.607357
# dtype: float64

# %%
e = df['Beef and bufallo (kilograms per year)'] / df['total consumption'] * 100

e
# Out:
# 0     21.104294
# 1     20.023148
# 2     20.659341
# 3     21.903787
# 4     19.806763
# 5     19.250253
# 6     20.057307
# 7     20.809249
# 8     23.203769
# 9     23.366834
# 10    24.133811
# 11    21.979287
# 12    18.659794
# 13    19.383698
# 14    21.652422
# 15    18.824701
# 16    18.926297
# 17    17.295308
# 18    18.577778
# 19    19.307359
# 20    19.724026
# 21    19.129082
# 22    18.350039
# 23    19.128508
# 24    23.091787
# 25    21.496212
# 26    22.250639
# 27    23.866553
# dtype: float64

# %%
sns.jointplot(data = df, x = df['Mutton and Goat (kilograms per year)'], y = df['kardio'], kind = 'reg', color = '#344c11')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Tingkat Konsumsi Daging Domba dan Kambing di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.xlabel('Per Capita Mutton and Goat Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['Other meats (kilograms per person)'], y = df['kardio'], kind = 'reg', color = '#235347')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Tingkat Konsumsi Daging Lainnya di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.xlabel('Per Capita Other Meats Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['Poultry (kilograms per year)'], y = df['kardio'], kind = 'reg', color = '#0b3453')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Tingkat Konsumsi Daging Unggas di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.xlabel('Per Capita Poultry Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['Pigmeat (kilograms per year)'], y = df['kardio'], kind = 'reg', color = '#66523a')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Tingkat Konsumsi Daging Babi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.xlabel('Per Capita Pigmeat Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['Beef and bufallo (kilograms per year)'], y = df['kardio'], kind = 'reg', color = '#941d26')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Tingkat Konsumsi Daging Sapi dan Kerbau di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.xlabel('Per Capita Beef and Bufallo Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()
