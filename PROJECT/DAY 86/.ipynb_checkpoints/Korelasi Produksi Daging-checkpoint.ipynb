# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "meat.csv"

df = pd.read_csv(file, sep = ';')

df
# Out:
#        Entity  Year  kardio  Mutton and Goat (kilograms per year)  \
# 0   Indonesia  1990  278302                                  0.51
# 1   Indonesia  1991  285751                                  0.52
# 2   Indonesia  1992  294517                                  0.54
# 3   Indonesia  1993  303860                                  0.59
# 4   Indonesia  1994  312544                                  0.52
# 5   Indonesia  1995  321557                                  0.49
# 6   Indonesia  1996  331193                                  0.50
# 7   Indonesia  1997  342414                                  0.54
# 8   Indonesia  1998  354220                                  0.40
# 9   Indonesia  1999  366292                                  0.38
# 10  Indonesia  2000  380554                                  0.38
# 11  Indonesia  2001  394941                                  0.44
# 12  Indonesia  2002  410020                                  0.59
# ...

# %%
unggas_con = df['Poultry (kilograms per year)']

unggas_con
# Out:
# 0     2.85
# 1     3.21
# 2     3.50
# 3     3.72
# 4     4.31
# 5     4.52
# 6     4.82
# 7     4.50
# 8     3.05
# 9     3.04
# 10    3.98
# 11    4.36
# 12    5.13
# 13    5.21
# 14    5.49
# 15    5.13
# 16    5.66
# 17    5.83
# 18    5.92
# 19    6.04
# 20    6.51
# 21    6.95
# 22    7.16
# 23    7.50
# 24    6.40
# 25    6.62
# 26    7.42
# 27    7.19
# Name: Poultry (kilograms per year), dtype: float64

# %%
unggas_prod = df['poultry (Ton)']

unggas_prod
# Out:
# 0      508700
# 1      583500
# 2      646600
# 3      698634
# 4      822675
# 5      875700
# 6      946979
# 7      898636
# 8      620521
# 9      620184
# 10     817740
# 11     923520
# 12    1104790
# 13    1138960
# 14    1213121
# 15    1147060
# 16    1284679
# 17    1339925
# 18    1380480
# 19    1430180
# 20    1565600
# 21    1693021
# 22    1767621
# 23    1872482
# 24    1972405
# 25    2065738
# 26    2342634
# 27    2301395
# Name: poultry (Ton), dtype: int64

# %%
unggas_con.corr(unggas_prod)
# Out:
# 0.9512990748640643

# %%
sapi_con = df['Beef and bufallo (kilograms per year)']

sapi_con
# Out:
# 0     1.72
# 1     1.73
# 2     1.88
# 3     2.14
# 4     2.05
# 5     1.90
# 6     2.10
# 7     2.16
# 8     1.97
# 9     1.86
# 10    2.02
# 11    1.91
# 12    1.81
# 13    1.95
# 14    2.28
# 15    1.89
# 16    2.08
# 17    1.88
# 18    2.09
# 19    2.23
# 20    2.43
# 21    2.46
# 22    2.38
# 23    2.59
# 24    2.39
# 25    2.27
# 26    2.61
# 27    2.79
# Name: Beef and bufallo (kilograms per year), dtype: float64

# %%
cons = df['total consumption']

cons
# Out:
# 0      8.15
# 1      8.64
# 2      9.10
# 3      9.77
# 4     10.35
# 5      9.87
# 6     10.47
# 7     10.38
# 8      8.49
# 9      7.96
# 10     8.37
# 11     8.69
# 12     9.70
# 13    10.06
# 14    10.53
# 15    10.04
# 16    10.99
# 17    10.87
# 18    11.25
# 19    11.55
# 20    12.32
# 21    12.86
# 22    12.97
# 23    13.54
# 24    10.35
# 25    10.56
# 26    11.73
# 27    11.69
# Name: total consumption, dtype: float64

# %%
prod = df['total production']

prod
# Out:
# 0     1356700
# 1     1465200
# 2     1571600
# 3     1717646
# 4     1867332
# 5     1807162
# 6     1942344
# 7     1932139
# 8     1630963
# 9     1527060
# 10    1616035
# 11    1723849
# 12    1944889
# 13    2044310
# 14    1895614
# 15    1717486
# 16    1920391
# 17    1950066
# 18    2021800
# 19    2074253
# 20    2249957
# 21    2438485
# 22    2545634
# 23    2713577
# 24    2807599
# 25    2938022
# 26    3232632
# 27    3209659
# Name: total production, dtype: int64

# %%
cons.corr(prod)
# Out:
# 0.7214628797405429

# %%
sapi_prod = df['beef and buffalo (Ton)']

sapi_prod
# Out:
# 0     303500
# 1     309700
# 2     342000
# 3     397512
# 4     384657
# 5     359462
# 6     395865
# 7     401003
# 8     388942
# 9     356876
# 10    385795
# 11    382329
# 12    372599
# 13    410350
# 14    487810
# 15    396757
# 16    439729
# 17    381236
# 18    431543
# 19    443955
# 20    472364
# 21    520664
# 22    545870
# 23    542655
# 24    532907
# 25    542071
# 26    550389
# 27    564017
# Name: beef and buffalo (Ton), dtype: int64

# %%
df['total production'] = df[['beef and buffalo (Ton)', 'poultry (Ton)', 'pigmeat (Ton)']].sum(axis = 1)

df
# Out:
#        Entity  Year  kardio  Mutton and Goat (kilograms per year)  \
# 0   Indonesia  1990  278302                                  0.51
# 1   Indonesia  1991  285751                                  0.52
# 2   Indonesia  1992  294517                                  0.54
# 3   Indonesia  1993  303860                                  0.59
# 4   Indonesia  1994  312544                                  0.52
# 5   Indonesia  1995  321557                                  0.49
# 6   Indonesia  1996  331193                                  0.50
# 7   Indonesia  1997  342414                                  0.54
# 8   Indonesia  1998  354220                                  0.40
# 9   Indonesia  1999  366292                                  0.38
# 10  Indonesia  2000  380554                                  0.38
# 11  Indonesia  2001  394941                                  0.44
# 12  Indonesia  2002  410020                                  0.59
# ...

# %%
df.describe()
# Out:
#               Year         kardio  Mutton and Goat (kilograms per year)  \
# count    28.000000      28.000000                             28.000000
# mean   2003.500000  439153.785714                              0.496071
# std       8.225975  111570.449979                              0.071406
# min    1990.000000  278302.000000                              0.380000
# 25%    1996.750000  339608.750000                              0.455000
# 50%    2003.500000  432467.500000                              0.495000
# 75%    2010.250000  530614.000000                              0.540000
# max    2017.000000  626883.000000                              0.660000
#
#        Other meats (kilograms per person)  Poultry (kilograms per year)  \
# count                           28.000000                     28.000000
# mean                             0.013571                      5.215000
# std                              0.009114                      1.441569
# ...

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 25)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path, size = 20)
font5 = fm.FontProperties(fname = path2, size = 15.98)

# %%
sapi_con.corr(sapi_prod)
# Out:
# 0.931310672741051

# %%
plt.figure(figsize = (10,4))

plt.bar(df['Year'] , df['beef and buffalo (Ton)'], color = '#344c11')


plt.title('Tingkat Produksi Daging Tahun 1990 - 2017', pad = 20, fontproperties = font1)
plt.xlabel('Tahun', fontproperties = font2)
plt.ylabel('Produksi Daging', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sapi = df['beef and buffalo (Ton)'] / df['total production'] * 100

sapi
# Out:
# 0     22.370458
# 1     21.137046
# 2     21.761262
# 3     23.142836
# 4     20.599283
# 5     19.890967
# 6     20.380787
# 7     20.754356
# 8     23.847383
# 9     23.370136
# 10    23.872936
# 11    22.178799
# 12    19.157854
# 13    20.072787
# 14    25.733615
# 15    23.101033
# 16    22.897889
# 17    19.549902
# 18    21.344495
# 19    21.403127
# 20    20.994357
# 21    21.351946
# 22    21.443381
# 23    19.997774
# 24    18.980880
# 25    18.450202
# 26    17.026033
# 27    17.572490
# dtype: float64

# %%
unggas = df['poultry (Ton)'] / df['total production'] * 100

unggas
# Out:
# 0     37.495393
# 1     39.823915
# 2     41.142784
# 3     40.673922
# 4     44.056172
# 5     48.457194
# 6     48.754443
# 7     46.509904
# 8     38.046295
# 9     40.612943
# 10    50.601627
# 11    53.573138
# 12    56.804784
# 13    55.713664
# 14    63.996204
# 15    66.787153
# 16    66.896741
# 17    68.711777
# 18    68.279751
# 19    68.949159
# 20    69.583552
# 21    69.429215
# 22    69.437358
# 23    69.004196
# 24    70.252376
# 25    70.310501
# 26    72.468317
# 27    71.702165
# dtype: float64

# %%
pigmeat = df['pigmeat (Ton)'] / df['total production'] * 100

pigmeat
# Out:
# 0     40.134149
# 1     39.039039
# 2     37.095953
# 3     36.183241
# 4     35.344545
# 5     31.651839
# 6     30.864770
# 7     32.735740
# 8     38.106321
# 9     36.016921
# 10    25.525437
# 11    24.248063
# 12    24.037362
# 13    24.213549
# 14    10.270182
# 15    10.111815
# 16    10.205370
# 17    11.738321
# 18    10.375754
# 19     9.647714
# 20     9.422091
# 21     9.218839
# 22     9.119261
# 23    10.998030
# 24    10.766744
# 25    11.239296
# 26    10.505650
# 27    10.725345
# dtype: float64

# %%
plt.figure(figsize = (14,6))

keterangan = ['Unggas', 'Babi', 'Sapi']

plt.barh(df['Year'], sapi, label = 'Daging Sapi/Kerbau', color = '#406c35')
plt.barh(df['Year'], unggas, left = sapi, label = 'Daging Unggas', color = '#ceba9f')
plt.barh(df['Year'], pigmeat, left = sapi + unggas, label = 'Daging Babi', color = '#4f0205')


plt.title('Tingkat Produksi Beberapa Jenis Daging di Indonesia Tahun 1990 - 2017', pad = 50, fontproperties = font1)
plt.xlabel('Meat Production (%)', fontproperties = font2)
plt.ylabel('Tahun', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(np.arange(1990, 2018,2), fontproperties = font3)

plt.legend(bbox_to_anchor=(0.5,1.05),  loc='center', ncols = len(keterangan), prop = font5)
plt.grid(linestyle = 'dotted', axis = 'y')

plt.show()

# %%
sns.jointplot(data = df, x = df['total consumption'], y = df['total production'], kind = 'reg', color = '#344c11')

plt.title('Korelasi Antara Tingkat Konsumsi Daging\ndengan Tingkat Produksi Daging di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font4)
plt.xlabel('Total Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Total Production (Ton)', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['total consumption'], y = df['poultry (Ton)'], kind = 'reg', color = '#0b3453')

plt.title('Korelasi Antara Tingkat Konsumsi\ndengan Tingkat Produksi Daging Unggas di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font4)
plt.xlabel('Per Capita Poultry Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Poultry Production (Ton)', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = df, x = df['Beef and bufallo (kilograms per year)'], y = df['beef and buffalo (Ton)'], kind = 'reg', color = '#3d2418')

plt.title('Korelasi Antara Tingkat Konsumsi\ndengan Tingkat Produksi Daging Sapi/Kerbau di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font4)
plt.xlabel('Per Capita Beef and Bufallo Consumption\n(kg/year)', fontproperties = font2)
plt.ylabel('Beef and Bufallo Production (Ton)', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()
