# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file1 = "cause_of_deaths.csv"

df1 = pd.read_csv(file1, sep = ';')

pd.set_option('display.max_columns', None)

df1
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
indo = df1.loc[df1['Country/Territory'] == 'Indonesia']

indo
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 2460         Indonesia  IDN  1990       19261
# 2461         Indonesia  IDN  1991       18316
# 2462         Indonesia  IDN  1992       17432
# 2463         Indonesia  IDN  1993       16722
# 2464         Indonesia  IDN  1994       16025
# 2465         Indonesia  IDN  1995       15296
# 2466         Indonesia  IDN  1996       14587
# 2467         Indonesia  IDN  1997       14036
# 2468         Indonesia  IDN  1998       13744
# 2469         Indonesia  IDN  1999       13254
# 2470         Indonesia  IDN  2000       12754
# 2471         Indonesia  IDN  2001       12514
# 2472         Indonesia  IDN  2002       12168
# 2473         Indonesia  IDN  2003       11761
# 2474         Indonesia  IDN  2004       11292
# 2475         Indonesia  IDN  2005       10825
# 2476         Indonesia  IDN  2006       10394
# 2477         Indonesia  IDN  2007       10001
# 2478         Indonesia  IDN  2008        9608
# ...

# %%
kardio = indo['Cardiovascular Diseases']

kardio
# Out:
# 2460    278302
# 2461    285751
# 2462    294517
# 2463    303860
# 2464    312544
# 2465    321557
# 2466    331193
# 2467    342414
# 2468    354220
# 2469    366292
# 2470    380554
# 2471    394941
# 2472    410020
# 2473    424879
# 2474    440056
# 2475    455437
# 2476    469704
# 2477    484163
# 2478    500374
# 2479    514806
# 2480    527322
# 2481    540490
# 2482    558106
# 2483    573039
# 2484    587184
# 2485    603096
# 2486    614602
# 2487    626883
# 2488    639224
# 2489    651481
# Name: Cardiovascular Diseases, dtype: int64

# %%
neoplasma = indo['Neoplasms']

neoplasma
# Out:
# 2460     95636
# 2461     98800
# 2462    102344
# 2463    105995
# 2464    109559
# 2465    113315
# 2466    117565
# 2467    121912
# 2468    126010
# 2469    130040
# 2470    134197
# 2471    137844
# 2472    141586
# 2473    145558
# 2474    149842
# 2475    154637
# 2476    159526
# 2477    164406
# 2478    168946
# 2479    173532
# 2480    177788
# 2481    183379
# 2482    188339
# 2483    193469
# 2484    198139
# 2485    202962
# 2486    209282
# 2487    215810
# 2488    222732
# 2489    229524
# Name: Neoplasms, dtype: int64

# %%
digestif = indo['Digestive Diseases']

digestif
# Out:
# 2460     84478
# 2461     85907
# 2462     87620
# 2463     89351
# 2464     90948
# 2465     92536
# 2466     94020
# 2467     95493
# 2468     97113
# 2469     98675
# 2470    100417
# 2471    102057
# 2472    103910
# 2473    105740
# 2474    107711
# 2475    109735
# 2476    111360
# 2477    112629
# 2478    113979
# 2479    115272
# 2480    116137
# 2481    117524
# 2482    118387
# 2483    119354
# 2484    120212
# 2485    119335
# 2486    120717
# 2487    123121
# 2488    124701
# 2489    126348
# Name: Digestive Diseases, dtype: int64

# %%
tbc = indo['Tuberculosis']

tbc
# Out:
# 2460    128009
# 2461    125100
# 2462    123350
# 2463    122167
# 2464    120251
# 2465    118083
# 2466    115789
# 2467    115176
# 2468    116838
# 2469    117608
# 2470    117563
# 2471    117026
# 2472    116569
# 2473    115703
# 2474    114201
# 2475    112034
# 2476    110253
# 2477    109058
# 2478    106904
# 2479    104609
# 2480    101631
# 2481     97484
# 2482     92813
# 2483     89584
# 2484     86953
# 2485     83909
# 2486     82533
# 2487     80770
# 2488     78494
# 2489     76549
# Name: Tuberculosis, dtype: int64

# %%
diare = indo['Diarrheal Diseases']

diare
# Out:
# 2460    133685
# 2461    126918
# 2462    121095
# 2463    115849
# 2464    111085
# 2465    106166
# 2466    101048
# 2467     96922
# 2468     94441
# 2469     91996
# 2470     90092
# 2471     89040
# 2472     88060
# 2473     86467
# 2474     84928
# 2475     83441
# 2476     81466
# 2477     79695
# 2478     77723
# 2479     75605
# 2480     72855
# 2481     70271
# 2482     68494
# 2483     66978
# 2484     65593
# 2485     64578
# 2486     63106
# 2487     62584
# 2488     60886
# 2489     59589
# Name: Diarrheal Diseases, dtype: int64

# %%
populasi = indo['population']

populasi
# Out:
# 2460    181413402.0
# 2461    184591903.0
# 2462    187739786.0
# 2463    190851175.0
# 2464    193917462.0
# 2465    196934260.0
# 2466    199901228.0
# 2467    202826446.0
# 2468    205724592.0
# 2469    208615169.0
# 2470    211513823.0
# 2471    214427417.0
# 2472    217357793.0
# 2473    220309469.0
# 2474    223285676.0
# 2475    226289470.0
# 2476    229318262.0
# 2477    232374245.0
# 2478    235469762.0
# 2479    238620563.0
# 2480    241834215.0
# 2481    245116206.0
# 2482    248452413.0
# 2483    251806402.0
# 2484    255129004.0
# 2485    258383256.0
# 2486    261554226.0
# 2487    264645886.0
# 2488    267663435.0
# 2489    270625568.0
# Name: population, dtype: float64

# %%
populasi = indo['population'].astype('int')

populasi
# Out:
# 2460    181413402
# 2461    184591903
# 2462    187739786
# 2463    190851175
# 2464    193917462
# 2465    196934260
# 2466    199901228
# 2467    202826446
# 2468    205724592
# 2469    208615169
# 2470    211513823
# 2471    214427417
# 2472    217357793
# 2473    220309469
# 2474    223285676
# 2475    226289470
# 2476    229318262
# 2477    232374245
# 2478    235469762
# 2479    238620563
# 2480    241834215
# 2481    245116206
# 2482    248452413
# 2483    251806402
# 2484    255129004
# 2485    258383256
# 2486    261554226
# 2487    264645886
# 2488    267663435
# 2489    270625568
# Name: population, dtype: int32

# %%
kardio.corr(populasi)
# Out:
# 0.9981456908307613

# %%
neoplasma.corr(populasi)
# Out:
# 0.9981164209169004

# %%
digestif.corr(populasi)
# Out:
# 0.991004636751259

# %%
tbc.corr(populasi)
# Out:
# -0.9574917636615932

# %%
diare.corr(populasi)
# Out:
# -0.9669751501676609

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 20)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path4, size = 10)
font5 = fm.FontProperties(fname = path2, size = 15.98)

# %%
sns.jointplot(data = indo, y = indo['Cardiovascular Diseases'], x = indo['population'], kind = 'reg', color = '#6e6456')

plt.title('Korelasi Antara Kematian Akibat Kardiovaskuler\ndengan Populasi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.ylabel('Cardiovascular Diseases', fontproperties = font2)
plt.xlabel('Population', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = indo, y = indo['Neoplasms'], x = indo['population'], kind = 'reg', color = '#140850')

plt.title('Korelasi Antara Kematian Akibat Neoplasma\ndengan Populasi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.ylabel('Neoplasms', fontproperties = font2)
plt.xlabel('Population', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = indo, y = indo['Digestive Diseases'], x = indo['population'], kind = 'reg', color = '#235347')

plt.title('Korelasi Antara Kematian Akibat Gangguan Pencernaan\ndengan Populasi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.ylabel('Digestive Diseases', fontproperties = font2)
plt.xlabel('Population', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = indo, y = indo['Tuberculosis'], x = indo['population'], kind = 'reg', color = '#500302')

plt.title('Korelasi Antara Kematian Akibat Tuberkulosis\ndengan Populasi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.ylabel('Tuberculosis', fontproperties = font2)
plt.xlabel('Population', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = indo, y = indo['Diarrheal Diseases'], x = indo['population'], kind = 'reg', color = '#0b3453')

plt.title('Korelasi Antara Kematian Akibat Penyakit Diare\ndengan Populasi di Indonesia\nTahun 1990 - 2017', pad = 80, fontproperties = font1)
plt.ylabel('Diarrheal Diseases', fontproperties = font2)
plt.xlabel('Population', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()
