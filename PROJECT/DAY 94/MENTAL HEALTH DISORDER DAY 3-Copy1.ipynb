# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "prevalence-by-mental-and-substance-use-disorder.csv"

df = pd.read_csv(file)

df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                              0.228979
# 1                                              0.228120
# 2                                              0.227328
# 3                                              0.226468
# 4                                              0.225567
# ...                                                 ...
# 6835                                           0.209359
# 6836                                           0.209979
# 6837                                           0.210631
# ...

# %%
df = df.loc[(df['Entity'] == 'Indonesia') |
       (df['Entity'] == 'India')]

df
# Out:
#          Entity Code  Year  \
# 2640      India  IND  1990
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2670  Indonesia  IDN  1990
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# ...

# %%
df.dtypes
# Out:
# Entity                                                                               object
# Code                                                                                 object
# Year                                                                                  int64
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)            float64
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)         float64
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)         float64
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)        float64
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)       float64
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)     float64
# Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)    float64
# dtype: object

# %%
df.describe()
# Out:
#               Year  \
# count    60.000000
# mean   2004.500000
# std       8.728484
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          60.000000
# mean                                            0.291342
# std                                             0.006470
# min                                             0.283639
# 25%                                             0.284923
# 50%                                             0.291565
# 75%                                             0.296123
# max                                             0.306168
#
#        Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          60.000000
# mean                                            0.351284
# ...

# %%
df['Total'] = df.iloc[:, [3, 4, 5, 6, 7, 8, 9]].sum(axis = 1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20204\4234339984.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df.iloc[:, [3, 4, 5, 6, 7, 8, 9]].sum(axis = 1)

# %%
df
# Out:
#          Entity Code  Year  \
# 2640      India  IND  1990
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2670  Indonesia  IDN  1990
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# ...

# %%
india = df.loc[df['Entity'] == 'India']

india
# Out:
#    Entity Code  Year  \
# 0   India  IND  1990
# 1   India  IND  1991
# 2   India  IND  1992
# 3   India  IND  1993
# 4   India  IND  1994
# 5   India  IND  1995
# 6   India  IND  1996
# 7   India  IND  1997
# 8   India  IND  1998
# 9   India  IND  1999
# 10  India  IND  2000
# 11  India  IND  2001
# 12  India  IND  2002
# 13  India  IND  2003
# 14  India  IND  2004
# 15  India  IND  2005
# 16  India  IND  2006
# 17  India  IND  2007
# 18  India  IND  2008
# 19  India  IND  2009
# 20  India  IND  2010
# 21  India  IND  2011
# 22  India  IND  2012
# 23  India  IND  2013
# 24  India  IND  2014
# 25  India  IND  2015
# 26  India  IND  2016
# 27  India  IND  2017
# 28  India  IND  2018
# 29  India  IND  2019
#
#     Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                            0.283639
# 1                                            0.283902
# 2                                            0.284109
# ...

# %%
indo = df.loc[df['Entity'] == 'Indonesia']

indo
# Out:
#        Entity Code  Year  \
# 30  Indonesia  IDN  1990
# 31  Indonesia  IDN  1991
# 32  Indonesia  IDN  1992
# 33  Indonesia  IDN  1993
# 34  Indonesia  IDN  1994
# 35  Indonesia  IDN  1995
# 36  Indonesia  IDN  1996
# 37  Indonesia  IDN  1997
# 38  Indonesia  IDN  1998
# 39  Indonesia  IDN  1999
# 40  Indonesia  IDN  2000
# 41  Indonesia  IDN  2001
# 42  Indonesia  IDN  2002
# 43  Indonesia  IDN  2003
# 44  Indonesia  IDN  2004
# 45  Indonesia  IDN  2005
# 46  Indonesia  IDN  2006
# 47  Indonesia  IDN  2007
# 48  Indonesia  IDN  2008
# 49  Indonesia  IDN  2009
# 50  Indonesia  IDN  2010
# 51  Indonesia  IDN  2011
# 52  Indonesia  IDN  2012
# 53  Indonesia  IDN  2013
# 54  Indonesia  IDN  2014
# 55  Indonesia  IDN  2015
# 56  Indonesia  IDN  2016
# 57  Indonesia  IDN  2017
# 58  Indonesia  IDN  2018
# 59  Indonesia  IDN  2019
#
#     Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 30                                           0.286067
# ...

# %%
populasi = [[181413402, 184591903, 187739786, 190851175, 193917462, 196934260, 199901228, 202826446, 205724592, 208615169, 
            211513823, 214427417, 217357793, 220309469, 223285676, 226289470, 229318262, 232374245, 235469762, 238620563, 241834215, 
            245116206, 248452413, 251806402, 255129004, 258383256, 261554226, 264645886, 267663435, 270625568]]

# %%
df['Entity'].size
# Out:
# 60

# %%
file2 = "populasi.csv"

df2 = pd.read_csv(file2, sep = ';')

df2
# Out:
#    Country/Territory Code  Year  population
# 0              India  IDN  1990   873277798
# 1              India  IDN  1991   891273209
# 2              India  IDN  1992   909307016
# 3              India  IDN  1993   927403860
# 4              India  IDN  1994   945601831
# 5              India  IDN  1995   963922588
# 6              India  IDN  1996   982365243
# 7              India  IDN  1997  1000900030
# 8              India  IDN  1998  1019483581
# 9              India  IDN  1999  1038058156
# 10             India  IDN  2000  1056575549
# 11             India  IDN  2001  1075000085
# 12             India  IDN  2002  1093317189
# 13             India  IDN  2003  1111523144
# 14             India  IDN  2004  1129623456
# 15             India  IDN  2005  1147609927
# 16             India  IDN  2006  1165486291
# 17             India  IDN  2007  1183209472
# 18             India  IDN  2008  1200669765
# 19             India  IDN  2009  1217726215
# ...

# %%
populasi = df2['population']

# %%
populasi = populasi.astype('int64')

# %%
df2.dtypes
# Out:
# Country/Territory    object
# Code                 object
# Year                  int64
# population            int64
# dtype: object

# %%
merge = pd.merge(df,populasi, on = populasi, how = 'left')
pd.set_option('display.max_rows', None)

merge
# Out:
#          key_0     Entity Code  Year  \
# 0    873277798      India  IND  1990
# 1    891273209      India  IND  1991
# 2    909307016      India  IND  1992
# 3    927403860      India  IND  1993
# 4    945601831      India  IND  1994
# 5    963922588      India  IND  1995
# 6    982365243      India  IND  1996
# 7   1000900030      India  IND  1997
# 8   1019483581      India  IND  1998
# 9   1038058156      India  IND  1999
# 10  1056575549      India  IND  2000
# 11  1075000085      India  IND  2001
# 12  1093317189      India  IND  2002
# 13  1111523144      India  IND  2003
# 14  1129623456      India  IND  2004
# 15  1147609927      India  IND  2005
# 16  1165486291      India  IND  2006
# 17  1183209472      India  IND  2007
# 18  1200669765      India  IND  2008
# 19  1217726215      India  IND  2009
# 20  1234281170      India  IND  2010
# 21  1250288729      India  IND  2011
# 22  1265782790      India  IND  2012
# 23  1280846129      India  IND  2013
# ...

# %%
df = merge.drop(columns = ['key_0'])

df
# Out:
#        Entity Code  Year  \
# 0       India  IND  1990
# 1       India  IND  1991
# 2       India  IND  1992
# 3       India  IND  1993
# 4       India  IND  1994
# 5       India  IND  1995
# 6       India  IND  1996
# 7       India  IND  1997
# 8       India  IND  1998
# 9       India  IND  1999
# 10      India  IND  2000
# 11      India  IND  2001
# 12      India  IND  2002
# 13      India  IND  2003
# 14      India  IND  2004
# 15      India  IND  2005
# 16      India  IND  2006
# 17      India  IND  2007
# 18      India  IND  2008
# 19      India  IND  2009
# 20      India  IND  2010
# 21      India  IND  2011
# 22      India  IND  2012
# 23      India  IND  2013
# 24      India  IND  2014
# 25      India  IND  2015
# 26      India  IND  2016
# 27      India  IND  2017
# 28      India  IND  2018
# 29      India  IND  2019
# 30  Indonesia  IDN  1990
# 31  Indonesia  IDN  1991
# 32  Indonesia  IDN  1992
# 33  Indonesia  IDN  1993
# 34  Indonesia  IDN  1994
# ...

# %%
indo.describe()
# Out:
#               Year  \
# count    30.000000
# mean   2004.500000
# std       8.803408
# min    1990.000000
# 25%    1997.250000
# 50%    2004.500000
# 75%    2011.750000
# max    2019.000000
#
#        Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          30.000000
# mean                                            0.295926
# std                                             0.005266
# min                                             0.286067
# 25%                                             0.292396
# 50%                                             0.296157
# 75%                                             0.298735
# max                                             0.306168
#
#        Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          30.000000
# mean                                            0.341947
# ...

# %%
india.describe()
# Out:
#               Year  \
# count    30.000000
# mean   2004.500000
# std       8.803408
# min    1990.000000
# 25%    1997.250000
# 50%    2004.500000
# 75%    2011.750000
# max    2019.000000
#
#        Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          30.000000
# mean                                            0.286757
# std                                             0.003735
# min                                             0.283639
# 25%                                             0.284223
# 50%                                             0.284874
# 75%                                             0.288275
# max                                             0.294656
#
#        Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          30.000000
# mean                                            0.360621
# ...

# %%
indo
# Out:
#          Entity Code  Year  \
# 2670  Indonesia  IDN  1990
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# 2673  Indonesia  IDN  1993
# 2674  Indonesia  IDN  1994
# 2675  Indonesia  IDN  1995
# 2676  Indonesia  IDN  1996
# 2677  Indonesia  IDN  1997
# 2678  Indonesia  IDN  1998
# 2679  Indonesia  IDN  1999
# 2680  Indonesia  IDN  2000
# 2681  Indonesia  IDN  2001
# 2682  Indonesia  IDN  2002
# 2683  Indonesia  IDN  2003
# 2684  Indonesia  IDN  2004
# 2685  Indonesia  IDN  2005
# 2686  Indonesia  IDN  2006
# 2687  Indonesia  IDN  2007
# 2688  Indonesia  IDN  2008
# 2689  Indonesia  IDN  2009
# 2690  Indonesia  IDN  2010
# 2691  Indonesia  IDN  2011
# 2692  Indonesia  IDN  2012
# 2693  Indonesia  IDN  2013
# 2694  Indonesia  IDN  2014
# 2695  Indonesia  IDN  2015
# 2696  Indonesia  IDN  2016
# 2697  Indonesia  IDN  2017
# 2698  Indonesia  IDN  2018
# 2699  Indonesia  IDN  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
(indo['Total'].mean())/100*(indo['population'].mean())
# Out:
# 17352294.067236137

# %%
indo.loc[indo['Year'] == 2019]['Total']/100*indo.loc[indo['Year'] == 2019]['population']
# Out:
# 59    2.158015e+07
# dtype: float64

# %%
indo.loc[indo['Year'] == 1990]['Total']/100*indo.loc[indo['Year'] == 1990]['population']
# Out:
# 30    1.368708e+07
# dtype: float64

# %%
total_indo = indo.loc[indo['Year'] == 2019]['population']

total_indo
# Out:
# 59    270625568
# Name: population, dtype: int64

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 25)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path, size = 22)
font5 = fm.FontProperties(fname = path2, size = 12)
font6 = fm.FontProperties(fname = path2, size = 18)

# %%
plt.figure(figsize = (14,4))

plt.bar(india['Year'], india['Total'], color = '#445f3b', label = 'India')
plt.bar(indo['Year'], indo['Total'], color = '#8ea076', label = 'Indonesia')

plt.title('Tren Mental Health Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font1)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Mental Health Disorder (%)', fontproperties = font2)


plt.xticks(np.arange(1990, 2020, 2), fontproperties = font3)
plt.yticks(np.arange(0, 13, 1), fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (9,4))

plt.stem(indo['Year'], indo['Total'], label = 'Indonesia', basefmt = '#084c61', linefmt = '#084c61')

plt.title('Tren Mental Health Disorder di Indonesia Tahun 1990 - 2019', fontproperties = font6)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Mental Health Disorder (%)', fontproperties = font2)


plt.xticks(np.arange(1990, 2022, 2), fontproperties = font3)
plt.yticks(np.arange(0, 11, 1), fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (14,4))

sns.lineplot(data = df, x = df['Year'], y = df['Total'], color = '#445f3b')
plt.plot(india['Year'], india['Total'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Total'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Mental Health Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font1)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Mental Health Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Schizrophrenia di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Schizophrenia (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Bipolar Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Bipolar Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Eating Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Eating Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Anxiety Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Anxiety Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Drug Use Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Drug Use Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Depressive Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Depressive Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
plt.figure(figsize = (10,4))

sns.lineplot(data = df, x = df['Year'], y = df['Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#445f3b')
plt.plot(india['Year'], india['Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#941d26', label = 'India', marker = 'o', linestyle = '--')
plt.plot(indo['Year'], indo['Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'], color = '#1c4f6b', label = 'Indonesia', marker = 'o', linestyle = '--')


plt.title('Tren Alcohol Use Disorder di India dan Indonesia Tahun 1990 - 2019', fontproperties = font4)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Alcohol Use Disorder (%)', fontproperties = font2)


plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
df
# Out:
#        Entity Code  Year  \
# 0       India  IND  1990
# 1       India  IND  1991
# 2       India  IND  1992
# 3       India  IND  1993
# 4       India  IND  1994
# 5       India  IND  1995
# 6       India  IND  1996
# 7       India  IND  1997
# 8       India  IND  1998
# 9       India  IND  1999
# 10      India  IND  2000
# 11      India  IND  2001
# 12      India  IND  2002
# 13      India  IND  2003
# 14      India  IND  2004
# 15      India  IND  2005
# 16      India  IND  2006
# 17      India  IND  2007
# 18      India  IND  2008
# 19      India  IND  2009
# 20      India  IND  2010
# 21      India  IND  2011
# 22      India  IND  2012
# 23      India  IND  2013
# 24      India  IND  2014
# 25      India  IND  2015
# 26      India  IND  2016
# 27      India  IND  2017
# 28      India  IND  2018
# 29      India  IND  2019
# 30  Indonesia  IDN  1990
# 31  Indonesia  IDN  1991
# 32  Indonesia  IDN  1992
# 33  Indonesia  IDN  1993
# 34  Indonesia  IDN  1994
# ...
