# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "prevalence-by-mental-and-substance-use-disorder.csv"

df = pd.read_csv(file)

df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                              0.228979
# 1                                              0.228120
# 2                                              0.227328
# 3                                              0.226468
# 4                                              0.225567
# ...                                                 ...
# 6835                                           0.209359
# 6836                                           0.209979
# 6837                                           0.210631
# ...

# %%
df = df.loc[(df['Entity'] == 'Indonesia') |
       (df['Entity'] == 'India')]

df
# Out:
#          Entity Code  Year  \
# 2640      India  IND  1990
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2670  Indonesia  IDN  1990
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# ...

# %%
df = df.drop(index= [2640, 2670])

df
# Out:
#          Entity Code  Year  \
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# 2673  Indonesia  IDN  1993
# 2674  Indonesia  IDN  1994
# ...

# %%
df['Total'] = df.iloc[:, [3, 4, 5, 6, 7, 8, 9]].sum(axis = 1)

df
# Out:
#          Entity Code  Year  \
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# 2673  Indonesia  IDN  1993
# 2674  Indonesia  IDN  1994
# ...

# %%
df['ID'] = df['Code'].str.cat(df['Year'].astype('str'))

df
# Out:
#          Entity Code  Year  \
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# 2673  Indonesia  IDN  1993
# 2674  Indonesia  IDN  1994
# ...

# %%
file2 = "populasi.csv"

df2 = pd.read_csv(file2, sep = ';')

df2
# Out:
#    Country/Territory Code  Year  population
# 0              India  IDN  1990   873277798
# 1              India  IDN  1991   891273209
# 2              India  IDN  1992   909307016
# 3              India  IDN  1993   927403860
# 4              India  IDN  1994   945601831
# 5              India  IDN  1995   963922588
# 6              India  IDN  1996   982365243
# 7              India  IDN  1997  1000900030
# 8              India  IDN  1998  1019483581
# 9              India  IDN  1999  1038058156
# 10             India  IDN  2000  1056575549
# 11             India  IDN  2001  1075000085
# 12             India  IDN  2002  1093317189
# 13             India  IDN  2003  1111523144
# 14             India  IDN  2004  1129623456
# 15             India  IDN  2005  1147609927
# 16             India  IDN  2006  1165486291
# 17             India  IDN  2007  1183209472
# 18             India  IDN  2008  1200669765
# 19             India  IDN  2009  1217726215
# ...

# %%
df2 = df2.drop(index = [0,30])

df2
# Out:
#    Country/Territory Code  Year  population
# 1              India  IDN  1991   891273209
# 2              India  IDN  1992   909307016
# 3              India  IDN  1993   927403860
# 4              India  IDN  1994   945601831
# 5              India  IDN  1995   963922588
# 6              India  IDN  1996   982365243
# 7              India  IDN  1997  1000900030
# 8              India  IDN  1998  1019483581
# 9              India  IDN  1999  1038058156
# 10             India  IDN  2000  1056575549
# 11             India  IDN  2001  1075000085
# 12             India  IDN  2002  1093317189
# 13             India  IDN  2003  1111523144
# 14             India  IDN  2004  1129623456
# 15             India  IDN  2005  1147609927
# 16             India  IDN  2006  1165486291
# 17             India  IDN  2007  1183209472
# 18             India  IDN  2008  1200669765
# 19             India  IDN  2009  1217726215
# 20             India  IDN  2010  1234281170
# ...

# %%
df2.loc[df2['Country/Territory'] == 'India','Code'] = 'IND'
df2.loc[df2['Country/Territory'] == 'Indonesia','Code'] = 'IDN'

# %%
df2['ID'] = df2['Code'].str.cat(df2['Year'].astype('str'))

df2
# Out:
#    Country/Territory Code  Year  population       ID
# 1              India  IND  1991   891273209  IND1991
# 2              India  IND  1992   909307016  IND1992
# 3              India  IND  1993   927403860  IND1993
# 4              India  IND  1994   945601831  IND1994
# 5              India  IND  1995   963922588  IND1995
# 6              India  IND  1996   982365243  IND1996
# 7              India  IND  1997  1000900030  IND1997
# 8              India  IND  1998  1019483581  IND1998
# 9              India  IND  1999  1038058156  IND1999
# 10             India  IND  2000  1056575549  IND2000
# 11             India  IND  2001  1075000085  IND2001
# 12             India  IND  2002  1093317189  IND2002
# 13             India  IND  2003  1111523144  IND2003
# 14             India  IND  2004  1129623456  IND2004
# 15             India  IND  2005  1147609927  IND2005
# 16             India  IND  2006  1165486291  IND2006
# 17             India  IND  2007  1183209472  IND2007
# ...

# %%
df
# Out:
#          Entity Code  Year  \
# 2641      India  IND  1991
# 2642      India  IND  1992
# 2643      India  IND  1993
# 2644      India  IND  1994
# 2645      India  IND  1995
# 2646      India  IND  1996
# 2647      India  IND  1997
# 2648      India  IND  1998
# 2649      India  IND  1999
# 2650      India  IND  2000
# 2651      India  IND  2001
# 2652      India  IND  2002
# 2653      India  IND  2003
# 2654      India  IND  2004
# 2655      India  IND  2005
# 2656      India  IND  2006
# 2657      India  IND  2007
# 2658      India  IND  2008
# 2659      India  IND  2009
# 2660      India  IND  2010
# 2661      India  IND  2011
# 2662      India  IND  2012
# 2663      India  IND  2013
# 2664      India  IND  2014
# 2665      India  IND  2015
# 2666      India  IND  2016
# 2667      India  IND  2017
# 2668      India  IND  2018
# 2669      India  IND  2019
# 2671  Indonesia  IDN  1991
# 2672  Indonesia  IDN  1992
# 2673  Indonesia  IDN  1993
# 2674  Indonesia  IDN  1994
# ...

# %%
populasi = df2['population']

# %%
merge = pd.merge(df,populasi, on = populasi, how = 'left')
pd.set_option('display.max_rows', None)

merge
# Out:
#          key_0     Entity Code  Year  \
# 0    891273209      India  IND  1991
# 1    909307016      India  IND  1992
# 2    927403860      India  IND  1993
# 3    945601831      India  IND  1994
# 4    963922588      India  IND  1995
# 5    982365243      India  IND  1996
# 6   1000900030      India  IND  1997
# 7   1019483581      India  IND  1998
# 8   1038058156      India  IND  1999
# 9   1056575549      India  IND  2000
# 10  1075000085      India  IND  2001
# 11  1093317189      India  IND  2002
# 12  1111523144      India  IND  2003
# 13  1129623456      India  IND  2004
# 14  1147609927      India  IND  2005
# 15  1165486291      India  IND  2006
# 16  1183209472      India  IND  2007
# 17  1200669765      India  IND  2008
# 18  1217726215      India  IND  2009
# 19  1234281170      India  IND  2010
# 20  1250288729      India  IND  2011
# 21  1265782790      India  IND  2012
# 22  1280846129      India  IND  2013
# 23  1295604184      India  IND  2014
# ...

# %%
df = merge.drop(columns = ['key_0'])

df
# Out:
#        Entity Code  Year  \
# 0       India  IND  1991
# 1       India  IND  1992
# 2       India  IND  1993
# 3       India  IND  1994
# 4       India  IND  1995
# 5       India  IND  1996
# 6       India  IND  1997
# 7       India  IND  1998
# 8       India  IND  1999
# 9       India  IND  2000
# 10      India  IND  2001
# 11      India  IND  2002
# 12      India  IND  2003
# 13      India  IND  2004
# 14      India  IND  2005
# 15      India  IND  2006
# 16      India  IND  2007
# 17      India  IND  2008
# 18      India  IND  2009
# 19      India  IND  2010
# 20      India  IND  2011
# 21      India  IND  2012
# 22      India  IND  2013
# 23      India  IND  2014
# 24      India  IND  2015
# 25      India  IND  2016
# 26      India  IND  2017
# 27      India  IND  2018
# 28      India  IND  2019
# 29  Indonesia  IDN  1991
# 30  Indonesia  IDN  1992
# 31  Indonesia  IDN  1993
# 32  Indonesia  IDN  1994
# 33  Indonesia  IDN  1995
# 34  Indonesia  IDN  1996
# ...

# %%
file3 = "gdp.csv"

df3 = pd.read_csv(file3, sep = ';')

df3
# Out:
#    Country Name  year       GDP_USD  GDP_per_capita_USD
# 0         India  1990  3.209790e+11             3675.56
# 1         India  1991  2.701050e+11             3030.55
# 2         India  1992  2.882080e+11             3169.53
# 3         India  1993  2.792960e+11             3011.59
# 4         India  1994  3.272760e+11             3461.02
# 5         India  1995  3.602820e+11             3737.66
# 6         India  1996  3.928970e+11             3999.50
# 7         India  1997  4.158680e+11             4154.93
# 8         India  1998  4.213510e+11             4132.98
# 9         India  1999  4.588200e+11             4419.98
# 10        India  2000  4.683950e+11             4433.14
# 11        India  2001  4.854410e+11             4515.72
# 12        India  2002  5.149380e+11             4709.86
# 13        India  2003  6.076990e+11             5467.26
# 14        India  2004  7.091490e+11             6277.74
# 15        India  2005  8.203820e+11             7148.61
# ...

# %%
df3.loc[df3['Country Name'] == 'India','ID'] = 'IND'
df3.loc[df3['Country Name'] == 'Indonesia','ID'] = 'IDN'

df3
# Out:
#    Country Name  year       GDP_USD  GDP_per_capita_USD   ID
# 0         India  1990  3.209790e+11             3675.56  IND
# 1         India  1991  2.701050e+11             3030.55  IND
# 2         India  1992  2.882080e+11             3169.53  IND
# 3         India  1993  2.792960e+11             3011.59  IND
# 4         India  1994  3.272760e+11             3461.02  IND
# 5         India  1995  3.602820e+11             3737.66  IND
# 6         India  1996  3.928970e+11             3999.50  IND
# 7         India  1997  4.158680e+11             4154.93  IND
# 8         India  1998  4.213510e+11             4132.98  IND
# 9         India  1999  4.588200e+11             4419.98  IND
# 10        India  2000  4.683950e+11             4433.14  IND
# 11        India  2001  4.854410e+11             4515.72  IND
# 12        India  2002  5.149380e+11             4709.86  IND
# 13        India  2003  6.076990e+11             5467.26  IND
# ...

# %%
df3['ID'] = df3['ID'].str.cat(df3['year'].astype('str'))

df3
# Out:
#    Country Name  year       GDP_USD  GDP_per_capita_USD       ID
# 0         India  1990  3.209790e+11             3675.56  IND1990
# 1         India  1991  2.701050e+11             3030.55  IND1991
# 2         India  1992  2.882080e+11             3169.53  IND1992
# 3         India  1993  2.792960e+11             3011.59  IND1993
# 4         India  1994  3.272760e+11             3461.02  IND1994
# 5         India  1995  3.602820e+11             3737.66  IND1995
# 6         India  1996  3.928970e+11             3999.50  IND1996
# 7         India  1997  4.158680e+11             4154.93  IND1997
# 8         India  1998  4.213510e+11             4132.98  IND1998
# 9         India  1999  4.588200e+11             4419.98  IND1999
# 10        India  2000  4.683950e+11             4433.14  IND2000
# 11        India  2001  4.854410e+11             4515.72  IND2001
# 12        India  2002  5.149380e+11             4709.86  IND2002
# ...

# %%
df3 = df3.drop(columns = ['Code'])

df3
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 df3 = df3.drop(columns = ['Code'])
#       3 df3
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\core\frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
gdp = df3['GDP_per_capita_USD']

gdp
# Out:
# 0     3675.56
# 1     3030.55
# 2     3169.53
# 3     3011.59
# 4     3461.02
# 5     3737.66
# 6     3999.50
# 7     4154.93
# 8     4132.98
# 9     4419.98
# 10    4433.14
# 11    4515.72
# 12    4709.86
# 13    5467.26
# 14    6277.74
# 15    7148.61
# 16    8067.53
# 17    1028.33
# 18    9985.22
# 19    1101.96
# 20    1357.56
# 21    1458.10
# 22    1443.88
# 23    1449.61
# 24    1573.88
# 25    1605.60
# 26    1732.55
# 27    1980.66
# 28    1998.25
# 29    2072.24
# 30    5850.76
# 31    6317.82
# 32    6819.38
# 33    8279.05
# 34    9122.03
# 35    1026.39
# 36    1137.41
# 37    1063.71
# 38    4639.48
# 39    6710.98
# 40    7801.90
# 41    7482.57
# 42    9001.77
# 43    1065.64
# 44    1150.26
# 45    1263.28
# 46    1589.80
# 47    1860.00
# 48    2166.85
# 49    2261.24
# 50    3122.36
# 51    3643.04
# 52    3694.35
# 53    3623.92
# 54    3491.63
# 55    3331.69
# 56    3562.81
# 57    3837.57
# 58    3893.85
# 59    4135.23
# ...

# %%
merge = pd.merge(df,gdp, on = gdp, how = 'left')
pd.set_option('display.max_rows', None)

merge
# Out:
#       key_0 Country Name  year       GDP_USD  GDP_per_capita_USD_x  \
# 0   3675.56        India  1990  3.209790e+11               3675.56
# 1   3030.55        India  1991  2.701050e+11               3030.55
# 2   3169.53        India  1992  2.882080e+11               3169.53
# 3   3011.59        India  1993  2.792960e+11               3011.59
# 4   3461.02        India  1994  3.272760e+11               3461.02
# 5   3737.66        India  1995  3.602820e+11               3737.66
# 6   3999.50        India  1996  3.928970e+11               3999.50
# 7   4154.93        India  1997  4.158680e+11               4154.93
# 8   4132.98        India  1998  4.213510e+11               4132.98
# 9   4419.98        India  1999  4.588200e+11               4419.98
# 10  4433.14        India  2000  4.683950e+11               4433.14
# 11  4515.72        India  2001  4.854410e+11               4515.72
# 12  4709.86        India  2002  5.149380e+11               4709.86
# ...

# %%
df = merge.drop(columns = ['key_0'])

df
# Out:
#    Country Name  year       GDP_USD  GDP_per_capita_USD_x Country/Territory  \
# 0         India  1990  3.209790e+11               3675.56               NaN
# 1         India  1991  2.701050e+11               3030.55             India
# 2         India  1992  2.882080e+11               3169.53             India
# 3         India  1993  2.792960e+11               3011.59             India
# 4         India  1994  3.272760e+11               3461.02             India
# 5         India  1995  3.602820e+11               3737.66             India
# 6         India  1996  3.928970e+11               3999.50             India
# 7         India  1997  4.158680e+11               4154.93             India
# 8         India  1998  4.213510e+11               4132.98             India
# 9         India  1999  4.588200e+11               4419.98             India
# 10        India  2000  4.683950e+11               4433.14             India
# ...

# %%
df = df.rename(columns = {'GDP_per_capita_USD' : 'GDP'})

df
# Out:
#    Country Name  year       GDP_USD  GDP_per_capita_USD_x Country/Territory  \
# 0         India  1990  3.209790e+11               3675.56               NaN
# 1         India  1991  2.701050e+11               3030.55             India
# 2         India  1992  2.882080e+11               3169.53             India
# 3         India  1993  2.792960e+11               3011.59             India
# 4         India  1994  3.272760e+11               3461.02             India
# 5         India  1995  3.602820e+11               3737.66             India
# 6         India  1996  3.928970e+11               3999.50             India
# 7         India  1997  4.158680e+11               4154.93             India
# 8         India  1998  4.213510e+11               4132.98             India
# 9         India  1999  4.588200e+11               4419.98             India
# 10        India  2000  4.683950e+11               4433.14             India
# ...

# %%
file4 = "unemployment.csv"

df4 = pd.read_csv(file4, sep = ';')

df4
# Out:
#       Country  Year  Unemployment
# 0       India  1991          5.60
# 1       India  1992          5.73
# 2       India  1993          5.69
# 3       India  1994          5.74
# 4       India  1995          5.76
# 5       India  1996          5.74
# 6       India  1997          5.61
# 7       India  1998          5.67
# 8       India  1999          5.74
# 9       India  2000          5.56
# 10      India  2001          5.58
# 11      India  2002          5.53
# 12      India  2003          5.64
# 13      India  2004          5.63
# 14      India  2005          5.61
# 15      India  2006          5.60
# 16      India  2007          5.57
# 17      India  2008          5.41
# 18      India  2009          5.54
# 19      India  2010          5.55
# 20      India  2011          5.43
# 21      India  2012          5.41
# 22      India  2013          5.42
# 23      India  2014          5.44
# 24      India  2015          5.43
# 25      India  2016          5.42
# ...

# %%
df4.loc[df4['Country'] == 'India', 'Code'] = 'IND'
df4.loc[df4['Country'] == 'Indonesia', 'Code'] = 'IDN'

df4
# Out:
#       Country  Year  Unemployment Code
# 0       India  1991          5.60  IND
# 1       India  1992          5.73  IND
# 2       India  1993          5.69  IND
# 3       India  1994          5.74  IND
# 4       India  1995          5.76  IND
# 5       India  1996          5.74  IND
# 6       India  1997          5.61  IND
# 7       India  1998          5.67  IND
# 8       India  1999          5.74  IND
# 9       India  2000          5.56  IND
# 10      India  2001          5.58  IND
# 11      India  2002          5.53  IND
# 12      India  2003          5.64  IND
# 13      India  2004          5.63  IND
# 14      India  2005          5.61  IND
# 15      India  2006          5.60  IND
# 16      India  2007          5.57  IND
# 17      India  2008          5.41  IND
# 18      India  2009          5.54  IND
# 19      India  2010          5.55  IND
# 20      India  2011          5.43  IND
# 21      India  2012          5.41  IND
# 22      India  2013          5.42  IND
# ...

# %%
df4['ID'] = df4['Code'].str.cat(df4['Year'].astype('str'))

df4.set_index('ID')
# Out:
#            Country  Year  Unemployment Code
# ID
# IND1991      India  1991          5.60  IND
# IND1992      India  1992          5.73  IND
# IND1993      India  1993          5.69  IND
# IND1994      India  1994          5.74  IND
# IND1995      India  1995          5.76  IND
# IND1996      India  1996          5.74  IND
# IND1997      India  1997          5.61  IND
# IND1998      India  1998          5.67  IND
# IND1999      India  1999          5.74  IND
# IND2000      India  2000          5.56  IND
# IND2001      India  2001          5.58  IND
# IND2002      India  2002          5.53  IND
# IND2003      India  2003          5.64  IND
# IND2004      India  2004          5.63  IND
# IND2005      India  2005          5.61  IND
# IND2006      India  2006          5.60  IND
# IND2007      India  2007          5.57  IND
# IND2008      India  2008          5.41  IND
# IND2009      India  2009          5.54  IND
# IND2010      India  2010          5.55  IND
# ...

# %%
df = df.set_index('ID').join(df4.set_index('ID'), how='left', lsuffix='_left', rsuffix='_right')

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 df = df.set_index('ID').join(df4.set_index('ID'), how='left', lsuffix='_left', rsuffix='_right')
#       3 df
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
# ...

# %%
df = df2.set_index('ID').join(df, how='left', lsuffix='_left', rsuffix='_right')

df
# Out:
#         Country/Territory Code_left  Year_left  population Entity Code_right  \
# ID
# IND1991             India       IND       1991   891273209    NaN        NaN
# IND1992             India       IND       1992   909307016    NaN        NaN
# IND1993             India       IND       1993   927403860    NaN        NaN
# IND1994             India       IND       1994   945601831    NaN        NaN
# IND1995             India       IND       1995   963922588    NaN        NaN
# IND1996             India       IND       1996   982365243    NaN        NaN
# IND1997             India       IND       1997  1000900030    NaN        NaN
# IND1998             India       IND       1998  1019483581    NaN        NaN
# IND1999             India       IND       1999  1038058156    NaN        NaN
# IND2000             India       IND       2000  1056575549    NaN        NaN
# IND2001             India       IND       2001  1075000085    NaN        NaN
# ...

# %%
df = df3.set_index('ID').join(df, how='left', lsuffix='_left', rsuffix='_right')
pd.set_option('display.max_columns', None)

df
# Out:
#         Country Name_left  year_left  GDP_USD_left  GDP_per_capita_USD  \
# ID
# IND1990             India       1990  3.209790e+11             3675.56
# IND1991             India       1991  2.701050e+11             3030.55
# IND1992             India       1992  2.882080e+11             3169.53
# IND1993             India       1993  2.792960e+11             3011.59
# IND1994             India       1994  3.272760e+11             3461.02
# IND1995             India       1995  3.602820e+11             3737.66
# IND1996             India       1996  3.928970e+11             3999.50
# IND1997             India       1997  4.158680e+11             4154.93
# IND1998             India       1998  4.213510e+11             4132.98
# IND1999             India       1999  4.588200e+11             4419.98
# IND2000             India       2000  4.683950e+11             4433.14
# IND2001             India       2001  4.854410e+11             4515.72
# ...

# %%
df = df.rename(columns = {'GDP_per_capita_USD_right' : 'GDP'})

df
# Out:
#         Country Name_left  year_left  GDP_USD_left  GDP_per_capita_USD  \
# ID
# IND1990             India       1990  3.209790e+11             3675.56
# IND1991             India       1991  2.701050e+11             3030.55
# IND1992             India       1992  2.882080e+11             3169.53
# IND1993             India       1993  2.792960e+11             3011.59
# IND1994             India       1994  3.272760e+11             3461.02
# IND1995             India       1995  3.602820e+11             3737.66
# IND1996             India       1996  3.928970e+11             3999.50
# IND1997             India       1997  4.158680e+11             4154.93
# IND1998             India       1998  4.213510e+11             4132.98
# IND1999             India       1999  4.588200e+11             4419.98
# IND2000             India       2000  4.683950e+11             4433.14
# IND2001             India       2001  4.854410e+11             4515.72
# ...

# %%
df = df[['Country', 'Year', 'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)', 
         'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)', 
         'Total', 
         'population', 
         'GDP', 
         'Unemployment']]

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 df = df[['Country', 'Year', 'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)',
#       2          'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)',
#       3          'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)',
#       4          'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)',
#       5          'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)',
#       6          'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)',
#       7          'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)',
#       8          'Total',
#       9          'population',
#      10          'GDP',
# ...

# %%
india = df.loc[df['Country'] == 'India']

india
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# ...

# %%
indo = df.loc[df['Country'] == 'Indonesia']

indo
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\BELAJAR\GITHUB\python-100daysChallenge\venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# ...

# %%
total_indo = indo['Total']

total_indo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 total_indo = indo['Total']
#       3 total_indo
#
# NameError: name 'indo' is not defined

# %%
total_india = india['Total']

total_india
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 total_india = india['Total']
#       3 total_india
#
# NameError: name 'india' is not defined

# %%
Unemp = indo['Unemployment']

Unemp
# Out:
# ID
# IDN1991    2.62
# IDN1992    2.73
# IDN1993    2.78
# IDN1994    4.37
# IDN1995    4.60
# IDN1996    4.86
# IDN1997    4.68
# IDN1998    5.46
# IDN1999    6.36
# IDN2000    6.08
# IDN2001    6.08
# IDN2002    6.60
# IDN2003    6.66
# IDN2004    7.30
# IDN2005    7.94
# IDN2006    7.55
# IDN2007    8.06
# IDN2008    7.21
# IDN2009    6.11
# IDN2010    5.61
# IDN2011    5.15
# IDN2012    4.47
# IDN2013    4.34
# IDN2014    4.05
# IDN2015    4.51
# IDN2016    4.30
# IDN2017    3.88
# IDN2018    4.40
# IDN2019    3.62
# Name: Unemployment, dtype: float64

# %%
Unemp = india['Unemployment']

Unemp
# Out:
# ID
# IND1991    5.60
# IND1992    5.73
# IND1993    5.69
# IND1994    5.74
# IND1995    5.76
# IND1996    5.74
# IND1997    5.61
# IND1998    5.67
# IND1999    5.74
# IND2000    5.56
# IND2001    5.58
# IND2002    5.53
# IND2003    5.64
# IND2004    5.63
# IND2005    5.61
# IND2006    5.60
# IND2007    5.57
# IND2008    5.41
# IND2009    5.54
# IND2010    5.55
# IND2011    5.43
# IND2012    5.41
# IND2013    5.42
# IND2014    5.44
# IND2015    5.43
# IND2016    5.42
# IND2017    5.36
# IND2018    5.33
# IND2019    5.27
# Name: Unemployment, dtype: float64

# %% [markdown]
# ## Korelasi Mental Health Indo dengan GDP per Kapita

# %%
indo['Total'].corr(indo['Unemployment'])
# Out:
# -0.03312325626999777

# %% [markdown]
# ## Korelasi Mental Health India dengan Populasi

# %%
india['Total'].corr(india['Unemployment'])
# Out:
# 0.8811891377069153

# %%
import matplotlib.font_manager as fm

# %%
path = "MADEAvenuePERSONALUSE-Regular.otf"
path2 = "Philosopher-Regular.ttf"
path3 = "Quicksand_Bold.otf"
path4 = "GrebackGrotesquePERSONAL-Regular.otf"



font1 = fm.FontProperties(fname = path, size = 25)
font2 = fm.FontProperties(fname = path2, size = 13)
font3 = fm.FontProperties(fname = path3, size = 9)
font4 = fm.FontProperties(fname = path, size = 22)
font5 = fm.FontProperties(fname = path2, size = 12)
font6 = fm.FontProperties(fname = path2, size = 18)

# %%
plt.figure(figsize = (14,4))

plt.bar(india['Year'], india['Unemployment'], color = '#235347', label = 'India')
plt.bar(indo['Year'], indo['Unemployment'], color = '#4f0205', label = 'Indonesia', bottom = india['Unemployment'])

plt.title('Tingkat Pengangguran di India dan Indonesia Tahun 1990 - 2019', fontproperties = font1)
plt.xlabel('Year', fontproperties = font2)
plt.ylabel('Unemployment(%)', fontproperties = font2)


plt.xticks(np.arange(1990, 2020, 2), fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.legend(prop = font5)

plt.show()

# %%
sns.jointplot(data = indo, y = indo['Total'], x = indo['Unemployment'], kind = 'reg', color = '#313f5f')

plt.title('Korelasi Antara Mental Health Disorder \ndengan Tingkat Pengangguran di Indonesia\n Tahun 1990 - 2019', pad = 80, fontproperties = font4)
plt.xlabel('Unemployment (%))', fontproperties = font2)
plt.ylabel('Mental Health Disorder (%)', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
sns.jointplot(data = india, y = india['Total'], x = india['Unemployment'], kind = 'reg', color = '#6e6456')

plt.title('Korelasi Antara Mental Health Disorder \ndengan Tingkat Pengangguran di India\n Tahun 1990 - 2019', pad = 80, fontproperties = font4)
plt.xlabel('Unemployment (%))', fontproperties = font2)
plt.ylabel('Mental Health Disorder (%)', fontproperties = font2)

plt.xticks(fontproperties = font3)
plt.yticks(fontproperties = font3)

plt.grid(linestyle = 'dotted')

plt.show()

# %%
indo.describe()
# Out:
#               Year  \
# count    29.000000
# mean   2005.000000
# std       8.514693
# min    1991.000000
# 25%    1998.000000
# 50%    2005.000000
# 75%    2012.000000
# max    2019.000000
#
#        Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          29.000000
# mean                                            0.296266
# std                                             0.005013
# min                                             0.287413
# 25%                                             0.292743
# 50%                                             0.296223
# 75%                                             0.299190
# max                                             0.306168
#
#        Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          29.000000
# mean                                            0.342111
# ...

# %%
india.describe()
# Out:
#               Year  \
# count    29.000000
# mean   2005.000000
# std       8.514693
# min    1991.000000
# 25%    1998.000000
# 50%    2005.000000
# 75%    2012.000000
# max    2019.000000
#
#        Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          29.000000
# mean                                            0.286865
# std                                             0.003754
# min                                             0.283902
# 25%                                             0.284250
# 50%                                             0.284972
# 75%                                             0.288682
# max                                             0.294656
#
#        Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# count                                          29.000000
# mean                                            0.360654
# ...

# %%
df
# Out:
#            Country  Year  \
# ID
# IND1991      India  1991
# IND1992      India  1992
# IND1993      India  1993
# IND1994      India  1994
# IND1995      India  1995
# IND1996      India  1996
# IND1997      India  1997
# IND1998      India  1998
# IND1999      India  1999
# IND2000      India  2000
# IND2001      India  2001
# IND2002      India  2002
# IND2003      India  2003
# IND2004      India  2004
# IND2005      India  2005
# IND2006      India  2006
# IND2007      India  2007
# IND2008      India  2008
# IND2009      India  2009
# IND2010      India  2010
# IND2011      India  2011
# IND2012      India  2012
# IND2013      India  2013
# IND2014      India  2014
# IND2015      India  2015
# IND2016      India  2016
# IND2017      India  2017
# IND2018      India  2018
# IND2019      India  2019
# IDN1991  Indonesia  1991
# IDN1992  Indonesia  1992
# IDN1993  Indonesia  1993
# IDN1994  Indonesia  1994
# IDN1995  Indonesia  1995
# IDN1996  Indonesia  1996
# ...

# %%
df.loc[df['Year'] == 1990]
# Out:
#        Entity Code  Year  \
# 0       India  IND  1990
# 30  Indonesia  IDN  1990
#
#     Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                            0.283639
# 30                                           0.286067
#
#     Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                            0.359677
# 30                                           0.337193
#
#     Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                            0.087173
# 30                                           0.083145
#
#     Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                            3.019089
# 30                                           3.461374
#
#     Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
df.to_csv('Mental Health Dataset.csv')
